# %% [markdown]
# ## ELLAHLAKES STOCK PRICE PREDICTION

# %%
## to change the name across the code
## ctrl + h will open the tab the fill the new name in replace
## to change the name across the entire code so you dont have to click enter everytime
## ctrl + shift + h

import pandas as pd

ellahlakes=pd.read_csv('../stock_data/ellahlakes.csv') ## so it can be small letter. This is cool.
ellahlakes=ellahlakes.drop(columns=['high_price','low_price'])
ellahlakes.rename(columns={'trade_date':'date'},inplace=True)
ellahlakes['date']=pd.to_datetime(ellahlakes['date'])
ellahlakes['month']=ellahlakes['date'].dt.month
ellahlakes['quarter']=ellahlakes['date'].dt.quarter
ellahlakes['year']=ellahlakes['date'].dt.year

ellahlakes
# Out:
#           id      symbol       date  open_price  close_price   volume  \
# 0      42782  ELLAHLAKES 2017-01-03        4.26         4.26        0
# 1      43342  ELLAHLAKES 2017-01-04        4.26         4.26        0
# 2      43452  ELLAHLAKES 2017-01-05        4.26         4.26        0
# 3      43562  ELLAHLAKES 2017-01-06        4.26         4.26        0
# 4      43652  ELLAHLAKES 2017-01-09        4.26         4.26        0
# ...      ...         ...        ...         ...          ...      ...
# 2258  298053  ELLAHLAKES 2026-07-13        8.75         8.75  7004984
# 2259  298491  ELLAHLAKES 2026-07-14        8.55         8.55  9521217
# 2260  298929  ELLAHLAKES 2026-07-15        8.95         8.95  2351435
# 2261  299367  ELLAHLAKES 2026-07-16        8.95         8.95  2042964
# 2262  299805  ELLAHLAKES 2026-07-17        9.00         9.00  4107698
#
#                             created_at  month  quarter  year
# 0     2026-04-08T02:41:25.765521+00:00      1        1  2017
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(ellahlakes['close_price'])
plt.show()

# %%
ellahlakes_end_month_df = (
    ellahlakes
    .sort_values("date")
    .groupby(ellahlakes["date"].dt.to_period("M"))
    .tail(1)
    .reset_index(drop=True)
)

ellahlakes_end_month_df
# Out:
#          id      symbol       date  open_price  close_price    volume  \
# 0     45352  ELLAHLAKES 2017-01-31        4.26         4.26         0
# 1     47173  ELLAHLAKES 2017-02-28        4.26         4.26         0
# 2     49289  ELLAHLAKES 2017-03-31        4.26         4.26         0
# 3     51117  ELLAHLAKES 2017-04-28        4.26         4.26         0
# 4     53039  ELLAHLAKES 2017-05-31        4.26         4.26         0
# ..      ...         ...        ...         ...          ...       ...
# 110   35291  ELLAHLAKES 2026-03-31       12.00        12.00   5217773
# 111  281117  ELLAHLAKES 2026-04-30        9.95         9.95   5720551
# 112  284183  ELLAHLAKES 2026-05-29       10.00        10.00  14652599
# 113  294111  ELLAHLAKES 2026-06-30        8.35         8.35   6500287
# 114  299805  ELLAHLAKES 2026-07-17        9.00         9.00   4107698
#
#                            created_at  month  quarter  year
# 0     2026-04-08T02:43:03.07753+00:00      1        1  2017
# ...

# %%
plt.plot(ellahlakes_end_month_df['close_price'])
plt.show()

# %%
ellahlakes_end_month_df['returns']=ellahlakes_end_month_df['close_price'].pct_change()*100
ellahlakes_end_month_df
# Out:
#          id      symbol       date  open_price  close_price    volume  \
# 0     45352  ELLAHLAKES 2017-01-31        4.26         4.26         0
# 1     47173  ELLAHLAKES 2017-02-28        4.26         4.26         0
# 2     49289  ELLAHLAKES 2017-03-31        4.26         4.26         0
# 3     51117  ELLAHLAKES 2017-04-28        4.26         4.26         0
# 4     53039  ELLAHLAKES 2017-05-31        4.26         4.26         0
# ..      ...         ...        ...         ...          ...       ...
# 110   35291  ELLAHLAKES 2026-03-31       12.00        12.00   5217773
# 111  281117  ELLAHLAKES 2026-04-30        9.95         9.95   5720551
# 112  284183  ELLAHLAKES 2026-05-29       10.00        10.00  14652599
# 113  294111  ELLAHLAKES 2026-06-30        8.35         8.35   6500287
# 114  299805  ELLAHLAKES 2026-07-17        9.00         9.00   4107698
#
#                            created_at  month  quarter  year    returns
# ...

# %%
plt.plot(ellahlakes_end_month_df['returns'])
plt.show()

# %%
## Test stationarity

from statsmodels.tsa.stattools import adfuller

result = adfuller(ellahlakes_end_month_df['returns'].dropna())
print(result)
pvalue = result[1]
if pvalue < 0.05:
    print('stationary')
else:
    print('not stationary')
# Out:
# (np.float64(-5.83688520980628), np.float64(3.857866426527441e-07), 2, 111, {'1%': np.float64(-3.490683082754047), '5%': np.float64(-2.8879516565798817), '10%': np.float64(-2.5808574442009578)}, np.float64(826.7649810641515))
# stationary

# %%
# Plotting the autocorrelation function and the partial autocorrelation function
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ellahlakes_end_month_df['returns'].dropna(), lags=10)
plot_pacf(ellahlakes_end_month_df['returns'].dropna(), lags=10)
plt.show()

# %%
import random
random.seed(12345)

from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

train=ellahlakes_end_month_df['close_price'][:-10]
test=ellahlakes_end_month_df['close_price'][-10:]

# Grid Search on the SARIMA model
import numpy as np
scores = []
for p in range(3):
    for i in range(3):
        for q in range(3):
            for P in range(3):
                for D in range(3):
                    for Q in range(3):
                        try:
                            mod = SARIMAX(train, 
                            order=(p,i,q), seasonal_order=(P,D,Q,12))
                            res = mod.fit(disp=False)
                            fcst=res.forecast(steps=10)
                            score =  [p,i,q,P,D,Q,r2_score(test,fcst)]
                            print(score)
                            scores.append(score)
                            del mod
                            del res
                        except:
                            print('errored')
# Out:
# [0, 0, 0, 0, 0, 0, -29.708308026380145]
# [0, 0, 0, 0, 0, 1, -19.296114189385786]
# [0, 0, 0, 0, 0, 2, -17.7958618387732]
# [0, 0, 0, 0, 1, 0, -14.337408962155127]
# [0, 0, 0, 0, 1, 1, -14.346710752237502]
# [0, 0, 0, 0, 1, 2, -14.27723241135963]
# [0, 0, 0, 0, 2, 0, -15.060829136410511]
# [0, 0, 0, 0, 2, 1, -15.013065917549167]
# [0, 0, 0, 0, 2, 2, -15.201501949948927]
# [0, 0, 0, 1, 0, 0, -14.861480560260937]
# [0, 0, 0, 1, 0, 1, -14.550178520191121]
# [0, 0, 0, 1, 0, 2, -14.390643738387237]
# [0, 0, 0, 1, 1, 0, -14.57336818085278]
# [0, 0, 0, 1, 1, 1, -14.180884685443328]
# [0, 0, 0, 1, 1, 2, -14.344699814156867]
# [0, 0, 0, 1, 2, 0, -15.343182935425133]
# [0, 0, 0, 1, 2, 1, -15.446105235397784]
# [0, 0, 0, 1, 2, 2, -15.438481322853569]
# [0, 0, 0, 2, 0, 0, -15.13986419416771]
# [0, 0, 0, 2, 0, 1, -14.3180853244762]
# [0, 0, 0, 2, 0, 2, -14.609493024830767]
# [0, 0, 0, 2, 1, 0, -14.563282819248224]
# [0, 0, 0, 2, 1, 1, -14.63350958201337]
# [0, 0, 0, 2, 1, 2, -14.365924551419832]
# ...

# %%
res = pd.DataFrame(scores)
res.columns = ['p', 'i', 'q', 'P', 'D', 'Q', 'score']
result = res.sort_values('score')
result
# Out:
#      p  i  q  P  D  Q       score
# 177  0  2  0  1  2  0 -105.942906
# 168  0  2  0  0  2  0 -105.137168
# 169  0  2  0  0  2  1 -100.265938
# 178  0  2  0  1  2  1  -97.741312
# 170  0  2  0  0  2  2  -91.516608
# ..  .. .. .. .. .. ..         ...
# 308  1  0  2  1  0  2    0.374488
# 316  1  0  2  2  0  1    0.377520
# 496  2  0  0  1  0  1    0.394845
# 271  1  0  1  0  0  1    0.408116
# 487  2  0  0  0  0  1    0.439488
#
# [729 rows x 7 columns]

# %%
# Fitting a SARIMAX model with our best model 
# order=(2,0,1), seasonal_order=(1,2,1,10)

import random
random.seed(12345)
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

y_train=ellahlakes_end_month_df['close_price'][:-10]
y_test=ellahlakes_end_month_df['close_price'][-10:]

# scaler=StandardScaler()
# exog_train_scaled=scaler.fit_transform(X_full[:-10])
# exog_test_scaled=scaler.transform(X_full[-10:])

mod = SARIMAX(
y_train,
order=(2,0,0), 
seasonal_order=(0,0,1,12),
)

res = mod.fit(disp=False)
fcst = res.forecast(steps=10)

plt.plot(list(y_test))
plt.plot(list(fcst))
plt.xlabel('Steps of the test data')
plt.ylabel('Monthly close price')
plt.legend(['test', 'forecast'])
plt.show()
print('r2_score: ',r2_score(y_test, fcst))
print('rmse: ', np.sqrt(mean_squared_error(y_test,fcst)))
print('description: ', ellahlakes_end_month_df.close_price.describe())
# Out:
# r2_score:  0.4394876586541767
# rmse:  1.614642070205105
# description:  count    115.000000
# mean       4.856174
# std        2.637120
# min        2.900000
# 25%        3.880000
# 50%        4.250000
# 75%        4.260000
# max       15.050000
# Name: close_price, dtype: float64

# %% [markdown]
# Its not capturing the variations properly. But we will work with it.

# %% [markdown]
# ## AFRINSURE STOCK PREDICTION

# %%
import pandas as pd

afri=pd.read_csv('../stock_data/AFRINSURE.csv')
afri
# Out:
#           id     symbol  trade_date  open_price  high_price  low_price  \
# 0      81307  AFRINSURE  2018-09-11         0.2         NaN        NaN
# 1      81409  AFRINSURE  2018-09-12         0.2         NaN        NaN
# 2      81511  AFRINSURE  2018-09-13         0.2         NaN        NaN
# 3      81613  AFRINSURE  2018-09-14         0.2         NaN        NaN
# 4      81715  AFRINSURE  2018-09-17         0.2         NaN        NaN
# ...      ...        ...         ...         ...         ...        ...
# 1851  298020  AFRINSURE  2026-07-13         0.2         NaN        NaN
# 1852  298458  AFRINSURE  2026-07-14         0.2         NaN        NaN
# 1853  298896  AFRINSURE  2026-07-15         0.2         NaN        NaN
# 1854  299334  AFRINSURE  2026-07-16         0.2         NaN        NaN
# 1855  299772  AFRINSURE  2026-07-17         0.2         NaN        NaN
#
#       close_price  volume                        created_at
# ...

# %%
afri=afri.drop(columns=['high_price','low_price'])

# %%
afri.rename(columns={'trade_date':'date'},inplace=True)

# %%
afri['date']=pd.to_datetime(afri['date'])
afri.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1856 entries, 0 to 1855
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1856 non-null   int64
#  1   symbol       1856 non-null   str
#  2   date         1856 non-null   datetime64[us]
#  3   open_price   1855 non-null   float64
#  4   close_price  1856 non-null   float64
#  5   volume       1781 non-null   float64
#  6   created_at   1856 non-null   str
# dtypes: datetime64[us](1), float64(3), int64(1), str(2)
# memory usage: 101.6 KB

# %%
afri['month']=afri['date'].dt.month
afri['quarter']=afri['date'].dt.quarter
afri['year']=afri['date'].dt.year

# %%
afri.close_price.describe()
# Out:
# count    1856.000000
# mean        0.200776
# std         0.005479
# min         0.200000
# 25%         0.200000
# 50%         0.200000
# 75%         0.200000
# max         0.260000
# Name: close_price, dtype: float64

# %% [markdown]
# The data is either faulty or this is how it is. The close_price is consistent.

# %%
import matplotlib.pyplot as plt

plt.plot(afri['close_price'])
plt.show()

# %% [markdown]
# We will stop here.

# %% [markdown]
# ## IKEJAHOTEL STOCK PRICE PREDICTION

# %%
## to change the name across the code
## ctrl + h will open the tab the fill the new name in replace
## to change the name across the entire code so you dont have to click enter everytime
## ctrl + shift + h

import pandas as pd

ikejahotel=pd.read_csv('../stock_data/ikejahotel.csv') ## so it can be small letter. This is cool.
ikejahotel=ikejahotel.drop(columns=['high_price','low_price'])
ikejahotel.rename(columns={'trade_date':'date'},inplace=True)
ikejahotel['date']=pd.to_datetime(ikejahotel['date'])
ikejahotel['month']=ikejahotel['date'].dt.month
ikejahotel['quarter']=ikejahotel['date'].dt.quarter
ikejahotel['year']=ikejahotel['date'].dt.year

ikejahotel
# Out:
#           id      symbol       date  open_price  close_price  volume  \
# 0      42858  IKEJAHOTEL 2017-01-03        1.78         1.78       0
# 1      43418  IKEJAHOTEL 2017-01-04        1.78         1.78       0
# 2      43528  IKEJAHOTEL 2017-01-05        1.78         1.78       0
# 3      43638  IKEJAHOTEL 2017-01-06        1.78         1.78       0
# 4      43728  IKEJAHOTEL 2017-01-09        1.78         1.78       0
# ...      ...         ...        ...         ...          ...     ...
# 2258  298073  IKEJAHOTEL 2026-07-13       42.50        42.50   55344
# 2259  298511  IKEJAHOTEL 2026-07-14       42.50        42.50  206672
# 2260  298949  IKEJAHOTEL 2026-07-15       42.50        42.50   47256
# 2261  299387  IKEJAHOTEL 2026-07-16       42.50        42.50   89609
# 2262  299825  IKEJAHOTEL 2026-07-17       42.50        42.50   87683
#
#                             created_at  month  quarter  year
# 0     2026-04-08T02:41:25.765521+00:00      1        1  2017
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(ikejahotel['close_price'])
plt.show()

# %%
ikejahotel_end_month_df = (
    ikejahotel
    .sort_values("date")
    .groupby(ikejahotel["date"].dt.to_period("M"))
    .tail(1)
    .reset_index(drop=True)
)

ikejahotel_end_month_df
# Out:
#          id      symbol       date  open_price  close_price  volume  \
# 0     45428  IKEJAHOTEL 2017-01-31        1.78         1.78       0
# 1     47251  IKEJAHOTEL 2017-02-28        1.78         1.78       0
# 2     49367  IKEJAHOTEL 2017-03-31        1.78         1.78       0
# 3     51194  IKEJAHOTEL 2017-04-28        1.78         1.78       0
# 4     53117  IKEJAHOTEL 2017-05-31        1.78         1.78       0
# ..      ...         ...        ...         ...          ...     ...
# 110   35310  IKEJAHOTEL 2026-03-31       39.00        39.00   91955
# 111  281136  IKEJAHOTEL 2026-04-30       37.25        37.25  305119
# 112  284202  IKEJAHOTEL 2026-05-29       40.20        40.20  230326
# 113  294130  IKEJAHOTEL 2026-06-30       43.25        43.25  738094
# 114  299825  IKEJAHOTEL 2026-07-17       42.50        42.50   87683
#
#                            created_at  month  quarter  year
# 0     2026-04-08T02:43:03.07753+00:00      1        1  2017
# ...

# %%
plt.plot(ikejahotel_end_month_df['close_price'])
plt.show()

# %%
ikejahotel_end_month_df['returns']=ikejahotel_end_month_df['close_price'].pct_change()*100
ikejahotel_end_month_df
# Out:
#          id      symbol       date  open_price  close_price  volume  \
# 0     45428  IKEJAHOTEL 2017-01-31        1.78         1.78       0
# 1     47251  IKEJAHOTEL 2017-02-28        1.78         1.78       0
# 2     49367  IKEJAHOTEL 2017-03-31        1.78         1.78       0
# 3     51194  IKEJAHOTEL 2017-04-28        1.78         1.78       0
# 4     53117  IKEJAHOTEL 2017-05-31        1.78         1.78       0
# ..      ...         ...        ...         ...          ...     ...
# 110   35310  IKEJAHOTEL 2026-03-31       39.00        39.00   91955
# 111  281136  IKEJAHOTEL 2026-04-30       37.25        37.25  305119
# 112  284202  IKEJAHOTEL 2026-05-29       40.20        40.20  230326
# 113  294130  IKEJAHOTEL 2026-06-30       43.25        43.25  738094
# 114  299825  IKEJAHOTEL 2026-07-17       42.50        42.50   87683
#
#                            created_at  month  quarter  year   returns
# 0     2026-04-08T02:43:03.07753+00:00      1        1  2017       NaN
# ...

# %%
plt.plot(ikejahotel_end_month_df['returns'])
plt.show()

# %%
## Test stationarity

from statsmodels.tsa.stattools import adfuller

result = adfuller(ikejahotel_end_month_df['returns'].dropna())
print(result)
pvalue = result[1]
if pvalue < 0.05:
    print('stationary')
else:
    print('not stationary')
# Out:
# (np.float64(-10.780631849987895), np.float64(2.2600004387888957e-19), 0, 113, {'1%': np.float64(-3.489589552580676), '5%': np.float64(-2.887477210140433), '10%': np.float64(-2.580604145195395)}, np.float64(879.1215548284869))
# stationary

# %%
# Plotting the autocorrelation function and the partial autocorrelation function
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ikejahotel_end_month_df['returns'].dropna(), lags=10)
plot_pacf(ikejahotel_end_month_df['returns'].dropna(), lags=10)
plt.show()

# %%
import random
random.seed(12345)

from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

train=ikejahotel_end_month_df['close_price'][:-10]
test=ikejahotel_end_month_df['close_price'][-10:]

# Grid Search on the SARIMA model
import numpy as np
scores = []
for p in range(3):
    for i in range(3):
        for q in range(3):
            for P in range(3):
                for D in range(3):
                    for Q in range(3):
                        try:
                            mod = SARIMAX(train, 
                            order=(p,i,q), seasonal_order=(P,D,Q,12))
                            res = mod.fit(disp=False)
                            fcst=res.forecast(steps=10)
                            score =  [p,i,q,P,D,Q,r2_score(test,fcst)]
                            print(score)
                            scores.append(score)
                            del mod
                            del res
                        except:
                            print('errored')
# Out:
# [0, 0, 0, 0, 0, 0, -26.225561177285336]
# [0, 0, 0, 0, 0, 1, -16.931878909700288]
# [0, 0, 0, 0, 0, 2, -13.11138431702995]
# [0, 0, 0, 0, 1, 0, -10.901880293779431]
# [0, 0, 0, 0, 1, 1, -9.19658985042697]
# [0, 0, 0, 0, 1, 2, -7.104955270350802]
# [0, 0, 0, 0, 2, 0, -6.061403441608416]
# [0, 0, 0, 0, 2, 1, -6.058158630112767]
# [0, 0, 0, 0, 2, 2, -5.140856512927209]
# [0, 0, 0, 1, 0, 0, -11.977548084837542]
# [0, 0, 0, 1, 0, 1, -10.102230395667176]
# [0, 0, 0, 1, 0, 2, -8.383773591850149]
# [0, 0, 0, 1, 1, 0, -6.884943491427204]
# [0, 0, 0, 1, 1, 1, -7.05824340728733]
# [0, 0, 0, 1, 1, 2, -6.496425920059456]
# [0, 0, 0, 1, 2, 0, -5.983797964497224]
# [0, 0, 0, 1, 2, 1, -5.673403696966755]
# [0, 0, 0, 1, 2, 2, -4.927209661773287]
# [0, 0, 0, 2, 0, 0, -8.250214854966613]
# [0, 0, 0, 2, 0, 1, -8.593183842006743]
# [0, 0, 0, 2, 0, 2, -9.980493253583916]
# [0, 0, 0, 2, 1, 0, -6.97873009164065]
# [0, 0, 0, 2, 1, 1, -6.750345634949211]
# [0, 0, 0, 2, 1, 2, -6.457043662326183]
# ...

# %%
res = pd.DataFrame(scores)
res.columns = ['p', 'i', 'q', 'P', 'D', 'Q', 'score']
result = res.sort_values('score')
result
# Out:
#      p  i  q  P  D  Q      score
# 0    0  0  0  0  0  0 -26.225561
# 27   0  0  1  0  0  0 -25.788811
# 54   0  0  2  0  0  0 -25.329073
# 162  0  2  0  0  0  0 -24.314946
# 145  0  1  2  1  0  1 -23.777172
# ..  .. .. .. .. .. ..        ...
# 664  2  2  0  1  2  2   0.158407
# 663  2  2  0  1  2  1   0.160658
# 671  2  2  0  2  2  0   0.168477
# 662  2  2  0  1  2  0   0.191521
# 672  2  2  0  2  2  1   0.220301
#
# [728 rows x 7 columns]

# %%
# Fitting a SARIMAX model with our best model 
# order=(2,0,1), seasonal_order=(1,2,1,10)

import random
random.seed(12345)
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

y_train=ikejahotel_end_month_df['close_price'][:-10]
y_test=ikejahotel_end_month_df['close_price'][-10:]

# scaler=StandardScaler()
# exog_train_scaled=scaler.fit_transform(X_full[:-10])
# exog_test_scaled=scaler.transform(X_full[-10:])

mod = SARIMAX(
y_train,
order=(2,2,0), 
seasonal_order=(2,2,1,12),
)

res = mod.fit(disp=False)
fcst = res.forecast(steps=10)

plt.plot(list(y_test))
plt.plot(list(fcst))
plt.xlabel('Steps of the test data')
plt.ylabel('Monthly close price')
plt.legend(['test', 'forecast'])
plt.show()
print('r2_score: ',r2_score(y_test, fcst))
print('rmse: ', np.sqrt(mean_squared_error(y_test,fcst)))
print('description: ', ikejahotel_end_month_df.close_price.describe())
# Out:
# r2_score:  0.22030138336471017
# rmse:  6.261624719558623
# description:  count    115.000000
# mean       6.389565
# std       10.413645
# min        0.840000
# 25%        1.205000
# 50%        1.780000
# 75%        6.715000
# max       43.250000
# Name: close_price, dtype: float64

# %% [markdown]
# This is ok.

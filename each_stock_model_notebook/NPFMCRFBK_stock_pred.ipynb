# %% [markdown]
# ## NPFMCRFBK STOCK PRICE PREDICTION

# %%
## to change the name across the code
## ctrl + h will open the tab the fill the new name in replace
## to change the name across the entire code so you dont have to click enter everytime
## ctrl + shift + h

import pandas as pd

npfmcrfbk=pd.read_csv('../stock_data/npfmcrfbk.csv') ## so it can be small letter. This is cool.
npfmcrfbk=npfmcrfbk.drop(columns=['high_price','low_price'])
npfmcrfbk.rename(columns={'trade_date':'date'},inplace=True)
npfmcrfbk['date']=pd.to_datetime(npfmcrfbk['date'])
npfmcrfbk['month']=npfmcrfbk['date'].dt.month
npfmcrfbk['quarter']=npfmcrfbk['date'].dt.quarter
npfmcrfbk['year']=npfmcrfbk['date'].dt.year

npfmcrfbk
# Out:
#           id     symbol       date  open_price  close_price   volume  \
# 0      42822  NPFMCRFBK 2017-01-03         1.1          1.1     3850
# 1      43382  NPFMCRFBK 2017-01-04         1.1          1.1   335000
# 2      43492  NPFMCRFBK 2017-01-05         1.1          1.1    27200
# 3      43602  NPFMCRFBK 2017-01-06         1.1          1.1    69000
# 4      43692  NPFMCRFBK 2017-01-09         1.1          1.1   101000
# ...      ...        ...        ...         ...          ...      ...
# 2258  298110  NPFMCRFBK 2026-07-13         5.0          5.0  1356108
# 2259  298548  NPFMCRFBK 2026-07-14         5.0          5.0   484904
# 2260  298986  NPFMCRFBK 2026-07-15         5.0          5.0   929546
# 2261  299424  NPFMCRFBK 2026-07-16         5.0          5.0   240515
# 2262  299862  NPFMCRFBK 2026-07-17         5.0          5.0   197149
#
#                             created_at  month  quarter  year
# 0     2026-04-08T02:41:25.765521+00:00      1        1  2017
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(npfmcrfbk['close_price'])
plt.show()

# %%
npfmcrfbk_end_month_df = (
    npfmcrfbk
    .sort_values("date")
    .groupby(npfmcrfbk["date"].dt.to_period("M"))
    .tail(1)
    .reset_index(drop=True)
)

npfmcrfbk_end_month_df
# Out:
#          id     symbol       date  open_price  close_price   volume  \
# 0     45392  NPFMCRFBK 2017-01-31        1.12         1.12     5000
# 1     47214  NPFMCRFBK 2017-02-28        1.12         1.12     1000
# 2     49330  NPFMCRFBK 2017-03-31        1.21         1.21  2610750
# 3     51157  NPFMCRFBK 2017-04-28        1.32         1.32   808239
# 4     53079  NPFMCRFBK 2017-05-31        1.28         1.28   128493
# ..      ...        ...        ...         ...          ...      ...
# 110   35347  NPFMCRFBK 2026-03-31        6.30         6.30  6424260
# 111  281173  NPFMCRFBK 2026-04-30        5.21         5.21  2507351
# 112  284239  NPFMCRFBK 2026-05-29        5.74         5.74   526523
# 113  294167  NPFMCRFBK 2026-06-30        4.75         4.75   695018
# 114  299862  NPFMCRFBK 2026-07-17        5.00         5.00   197149
#
#                            created_at  month  quarter  year
# 0     2026-04-08T02:43:03.07753+00:00      1        1  2017
# ...

# %%
plt.plot(npfmcrfbk_end_month_df['close_price'])
plt.show()

# %%
npfmcrfbk_end_month_df['returns']=npfmcrfbk_end_month_df['close_price'].pct_change()*100
npfmcrfbk_end_month_df
# Out:
#          id     symbol       date  open_price  close_price   volume  \
# 0     45392  NPFMCRFBK 2017-01-31        1.12         1.12     5000
# 1     47214  NPFMCRFBK 2017-02-28        1.12         1.12     1000
# 2     49330  NPFMCRFBK 2017-03-31        1.21         1.21  2610750
# 3     51157  NPFMCRFBK 2017-04-28        1.32         1.32   808239
# 4     53079  NPFMCRFBK 2017-05-31        1.28         1.28   128493
# ..      ...        ...        ...         ...          ...      ...
# 110   35347  NPFMCRFBK 2026-03-31        6.30         6.30  6424260
# 111  281173  NPFMCRFBK 2026-04-30        5.21         5.21  2507351
# 112  284239  NPFMCRFBK 2026-05-29        5.74         5.74   526523
# 113  294167  NPFMCRFBK 2026-06-30        4.75         4.75   695018
# 114  299862  NPFMCRFBK 2026-07-17        5.00         5.00   197149
#
#                            created_at  month  quarter  year    returns
# 0     2026-04-08T02:43:03.07753+00:00      1        1  2017        NaN
# ...

# %%
plt.plot(npfmcrfbk_end_month_df['returns'])
plt.show()

# %%
## Test stationarity

from statsmodels.tsa.stattools import adfuller

result = adfuller(npfmcrfbk_end_month_df['returns'].dropna())
print(result)
pvalue = result[1]
if pvalue < 0.05:
    print('stationary')
else:
    print('not stationary')
# Out:
# (np.float64(-11.639057788866713), np.float64(2.169091121680307e-21), 0, 113, {'1%': np.float64(-3.489589552580676), '5%': np.float64(-2.887477210140433), '10%': np.float64(-2.580604145195395)}, np.float64(810.7514110870223))
# stationary

# %%
# Plotting the autocorrelation function and the partial autocorrelation function
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(npfmcrfbk_end_month_df['returns'].dropna(), lags=10)
plot_pacf(npfmcrfbk_end_month_df['returns'].dropna(), lags=10)
plt.show()

# %%
import random
random.seed(12345)

from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

train=npfmcrfbk_end_month_df['close_price'][:-10]
test=npfmcrfbk_end_month_df['close_price'][-10:]

# Grid Search on the SARIMA model
import numpy as np
scores = []
for p in range(3):
    for i in range(3):
        for q in range(3):
            for P in range(3):
                for D in range(3):
                    for Q in range(3):
                        try:
                            mod = SARIMAX(train, 
                            order=(p,i,q), seasonal_order=(P,D,Q,12))
                            res = mod.fit(disp=False)
                            fcst=res.forecast(steps=10)
                            score =  [p,i,q,P,D,Q,r2_score(test,fcst)]
                            print(score)
                            scores.append(score)
                            del mod
                            del res
                        except:
                            print('errored')
# Out:
# [0, 0, 0, 0, 0, 0, -14.326693369147938]
# [0, 0, 0, 0, 0, 1, -8.98398525688631]
# [0, 0, 0, 0, 0, 2, -7.502132029833788]
# [0, 0, 0, 0, 1, 0, -5.086584974505866]
# [0, 0, 0, 0, 1, 1, -5.412121663069979]
# [0, 0, 0, 0, 1, 2, -5.447167732146739]
# [0, 0, 0, 0, 2, 0, -4.634358249069735]
# [0, 0, 0, 0, 2, 1, -4.776733658998464]
# [0, 0, 0, 0, 2, 2, -4.791962651340099]
# [0, 0, 0, 1, 0, 0, -5.324036171333382]
# [0, 0, 0, 1, 0, 1, -5.516988820792551]
# [0, 0, 0, 1, 0, 2, -5.554455425320348]
# [0, 0, 0, 1, 1, 0, -5.427016063207929]
# [0, 0, 0, 1, 1, 1, -5.470357687771613]
# [0, 0, 0, 1, 1, 2, -5.425320936116141]
# [0, 0, 0, 1, 2, 0, -4.933381397592669]
# [0, 0, 0, 1, 2, 1, -5.015581478739534]
# [0, 0, 0, 1, 2, 2, -4.802367334031977]
# [0, 0, 0, 2, 0, 0, -5.564249890083307]
# [0, 0, 0, 2, 0, 1, -5.571628839747973]
# [0, 0, 0, 2, 0, 2, -5.529552007178899]
# [0, 0, 0, 2, 1, 0, -5.444620687021306]
# [0, 0, 0, 2, 1, 1, -5.4359857964585565]
# [0, 0, 0, 2, 1, 2, -5.5098997736547615]
# ...

# %%
res = pd.DataFrame(scores)
res.columns = ['p', 'i', 'q', 'P', 'D', 'Q', 'score']
result = res.sort_values('score')
result
# Out:
#      p  i  q  P  D  Q      score
# 0    0  0  0  0  0  0 -14.326693
# 27   0  0  1  0  0  0 -13.866004
# 54   0  0  2  0  0  0 -13.684330
# 186  0  2  0  2  2  0  -9.402672
# 28   0  0  1  0  0  1  -9.333339
# ..  .. .. .. .. .. ..        ...
# 652  2  2  0  0  1  1  -0.096071
# 661  2  2  0  1  1  1  -0.042687
# 725  2  2  2  2  1  2  -0.034976
# 653  2  2  0  0  1  2   0.013659
# 670  2  2  0  2  1  1   0.098640
#
# [729 rows x 7 columns]

# %%
# Fitting a SARIMAX model with our best model 
# order=(2,0,1), seasonal_order=(1,2,1,10)

import random
random.seed(12345)
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

y_train=npfmcrfbk_end_month_df['close_price'][:-10]
y_test=npfmcrfbk_end_month_df['close_price'][-10:]

# scaler=StandardScaler()
# exog_train_scaled=scaler.fit_transform(X_full[:-10])
# exog_test_scaled=scaler.transform(X_full[-10:])

mod = SARIMAX(
y_train,
order=(2,2,0), 
seasonal_order=(2,1,1,12),
)

res = mod.fit(disp=False)
fcst = res.forecast(steps=10)

plt.plot(list(y_test))
plt.plot(list(fcst))
plt.xlabel('Steps of the test data')
plt.ylabel('Monthly close price')
plt.legend(['test', 'forecast'])
plt.show()
print('r2_score: ',r2_score(y_test, fcst))
print('rmse: ', np.sqrt(mean_squared_error(y_test,fcst)))
print('description: ', npfmcrfbk_end_month_df.close_price.describe())
# Out:
# r2_score:  0.09863972991036285
# rmse:  1.2315660684228988
# description:  count    115.000000
# mean       1.942348
# std        1.064248
# min        0.950000
# 25%        1.450000
# 50%        1.700000
# 75%        1.910000
# max        6.740000
# Name: close_price, dtype: float64

# %% [markdown]
# Its not capturing the variations properly. Lets try the returns

# %%
import random
random.seed(12345)

from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

train=npfmcrfbk_end_month_df['returns'].dropna()[:-10]
test=npfmcrfbk_end_month_df['returns'].dropna()[-10:]

# Grid Search on the SARIMA model
import numpy as np
scores = []
for p in range(3):
    for i in range(3):
        for q in range(3):
            for P in range(3):
                for D in range(3):
                    for Q in range(3):
                        try:
                            mod = SARIMAX(train, 
                            order=(p,i,q), seasonal_order=(P,D,Q,12))
                            res = mod.fit(disp=False)
                            fcst=res.forecast(steps=10)
                            score =  [p,i,q,P,D,Q,r2_score(test,fcst)]
                            print(score)
                            scores.append(score)
                            del mod
                            del res
                        except:
                            print('errored')
# Out:
# [0, 0, 0, 0, 0, 0, -0.10597708655176152]
# [0, 0, 0, 0, 0, 1, -0.12697570522054136]
# [0, 0, 0, 0, 0, 2, -0.13682949892761287]
# [0, 0, 0, 0, 1, 0, -0.14479477263704643]
# [0, 0, 0, 0, 1, 1, 0.188564051648358]
# [0, 0, 0, 0, 1, 2, 0.16372123993903342]
# [0, 0, 0, 0, 2, 0, -0.9502557686637838]
# [0, 0, 0, 0, 2, 1, -0.3754576899895212]
# [0, 0, 0, 0, 2, 2, -0.10011669118727862]
# [0, 0, 0, 1, 0, 0, -0.12952356126243703]
# [0, 0, 0, 1, 0, 1, -0.13247748395042946]
# [0, 0, 0, 1, 0, 2, 0.02537246450942532]
# [0, 0, 0, 1, 1, 0, -0.10245470403014889]
# [0, 0, 0, 1, 1, 1, 0.16474768966230524]
# [0, 0, 0, 1, 1, 2, 0.16955342838630982]
# [0, 0, 0, 1, 2, 0, -0.6463522310609722]
# [0, 0, 0, 1, 2, 1, -0.3003504821754137]
# [0, 0, 0, 1, 2, 2, -0.09853632354354613]
# [0, 0, 0, 2, 0, 0, -0.13578487681462503]
# [0, 0, 0, 2, 0, 1, 0.0050359184238765176]
# [0, 0, 0, 2, 0, 2, 0.006108230820396465]
# [0, 0, 0, 2, 1, 0, -0.02353284001169631]
# [0, 0, 0, 2, 1, 1, 0.19798461891614394]
# ...

# %%
res = pd.DataFrame(scores)
res.columns = ['p', 'i', 'q', 'P', 'D', 'Q', 'score']
result = res.sort_values('score')
result
# Out:
#      p  i  q  P  D  Q      score
# 429  1  2  0  2  2  0 -57.824607
# 417  1  2  0  1  1  0 -45.705412
# 421  1  2  0  1  2  1 -40.970089
# 426  1  2  0  2  1  0 -40.364919
# 420  1  2  0  1  2  0 -39.954856
# ..  .. .. .. .. .. ..        ...
# 473  1  2  2  1  1  2   0.229770
# 157  0  1  2  2  1  1   0.239332
# 346  1  1  0  2  1  1   0.246054
# 454  1  2  1  2  1  1   0.247427
# 481  1  2  2  2  1  1   0.259765
#
# [729 rows x 7 columns]

# %%
# Fitting a SARIMAX model with our best model 
# order=(2,0,1), seasonal_order=(1,2,1,10)

import random
random.seed(12345)
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

y_train=npfmcrfbk_end_month_df['returns'].dropna()[:-10]
y_test=npfmcrfbk_end_month_df['returns'].dropna()[-10:]

# scaler=StandardScaler()
# exog_train_scaled=scaler.fit_transform(X_full[:-10])
# exog_test_scaled=scaler.transform(X_full[-10:])

mod = SARIMAX(
y_train,
order=(1,2,2), 
seasonal_order=(2,1,1,12),
)

res = mod.fit(disp=False)
fcst = res.forecast(steps=10)

plt.plot(list(y_test))
plt.plot(list(fcst))
plt.xlabel('Steps of the test data')
plt.ylabel('Monthly close price')
plt.legend(['test', 'forecast'])
plt.show()
print('r2_score: ',r2_score(y_test, fcst))
print('rmse: ', np.sqrt(mean_squared_error(y_test,fcst)))
print('description: ', npfmcrfbk_end_month_df.returns.dropna().describe())
# Out:
# r2_score:  0.25976520596249797
# rmse:  19.61060795394565
# description:  count    114.000000
# mean       2.195552
# std       13.926530
# min      -30.939227
# 25%       -5.826859
# 50%        0.543880
# 75%        7.983307
# max       59.029650
# Name: returns, dtype: float64

# %% [markdown]
# Very horrible. We will work with it.

# %% [markdown]
# ## TRAINING AND TESTING
#
# We will do all training and testing here.

# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import os
import datetime as dt

# %%
import pandas as pd

finance_sector_df=pd.read_csv('feature_engineering/stocks_sectors/financial_services/financial_services_sector')

# %%
finance_sector_df.head()
# Out:
#          date              sector  weighted_sector_returns  \
# 0  2017-01-03  financial_services                 0.000000
# 1  2017-01-04  financial_services                 0.353432
# 2  2017-01-05  financial_services                -0.182223
# 3  2017-01-06  financial_services                 1.397196
# 4  2017-01-09  financial_services                 3.645896
#
#    n_stocks_contributing  sector_index  sector_volume
# 0                   20.0    100.000000     48125518.0
# 1                   20.0    100.353432     26705191.0
# 2                   20.0    100.170565     66991076.0
# 3                   20.0    101.570144     97521276.0
# 4                   20.0    105.273286     99013315.0

# %%
finance_sector_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     2263 non-null   str
#  1   sector                   2263 non-null   str
#  2   weighted_sector_returns  2263 non-null   float64
#  3   n_stocks_contributing    2263 non-null   float64
#  4   sector_index             2263 non-null   float64
#  5   sector_volume            2263 non-null   float64
# dtypes: float64(4), str(2)
# memory usage: 106.2 KB

# %%
finance_sector_df['date']=pd.to_datetime(finance_sector_df['date'], format='%Y-%m-%d', errors='coerce')

# %%
finance_sector_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     2263 non-null   datetime64[us]
#  1   sector                   2263 non-null   str
#  2   weighted_sector_returns  2263 non-null   float64
#  3   n_stocks_contributing    2263 non-null   float64
#  4   sector_index             2263 non-null   float64
#  5   sector_volume            2263 non-null   float64
# dtypes: datetime64[us](1), float64(4), str(1)
# memory usage: 106.2 KB

# %%
macro_eco_data=pd.read_csv('macroeconomic_data/populated_cleaned_macro_data')

# %%
macro_eco_data.head()
# Out:
#   Quarter  Month        Date  consumer_price_index(CPI)_monthly  \
# 0      Q2  April  2017-04-03                          204.45661
# 1      Q2  April  2017-04-04                          204.45661
# 2      Q2  April  2017-04-05                          204.45661
# 3      Q2  April  2017-04-06                          204.45661
# 4      Q2  April  2017-04-07                          204.45661
#
#    Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                    52.13                          1.6
# 1                    52.13                          1.6
# 2                    52.13                          1.6
# 3                    52.13                          1.6
# 4                    52.13                          1.6
#
#    Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                      1.15                              17.32
# 1                      1.15                              17.32
# 2                      1.15                              17.32
# 3                      1.15                              17.32
# 4                      1.15                              17.32
#
#    Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0               22304267.84                       1983633.07  ...
# 1               22304267.84                       1983633.07  ...
# 2               22304267.84                       1983633.07  ...
# 3               22304267.84                       1983633.07  ...
# 4               22304267.84                       1983633.07  ...
#
#    gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                           1237.68                               26028.36
# 1                           1237.68                               26028.36
# 2                           1237.68                               26028.36
# 3                           1237.68                               26028.36
# 4                           1237.68                               26028.36
#
#    Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                            200.5                                26228.85
# 1                            200.5                                26228.85
# 2                            200.5                                26228.85
# 3                            200.5                                26228.85
# 4                            200.5                                26228.85
#
#    foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 0                        3.029795e+10                         2.962647e+10
# 1                        3.029795e+10                         2.962647e+10
# 2                        3.029795e+10                         2.962647e+10
# 3                        3.029795e+10                         2.962647e+10
# 4                        3.029795e+10                         2.962647e+10
#
#    Year  Month_idx  foreign_reserve_gross(USD)_daily  \
# 0  2017          4                      3.030715e+10
# 1  2017          4                      3.031831e+10
# 2  2017          4                      3.032576e+10
# 3  2017          4                      3.034555e+10
# 4  2017          4                      3.036654e+10
#
#    foreign_reserve_liquid(USD)_daily
# 0                       2.963927e+10
# 1                       2.965163e+10
# 2                       2.966022e+10
# 3                       2.968121e+10
# 4                       2.970295e+10
#
# [5 rows x 84 columns]

# %%
macro_eco_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2257 entries, 0 to 2256
# Data columns (total 84 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Quarter                                                                     2257 non-null   str
#  1   Month                                                                       2257 non-null   str
#  2   Date                                                                        2257 non-null   str
#  3   consumer_price_index(CPI)_monthly                                           2257 non-null   float64
#  4   Crude Oil Price_monthly                                                     2257 non-null   float64
#  5   Domestic Production_monthly                                                 2257 non-null   float64
#  6   Crude Oil Export_monthly                                                    2257 non-null   float64
#  7   Inflation_allItemsAverage_monthly                                           2257 non-null   float64
#  8   Money Supply(M2)_monthly                                                    2257 non-null   float64
#  9   currency in circulation_monthly                                             2257 non-null   float64
#  10  bank reserves_monthly                                                       2257 non-null   float64
#  11  netForeignAssets_monthly                                                    2257 non-null   float64
#  12  netDomesticAssets_monthly                                                   2257 non-null   float64
#  13  netDomesticCredit_monthly                                                   2257 non-null   float64
#  14  creditToGovernment_monthly                                                  2257 non-null   float64
#  15  creditToPrivateSector_monthly                                               2257 non-null   float64
#  16  MonetaryPolicyRate_monthly                                                  2257 non-null   float64
#  17  TreasuryBillRate_monthly                                                    2257 non-null   float64
#  18  Lending_Rate_monthly                                                        2257 non-null   float64
#  19  Exchange_Rate(USD-EOP)_monthly                                              2257 non-null   float64
#  20  Premium_Motor_Spirit(PMS)_monthly                                           2257 non-null   float64
#  21  A. GDP_AGRICULTURE(agric)_quarterly                                         2257 non-null   float64
#  22  gdp_agric_Crop Production_quarterly                                         2257 non-null   float64
#  23  gdp_agric_Livestock_quarterly                                               2257 non-null   float64
#  24  gdp_agric_Forestry_quarterly                                                2257 non-null   float64
#  25   gdp_Fishing_quarterly                                                      2257 non-null   float64
#  26  GDP_INDUSTRY(ind)_quarterly                                                 2257 non-null   float64
#  27  gdp_ind_Mining and Quarrying(MQ)_quarterly                                  2257 non-null   float64
#  28  gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly                        2257 non-null   float64
#  29  gdp_ind_MQ_Coal Mining_quarterly                                            2257 non-null   float64
#  30  gdp_ind_MQ_Metal Ores_quarterly                                             2257 non-null   float64
#  31  gdp_ind_MQ_Quarrying and Other Minerals_quarterly                           2257 non-null   float64
#  32  gdp_ind_Manufacturing(mfg)_quarterly                                        2257 non-null   float64
#  33   gdp_ind_mfg_Oil Refining_quarterly                                         2257 non-null   float64
#  34  gdp_ind_mfg_Cement_quarterly                                                2257 non-null   float64
#  35  gdp_ind_mfg_Food, Beverage and Tobacco_quarterly                            2257 non-null   float64
#  36  gdp_ind_mfg_Textile, Apparel and Footwear_quarterly                         2257 non-null   float64
#  37  gdp_ind_mfg_Wood and Wood Products_quarterly                                2257 non-null   float64
#  38  gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly                        2257 non-null   float64
#  39  gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly                  2257 non-null   float64
#  40  gdp_ind_mfg_Non-Metallic Products_quarterly                                 2257 non-null   float64
#  41  gdp_ind_mfg_Plastic and Rubber Products_quarterly                           2257 non-null   float64
#  42  gdp_ind_mfg_Electrical and Electronics_quarterly                            2257 non-null   float64
#  43  gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly                           2257 non-null   float64
#  44  gdp_ind_mfg_Motor Vehicles and Assembly_quarterly                           2257 non-null   float64
#  45  gdp_ind_mfg_Other Manufacturing_quarterly                                   2257 non-null   float64
#  46  gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly                 2257 non-null   float64
#  47  gdp_ind_Water supply, Sewage, Waste Management_quarterly                    2257 non-null   float64
#  48  gdp_ind_Construction_quarterly                                              2257 non-null   float64
#  49  GDP_SERVICES(svc)_quarterly                                                 2257 non-null   float64
#  50  gdp_svc_Trade_quarterly                                                     2257 non-null   float64
#  51  gdp_svc_Accommodation and Food Services_quarterly                           2257 non-null   float64
#  52  gdp_svc_Transportation and Storage(TS)_quarterly                            2257 non-null   float64
#  53  gdp_svc_TS_RoadTransport_quarterly                                          2257 non-null   float64
#  54  gdp_svc_TS_Rail Transport & Pipelines_quarterly                             2257 non-null   float64
#  55  gdp_svc_TS_Water Transport_quarterly                                        2257 non-null   float64
#  56  gdp_svc_TS_Air Transport_quarterly                                          2257 non-null   float64
#  57  gdp_svc_TS_Transport Services_quarterly                                     2257 non-null   float64
#  58  gdp_svc_TS_Post and Courier Services_quarterly                              2257 non-null   float64
#  59  gdp_svc_Information and Communication(IC)_quarterly                         2257 non-null   float64
#  60  gdp_svc_IC_Telecommunications and Information Services_quarterly            2257 non-null   float64
#  61  gdp_svc_IC_Publishing_quarterly                                             2257 non-null   float64
#  62  gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly  2257 non-null   float64
#  63  gdp_svc_IC_Broadcasting_quarterly                                           2257 non-null   float64
#  64  gdp_svc_Arts, Entertainment & Recreation_quarterly                          2257 non-null   float64
#  65  gdp_svc_Financial and Insurance(FI)_quarterly                               2257 non-null   float64
#  66  gdp_svc_FI_Financial Institutions_quarterly                                 2257 non-null   float64
#  67  gdp_svc_FI_Insurance_quarterly                                              2257 non-null   float64
#  68  gdp_svc_Real Estate_quarterly                                               2257 non-null   float64
#  69  gdp_svc_Professional, Scientific & Technical Services_quarterly             2257 non-null   float64
#  70  gdp_svc_Administrative and Support Services_quarterly                       2257 non-null   float64
#  71  gdp_svc_Public Administration_quarterly                                     2257 non-null   float64
#  72  gdp_svc_Education_quarterly                                                 2257 non-null   float64
#  73  gdp_svc_Human Health & Social Services_quarterly                            2257 non-null   float64
#  74  gdp_svc_Other Services_quarterly                                            2257 non-null   float64
#  75  GDP at Current Basic Prices_quarterly                                       2257 non-null   float64
#  76  Net Taxes on Products_quarterly                                             2257 non-null   float64
#  77  GDP at Current Market Prices_quarterly                                      2257 non-null   float64
#  78  foreign_reserve_Gross(USD)_monthly                                          2257 non-null   float64
#  79  foreign_reserve_Liquid(USD)_monthly                                         2257 non-null   float64
#  80  Year                                                                        2257 non-null   int64
#  81  Month_idx                                                                   2257 non-null   int64
#  82  foreign_reserve_gross(USD)_daily                                            2257 non-null   float64
#  83  foreign_reserve_liquid(USD)_daily                                           2257 non-null   float64
# dtypes: float64(79), int64(2), str(3)
# memory usage: 1.4 MB

# %%
macro_eco_data['Date']=pd.to_datetime(macro_eco_data['Date'], format='%Y-%m-%d', errors="coerce")

# %%
macro_eco_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2257 entries, 0 to 2256
# Data columns (total 84 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Quarter                                                                     2257 non-null   str
#  1   Month                                                                       2257 non-null   str
#  2   Date                                                                        2257 non-null   datetime64[us]
#  3   consumer_price_index(CPI)_monthly                                           2257 non-null   float64
#  4   Crude Oil Price_monthly                                                     2257 non-null   float64
#  5   Domestic Production_monthly                                                 2257 non-null   float64
#  6   Crude Oil Export_monthly                                                    2257 non-null   float64
#  7   Inflation_allItemsAverage_monthly                                           2257 non-null   float64
#  8   Money Supply(M2)_monthly                                                    2257 non-null   float64
#  9   currency in circulation_monthly                                             2257 non-null   float64
#  10  bank reserves_monthly                                                       2257 non-null   float64
#  11  netForeignAssets_monthly                                                    2257 non-null   float64
#  12  netDomesticAssets_monthly                                                   2257 non-null   float64
#  13  netDomesticCredit_monthly                                                   2257 non-null   float64
#  14  creditToGovernment_monthly                                                  2257 non-null   float64
#  15  creditToPrivateSector_monthly                                               2257 non-null   float64
#  16  MonetaryPolicyRate_monthly                                                  2257 non-null   float64
#  17  TreasuryBillRate_monthly                                                    2257 non-null   float64
#  18  Lending_Rate_monthly                                                        2257 non-null   float64
#  19  Exchange_Rate(USD-EOP)_monthly                                              2257 non-null   float64
#  20  Premium_Motor_Spirit(PMS)_monthly                                           2257 non-null   float64
#  21  A. GDP_AGRICULTURE(agric)_quarterly                                         2257 non-null   float64
#  22  gdp_agric_Crop Production_quarterly                                         2257 non-null   float64
#  23  gdp_agric_Livestock_quarterly                                               2257 non-null   float64
#  24  gdp_agric_Forestry_quarterly                                                2257 non-null   float64
#  25   gdp_Fishing_quarterly                                                      2257 non-null   float64
#  26  GDP_INDUSTRY(ind)_quarterly                                                 2257 non-null   float64
#  27  gdp_ind_Mining and Quarrying(MQ)_quarterly                                  2257 non-null   float64
#  28  gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly                        2257 non-null   float64
#  29  gdp_ind_MQ_Coal Mining_quarterly                                            2257 non-null   float64
#  30  gdp_ind_MQ_Metal Ores_quarterly                                             2257 non-null   float64
#  31  gdp_ind_MQ_Quarrying and Other Minerals_quarterly                           2257 non-null   float64
#  32  gdp_ind_Manufacturing(mfg)_quarterly                                        2257 non-null   float64
#  33   gdp_ind_mfg_Oil Refining_quarterly                                         2257 non-null   float64
#  34  gdp_ind_mfg_Cement_quarterly                                                2257 non-null   float64
#  35  gdp_ind_mfg_Food, Beverage and Tobacco_quarterly                            2257 non-null   float64
#  36  gdp_ind_mfg_Textile, Apparel and Footwear_quarterly                         2257 non-null   float64
#  37  gdp_ind_mfg_Wood and Wood Products_quarterly                                2257 non-null   float64
#  38  gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly                        2257 non-null   float64
#  39  gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly                  2257 non-null   float64
#  40  gdp_ind_mfg_Non-Metallic Products_quarterly                                 2257 non-null   float64
#  41  gdp_ind_mfg_Plastic and Rubber Products_quarterly                           2257 non-null   float64
#  42  gdp_ind_mfg_Electrical and Electronics_quarterly                            2257 non-null   float64
#  43  gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly                           2257 non-null   float64
#  44  gdp_ind_mfg_Motor Vehicles and Assembly_quarterly                           2257 non-null   float64
#  45  gdp_ind_mfg_Other Manufacturing_quarterly                                   2257 non-null   float64
#  46  gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly                 2257 non-null   float64
#  47  gdp_ind_Water supply, Sewage, Waste Management_quarterly                    2257 non-null   float64
#  48  gdp_ind_Construction_quarterly                                              2257 non-null   float64
#  49  GDP_SERVICES(svc)_quarterly                                                 2257 non-null   float64
#  50  gdp_svc_Trade_quarterly                                                     2257 non-null   float64
#  51  gdp_svc_Accommodation and Food Services_quarterly                           2257 non-null   float64
#  52  gdp_svc_Transportation and Storage(TS)_quarterly                            2257 non-null   float64
#  53  gdp_svc_TS_RoadTransport_quarterly                                          2257 non-null   float64
#  54  gdp_svc_TS_Rail Transport & Pipelines_quarterly                             2257 non-null   float64
#  55  gdp_svc_TS_Water Transport_quarterly                                        2257 non-null   float64
#  56  gdp_svc_TS_Air Transport_quarterly                                          2257 non-null   float64
#  57  gdp_svc_TS_Transport Services_quarterly                                     2257 non-null   float64
#  58  gdp_svc_TS_Post and Courier Services_quarterly                              2257 non-null   float64
#  59  gdp_svc_Information and Communication(IC)_quarterly                         2257 non-null   float64
#  60  gdp_svc_IC_Telecommunications and Information Services_quarterly            2257 non-null   float64
#  61  gdp_svc_IC_Publishing_quarterly                                             2257 non-null   float64
#  62  gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly  2257 non-null   float64
#  63  gdp_svc_IC_Broadcasting_quarterly                                           2257 non-null   float64
#  64  gdp_svc_Arts, Entertainment & Recreation_quarterly                          2257 non-null   float64
#  65  gdp_svc_Financial and Insurance(FI)_quarterly                               2257 non-null   float64
#  66  gdp_svc_FI_Financial Institutions_quarterly                                 2257 non-null   float64
#  67  gdp_svc_FI_Insurance_quarterly                                              2257 non-null   float64
#  68  gdp_svc_Real Estate_quarterly                                               2257 non-null   float64
#  69  gdp_svc_Professional, Scientific & Technical Services_quarterly             2257 non-null   float64
#  70  gdp_svc_Administrative and Support Services_quarterly                       2257 non-null   float64
#  71  gdp_svc_Public Administration_quarterly                                     2257 non-null   float64
#  72  gdp_svc_Education_quarterly                                                 2257 non-null   float64
#  73  gdp_svc_Human Health & Social Services_quarterly                            2257 non-null   float64
#  74  gdp_svc_Other Services_quarterly                                            2257 non-null   float64
#  75  GDP at Current Basic Prices_quarterly                                       2257 non-null   float64
#  76  Net Taxes on Products_quarterly                                             2257 non-null   float64
#  77  GDP at Current Market Prices_quarterly                                      2257 non-null   float64
#  78  foreign_reserve_Gross(USD)_monthly                                          2257 non-null   float64
#  79  foreign_reserve_Liquid(USD)_monthly                                         2257 non-null   float64
#  80  Year                                                                        2257 non-null   int64
#  81  Month_idx                                                                   2257 non-null   int64
#  82  foreign_reserve_gross(USD)_daily                                            2257 non-null   float64
#  83  foreign_reserve_liquid(USD)_daily                                           2257 non-null   float64
# dtypes: datetime64[us](1), float64(79), int64(2), str(2)
# memory usage: 1.4 MB

# %%
macro_eco_data = macro_eco_data.rename(columns={"Date": "date"})

# %%
macro_eco_data.head()
# Out:
#   Quarter  Month       date  consumer_price_index(CPI)_monthly  \
# 0      Q2  April 2017-04-03                          204.45661
# 1      Q2  April 2017-04-04                          204.45661
# 2      Q2  April 2017-04-05                          204.45661
# 3      Q2  April 2017-04-06                          204.45661
# 4      Q2  April 2017-04-07                          204.45661
#
#    Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                    52.13                          1.6
# 1                    52.13                          1.6
# 2                    52.13                          1.6
# 3                    52.13                          1.6
# 4                    52.13                          1.6
#
#    Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                      1.15                              17.32
# 1                      1.15                              17.32
# 2                      1.15                              17.32
# 3                      1.15                              17.32
# 4                      1.15                              17.32
#
#    Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0               22304267.84                       1983633.07  ...
# 1               22304267.84                       1983633.07  ...
# 2               22304267.84                       1983633.07  ...
# 3               22304267.84                       1983633.07  ...
# 4               22304267.84                       1983633.07  ...
#
#    gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                           1237.68                               26028.36
# 1                           1237.68                               26028.36
# 2                           1237.68                               26028.36
# 3                           1237.68                               26028.36
# 4                           1237.68                               26028.36
#
#    Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                            200.5                                26228.85
# 1                            200.5                                26228.85
# 2                            200.5                                26228.85
# 3                            200.5                                26228.85
# 4                            200.5                                26228.85
#
#    foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 0                        3.029795e+10                         2.962647e+10
# 1                        3.029795e+10                         2.962647e+10
# 2                        3.029795e+10                         2.962647e+10
# 3                        3.029795e+10                         2.962647e+10
# 4                        3.029795e+10                         2.962647e+10
#
#    Year  Month_idx  foreign_reserve_gross(USD)_daily  \
# 0  2017          4                      3.030715e+10
# 1  2017          4                      3.031831e+10
# 2  2017          4                      3.032576e+10
# 3  2017          4                      3.034555e+10
# 4  2017          4                      3.036654e+10
#
#    foreign_reserve_liquid(USD)_daily
# 0                       2.963927e+10
# 1                       2.965163e+10
# 2                       2.966022e+10
# 3                       2.968121e+10
# 4                       2.970295e+10
#
# [5 rows x 84 columns]

# %% [markdown]
# LET US WORK WITHOUT ANY LAGGING AT FIRST

# %%
## Lets merge the data 

finance_sector_ME_df = finance_sector_df.merge(
    macro_eco_data,
    on="date",
    how="left"
)

# %%
finance_sector_ME_df
# Out:
#            date              sector  weighted_sector_returns  \
# 0    2017-01-03  financial_services                 0.000000
# 1    2017-01-04  financial_services                 0.353432
# 2    2017-01-05  financial_services                -0.182223
# 3    2017-01-06  financial_services                 1.397196
# 4    2017-01-09  financial_services                 3.645896
# ...         ...                 ...                      ...
# 2286 2026-07-13  financial_services                -0.746327
# 2287 2026-07-14  financial_services                 0.906947
# 2288 2026-07-15  financial_services                 0.779799
# 2289 2026-07-16  financial_services                 1.505893
# 2290 2026-07-17  financial_services                 1.536021
#
#       n_stocks_contributing  sector_index  sector_volume Quarter Month  \
# 0                      20.0    100.000000     48125518.0     NaN   NaN
# 1                      20.0    100.353432     26705191.0     NaN   NaN
# 2                      20.0    100.170565     66991076.0     NaN   NaN
# 3                      20.0    101.570144     97521276.0     NaN   NaN
# 4                      20.0    105.273286     99013315.0     NaN   NaN
# ...                     ...           ...            ...     ...   ...
# 2286                   35.0   2695.019313    290562049.0     NaN   NaN
# 2287                   35.0   2719.461701    163509442.0     NaN   NaN
# 2288                   35.0   2740.668037    258362267.0     NaN   NaN
# 2289                   35.0   2781.939574    261040578.0     NaN   NaN
# 2290                   35.0   2824.670764    295044834.0     NaN   NaN
#
#       consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  ...  \
# 0                                   NaN                      NaN  ...
# 1                                   NaN                      NaN  ...
# 2                                   NaN                      NaN  ...
# 3                                   NaN                      NaN  ...
# 4                                   NaN                      NaN  ...
# ...                                 ...                      ...  ...
# 2286                                NaN                      NaN  ...
# 2287                                NaN                      NaN  ...
# 2288                                NaN                      NaN  ...
# 2289                                NaN                      NaN  ...
# 2290                                NaN                      NaN  ...
#
#       gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
# ...                                ...                                    ...
# 2286                               NaN                                    NaN
# 2287                               NaN                                    NaN
# 2288                               NaN                                    NaN
# 2289                               NaN                                    NaN
# 2290                               NaN                                    NaN
#
#       Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
# ...                               ...                                     ...
# 2286                              NaN                                     NaN
# 2287                              NaN                                     NaN
# 2288                              NaN                                     NaN
# 2289                              NaN                                     NaN
# 2290                              NaN                                     NaN
#
#       foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 2286                                 NaN                                  NaN
# 2287                                 NaN                                  NaN
# 2288                                 NaN                                  NaN
# 2289                                 NaN                                  NaN
# 2290                                 NaN                                  NaN
#
#       Year  Month_idx  foreign_reserve_gross(USD)_daily  \
# 0      NaN        NaN                               NaN
# 1      NaN        NaN                               NaN
# 2      NaN        NaN                               NaN
# 3      NaN        NaN                               NaN
# 4      NaN        NaN                               NaN
# ...    ...        ...                               ...
# 2286   NaN        NaN                               NaN
# 2287   NaN        NaN                               NaN
# 2288   NaN        NaN                               NaN
# 2289   NaN        NaN                               NaN
# 2290   NaN        NaN                               NaN
#
#       foreign_reserve_liquid(USD)_daily
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2286                                NaN
# 2287                                NaN
# 2288                                NaN
# 2289                                NaN
# 2290                                NaN
#
# [2291 rows x 89 columns]

# %%
finance_sector_ME_df.dropna(inplace=True)

# %%
finance_sector_ME_df.head()
# Out:
#          date              sector  weighted_sector_returns  \
# 64 2017-04-03  financial_services                -0.403579
# 65 2017-04-04  financial_services                -0.295235
# 66 2017-04-05  financial_services                 0.584640
# 67 2017-04-06  financial_services                -0.282732
# 68 2017-04-07  financial_services                 0.624710
#
#     n_stocks_contributing  sector_index  sector_volume Quarter  Month  \
# 64                   21.0    105.031248     51906903.0      Q2  April
# 65                   21.0    104.721159     45091739.0      Q2  April
# 66                   21.0    105.333401     96410309.0      Q2  April
# 67                   21.0    105.035590    101585127.0      Q2  April
# 68                   21.0    105.691757     51494340.0      Q2  April
#
#     consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  ...  \
# 64                          204.45661                    52.13  ...
# 65                          204.45661                    52.13  ...
# 66                          204.45661                    52.13  ...
# 67                          204.45661                    52.13  ...
# 68                          204.45661                    52.13  ...
#
#     gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 64                           1237.68                               26028.36
# 65                           1237.68                               26028.36
# 66                           1237.68                               26028.36
# 67                           1237.68                               26028.36
# 68                           1237.68                               26028.36
#
#     Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 64                            200.5                                26228.85
# 65                            200.5                                26228.85
# 66                            200.5                                26228.85
# 67                            200.5                                26228.85
# 68                            200.5                                26228.85
#
#     foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 64                        3.029795e+10                         2.962647e+10
# 65                        3.029795e+10                         2.962647e+10
# 66                        3.029795e+10                         2.962647e+10
# 67                        3.029795e+10                         2.962647e+10
# 68                        3.029795e+10                         2.962647e+10
#
#       Year  Month_idx  foreign_reserve_gross(USD)_daily  \
# 64  2017.0        4.0                      3.030715e+10
# 65  2017.0        4.0                      3.031831e+10
# 66  2017.0        4.0                      3.032576e+10
# 67  2017.0        4.0                      3.034555e+10
# 68  2017.0        4.0                      3.036654e+10
#
#     foreign_reserve_liquid(USD)_daily
# 64                       2.963927e+10
# 65                       2.965163e+10
# 66                       2.966022e+10
# 67                       2.968121e+10
# 68                       2.970295e+10
#
# [5 rows x 89 columns]

# %%
finance_sector_ME_df.columns
# Out:
# Index(['date', 'sector', 'weighted_sector_returns', 'n_stocks_contributing',
#        'sector_index', 'sector_volume', 'Quarter', 'Month',
#        'consumer_price_index(CPI)_monthly', 'Crude Oil Price_monthly',
#        'Domestic Production_monthly', 'Crude Oil Export_monthly',
#        'Inflation_allItemsAverage_monthly', 'Money Supply(M2)_monthly',
#        'currency in circulation_monthly', 'bank reserves_monthly',
#        'netForeignAssets_monthly', 'netDomesticAssets_monthly',
#        'netDomesticCredit_monthly', 'creditToGovernment_monthly',
#        'creditToPrivateSector_monthly', 'MonetaryPolicyRate_monthly',
#        'TreasuryBillRate_monthly', 'Lending_Rate_monthly',
#        'Exchange_Rate(USD-EOP)_monthly', 'Premium_Motor_Spirit(PMS)_monthly',
#        'A. GDP_AGRICULTURE(agric)_quarterly',
#        'gdp_agric_Crop Production_quarterly', 'gdp_agric_Livestock_quarterly',
#        'gdp_agric_Forestry_quarterly', ' gdp_Fishing_quarterly',
#        'GDP_INDUSTRY(ind)_quarterly',
#        'gdp_ind_Mining and Quarrying(MQ)_quarterly',
#        'gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly',
#        'gdp_ind_MQ_Coal Mining_quarterly', 'gdp_ind_MQ_Metal Ores_quarterly',
#        'gdp_ind_MQ_Quarrying and Other Minerals_quarterly',
#        'gdp_ind_Manufacturing(mfg)_quarterly',
#        ' gdp_ind_mfg_Oil Refining_quarterly', 'gdp_ind_mfg_Cement_quarterly',
#        'gdp_ind_mfg_Food, Beverage and Tobacco_quarterly',
#        'gdp_ind_mfg_Textile, Apparel and Footwear_quarterly',
#        'gdp_ind_mfg_Wood and Wood Products_quarterly',
#        'gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly',
#        'gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly',
#        'gdp_ind_mfg_Non-Metallic Products_quarterly',
#        'gdp_ind_mfg_Plastic and Rubber Products_quarterly',
#        'gdp_ind_mfg_Electrical and Electronics_quarterly',
#        'gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly',
#        'gdp_ind_mfg_Motor Vehicles and Assembly_quarterly',
#        'gdp_ind_mfg_Other Manufacturing_quarterly',
#        'gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly',
#        'gdp_ind_Water supply, Sewage, Waste Management_quarterly',
#        'gdp_ind_Construction_quarterly', 'GDP_SERVICES(svc)_quarterly',
#        'gdp_svc_Trade_quarterly',
#        'gdp_svc_Accommodation and Food Services_quarterly',
#        'gdp_svc_Transportation and Storage(TS)_quarterly',
#        'gdp_svc_TS_RoadTransport_quarterly',
#        'gdp_svc_TS_Rail Transport & Pipelines_quarterly',
#        'gdp_svc_TS_Water Transport_quarterly',
#        'gdp_svc_TS_Air Transport_quarterly',
#        'gdp_svc_TS_Transport Services_quarterly',
#        'gdp_svc_TS_Post and Courier Services_quarterly',
#        'gdp_svc_Information and Communication(IC)_quarterly',
#        'gdp_svc_IC_Telecommunications and Information Services_quarterly',
#        'gdp_svc_IC_Publishing_quarterly',
#        'gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly',
#        'gdp_svc_IC_Broadcasting_quarterly',
#        'gdp_svc_Arts, Entertainment & Recreation_quarterly',
#        'gdp_svc_Financial and Insurance(FI)_quarterly',
#        'gdp_svc_FI_Financial Institutions_quarterly',
#        'gdp_svc_FI_Insurance_quarterly', 'gdp_svc_Real Estate_quarterly',
#        'gdp_svc_Professional, Scientific & Technical Services_quarterly',
#        'gdp_svc_Administrative and Support Services_quarterly',
#        'gdp_svc_Public Administration_quarterly',
#        'gdp_svc_Education_quarterly',
#        'gdp_svc_Human Health & Social Services_quarterly',
#        'gdp_svc_Other Services_quarterly',
#        'GDP at Current Basic Prices_quarterly',
#        'Net Taxes on Products_quarterly',
#        'GDP at Current Market Prices_quarterly',
#        'foreign_reserve_Gross(USD)_monthly',
#        'foreign_reserve_Liquid(USD)_monthly', 'Year', 'Month_idx',
#        'foreign_reserve_gross(USD)_daily',
#        'foreign_reserve_liquid(USD)_daily'],
#       dtype='str')

# %%
finance_sector_ME_df.rename(columns={'A. GDP_AGRICULTURE(agric)_quarterly':'GDP_AGRICULTURE(agric)_quarterly', ' gdp_ind_mfg_Oil Refining_quarterly':'gdp_ind_mfg_Oil Refining_quarterly'}, inplace=True)

# %%
finance_sec_num_df = finance_sector_ME_df.select_dtypes(include="number")

# %%
finance_sec_num_df.columns
# Out:
# Index(['weighted_sector_returns', 'n_stocks_contributing', 'sector_index',
#        'sector_volume', 'consumer_price_index(CPI)_monthly',
#        'Crude Oil Price_monthly', 'Domestic Production_monthly',
#        'Crude Oil Export_monthly', 'Inflation_allItemsAverage_monthly',
#        'Money Supply(M2)_monthly', 'currency in circulation_monthly',
#        'bank reserves_monthly', 'netForeignAssets_monthly',
#        'netDomesticAssets_monthly', 'netDomesticCredit_monthly',
#        'creditToGovernment_monthly', 'creditToPrivateSector_monthly',
#        'MonetaryPolicyRate_monthly', 'TreasuryBillRate_monthly',
#        'Lending_Rate_monthly', 'Exchange_Rate(USD-EOP)_monthly',
#        'Premium_Motor_Spirit(PMS)_monthly', 'GDP_AGRICULTURE(agric)_quarterly',
#        'gdp_agric_Crop Production_quarterly', 'gdp_agric_Livestock_quarterly',
#        'gdp_agric_Forestry_quarterly', ' gdp_Fishing_quarterly',
#        'GDP_INDUSTRY(ind)_quarterly',
#        'gdp_ind_Mining and Quarrying(MQ)_quarterly',
#        'gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly',
#        'gdp_ind_MQ_Coal Mining_quarterly', 'gdp_ind_MQ_Metal Ores_quarterly',
#        'gdp_ind_MQ_Quarrying and Other Minerals_quarterly',
#        'gdp_ind_Manufacturing(mfg)_quarterly',
#        'gdp_ind_mfg_Oil Refining_quarterly', 'gdp_ind_mfg_Cement_quarterly',
#        'gdp_ind_mfg_Food, Beverage and Tobacco_quarterly',
#        'gdp_ind_mfg_Textile, Apparel and Footwear_quarterly',
#        'gdp_ind_mfg_Wood and Wood Products_quarterly',
#        'gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly',
#        'gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly',
#        'gdp_ind_mfg_Non-Metallic Products_quarterly',
#        'gdp_ind_mfg_Plastic and Rubber Products_quarterly',
#        'gdp_ind_mfg_Electrical and Electronics_quarterly',
#        'gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly',
#        'gdp_ind_mfg_Motor Vehicles and Assembly_quarterly',
#        'gdp_ind_mfg_Other Manufacturing_quarterly',
#        'gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly',
#        'gdp_ind_Water supply, Sewage, Waste Management_quarterly',
#        'gdp_ind_Construction_quarterly', 'GDP_SERVICES(svc)_quarterly',
#        'gdp_svc_Trade_quarterly',
#        'gdp_svc_Accommodation and Food Services_quarterly',
#        'gdp_svc_Transportation and Storage(TS)_quarterly',
#        'gdp_svc_TS_RoadTransport_quarterly',
#        'gdp_svc_TS_Rail Transport & Pipelines_quarterly',
#        'gdp_svc_TS_Water Transport_quarterly',
#        'gdp_svc_TS_Air Transport_quarterly',
#        'gdp_svc_TS_Transport Services_quarterly',
#        'gdp_svc_TS_Post and Courier Services_quarterly',
#        'gdp_svc_Information and Communication(IC)_quarterly',
#        'gdp_svc_IC_Telecommunications and Information Services_quarterly',
#        'gdp_svc_IC_Publishing_quarterly',
#        'gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly',
#        'gdp_svc_IC_Broadcasting_quarterly',
#        'gdp_svc_Arts, Entertainment & Recreation_quarterly',
#        'gdp_svc_Financial and Insurance(FI)_quarterly',
#        'gdp_svc_FI_Financial Institutions_quarterly',
#        'gdp_svc_FI_Insurance_quarterly', 'gdp_svc_Real Estate_quarterly',
#        'gdp_svc_Professional, Scientific & Technical Services_quarterly',
#        'gdp_svc_Administrative and Support Services_quarterly',
#        'gdp_svc_Public Administration_quarterly',
#        'gdp_svc_Education_quarterly',
#        'gdp_svc_Human Health & Social Services_quarterly',
#        'gdp_svc_Other Services_quarterly',
#        'GDP at Current Basic Prices_quarterly',
#        'Net Taxes on Products_quarterly',
#        'GDP at Current Market Prices_quarterly',
#        'foreign_reserve_Gross(USD)_monthly',
#        'foreign_reserve_Liquid(USD)_monthly', 'Year', 'Month_idx',
#        'foreign_reserve_gross(USD)_daily',
#        'foreign_reserve_liquid(USD)_daily'],
#       dtype='str')

# %%
fin_sec_corr=finance_sec_num_df.corr()

# %%
fin_sec_corr
# Out:
#                                      weighted_sector_returns  \
# weighted_sector_returns                             1.000000
# n_stocks_contributing                               0.013134
# sector_index                                        0.036320
# sector_volume                                       0.078945
# consumer_price_index(CPI)_monthly                   0.036956
# ...                                                      ...
# foreign_reserve_Liquid(USD)_monthly                -0.063666
# Year                                                0.029180
# Month_idx                                           0.007373
# foreign_reserve_gross(USD)_daily                   -0.059885
# foreign_reserve_liquid(USD)_daily                  -0.061164
#
#                                      n_stocks_contributing  sector_index  \
# weighted_sector_returns                           0.013134      0.036320
# n_stocks_contributing                             1.000000      0.574562
# sector_index                                      0.574562      1.000000
# sector_volume                                     0.232719      0.399895
# consumer_price_index(CPI)_monthly                 0.775609      0.921058
# ...                                                    ...           ...
# foreign_reserve_Liquid(USD)_monthly               0.040849      0.322421
# Year                                              0.909361      0.794263
# Month_idx                                        -0.001014     -0.076155
# foreign_reserve_gross(USD)_daily                  0.057298      0.406158
# foreign_reserve_liquid(USD)_daily                 0.056909      0.402043
#
#                                      sector_volume  \
# weighted_sector_returns                   0.078945
# n_stocks_contributing                     0.232719
# sector_index                              0.399895
# sector_volume                             1.000000
# consumer_price_index(CPI)_monthly         0.389579
# ...                                            ...
# foreign_reserve_Liquid(USD)_monthly       0.058561
# Year                                      0.326554
# Month_idx                                -0.011213
# foreign_reserve_gross(USD)_daily          0.112582
# foreign_reserve_liquid(USD)_daily         0.110399
#
#                                      consumer_price_index(CPI)_monthly  \
# weighted_sector_returns                                       0.036956
# n_stocks_contributing                                         0.775609
# sector_index                                                  0.921058
# sector_volume                                                 0.389579
# consumer_price_index(CPI)_monthly                             1.000000
# ...                                                                ...
# foreign_reserve_Liquid(USD)_monthly                           0.134870
# Year                                                          0.939833
# Month_idx                                                    -0.028351
# foreign_reserve_gross(USD)_daily                              0.215572
# foreign_reserve_liquid(USD)_daily                             0.209259
#
#                                      Crude Oil Price_monthly  \
# weighted_sector_returns                            -0.040798
# n_stocks_contributing                               0.480108
# sector_index                                        0.298052
# sector_volume                                       0.061151
# consumer_price_index(CPI)_monthly                   0.376336
# ...                                                      ...
# foreign_reserve_Liquid(USD)_monthly                 0.255068
# Year                                                0.463800
# Month_idx                                          -0.001027
# foreign_reserve_gross(USD)_daily                    0.235058
# foreign_reserve_liquid(USD)_daily                   0.233212
#
#                                      Domestic Production_monthly  \
# weighted_sector_returns                                -0.030343
# n_stocks_contributing                                  -0.693658
# sector_index                                           -0.292877
# sector_volume                                          -0.109461
# consumer_price_index(CPI)_monthly                      -0.512520
# ...                                                          ...
# foreign_reserve_Liquid(USD)_monthly                     0.235269
# Year                                                   -0.690198
# Month_idx                                              -0.050502
# foreign_reserve_gross(USD)_daily                        0.221834
# foreign_reserve_liquid(USD)_daily                       0.213639
#
#                                      Crude Oil Export_monthly  \
# weighted_sector_returns                             -0.030343
# n_stocks_contributing                               -0.693658
# sector_index                                        -0.292877
# sector_volume                                       -0.109461
# consumer_price_index(CPI)_monthly                   -0.512520
# ...                                                       ...
# foreign_reserve_Liquid(USD)_monthly                  0.235269
# Year                                                -0.690198
# Month_idx                                           -0.050502
# foreign_reserve_gross(USD)_daily                     0.221834
# foreign_reserve_liquid(USD)_daily                    0.213639
#
#                                      Inflation_allItemsAverage_monthly  \
# weighted_sector_returns                                       0.057628
# n_stocks_contributing                                         0.521398
# sector_index                                                  0.516747
# sector_volume                                                 0.264222
# consumer_price_index(CPI)_monthly                             0.709324
# ...                                                                ...
# foreign_reserve_Liquid(USD)_monthly                          -0.258691
# Year                                                          0.665742
# Month_idx                                                     0.065195
# foreign_reserve_gross(USD)_daily                             -0.149984
# foreign_reserve_liquid(USD)_daily                            -0.163145
#
#                                      Money Supply(M2)_monthly  ...  \
# weighted_sector_returns                              0.037051  ...
# n_stocks_contributing                                0.758349  ...
# sector_index                                         0.901570  ...
# sector_volume                                        0.384258  ...
# consumer_price_index(CPI)_monthly                    0.993408  ...
# ...                                                       ...  ...
# foreign_reserve_Liquid(USD)_monthly                  0.104791  ...
# Year                                                 0.925565  ...
# Month_idx                                           -0.040498  ...
# foreign_reserve_gross(USD)_daily                     0.190632  ...
# foreign_reserve_liquid(USD)_daily                    0.183294  ...
#
#                                      gdp_svc_Other Services_quarterly  \
# weighted_sector_returns                                      0.019696
# n_stocks_contributing                                        0.385504
# sector_index                                                 0.606790
# sector_volume                                                0.244019
# consumer_price_index(CPI)_monthly                            0.574753
# ...                                                               ...
# foreign_reserve_Liquid(USD)_monthly                          0.289085
# Year                                                         0.574229
# Month_idx                                                   -0.621855
# foreign_reserve_gross(USD)_daily                             0.350613
# foreign_reserve_liquid(USD)_daily                            0.349043
#
#                                      GDP at Current Basic Prices_quarterly  \
# weighted_sector_returns                                           0.033253
# n_stocks_contributing                                             0.705498
# sector_index                                                      0.949877
# sector_volume                                                     0.397899
# consumer_price_index(CPI)_monthly                                 0.960515
# ...                                                                    ...
# foreign_reserve_Liquid(USD)_monthly                               0.251707
# Year                                                              0.885934
# Month_idx                                                        -0.075549
# foreign_reserve_gross(USD)_daily                                  0.331794
# foreign_reserve_liquid(USD)_daily                                 0.328711
#
#                                      Net Taxes on Products_quarterly  \
# weighted_sector_returns                                     0.026542
# n_stocks_contributing                                       0.167179
# sector_index                                                0.088525
# sector_volume                                               0.062896
# consumer_price_index(CPI)_monthly                           0.126560
# ...                                                              ...
# foreign_reserve_Liquid(USD)_monthly                        -0.164784
# Year                                                        0.173804
# Month_idx                                                  -0.198451
# foreign_reserve_gross(USD)_daily                           -0.146956
# foreign_reserve_liquid(USD)_daily                          -0.151083
#
#                                      GDP at Current Market Prices_quarterly  \
# weighted_sector_returns                                            0.033293
# n_stocks_contributing                                              0.705564
# sector_index                                                       0.949411
# sector_volume                                                      0.397814
# consumer_price_index(CPI)_monthly                                  0.961487
# ...                                                                     ...
# foreign_reserve_Liquid(USD)_monthly                                0.250469
# Year                                                               0.886334
# Month_idx                                                         -0.075114
# foreign_reserve_gross(USD)_daily                                   0.330780
# foreign_reserve_liquid(USD)_daily                                  0.327616
#
#                                      foreign_reserve_Gross(USD)_monthly  \
# weighted_sector_returns                                       -0.062380
# n_stocks_contributing                                          0.040983
# sector_index                                                   0.327477
# sector_volume                                                  0.062106
# consumer_price_index(CPI)_monthly                              0.142102
# ...                                                                 ...
# foreign_reserve_Liquid(USD)_monthly                            0.998800
# Year                                                           0.061955
# Month_idx                                                     -0.098474
# foreign_reserve_gross(USD)_daily                               0.971457
# foreign_reserve_liquid(USD)_daily                              0.970683
#
#                                      foreign_reserve_Liquid(USD)_monthly  \
# weighted_sector_returns                                        -0.063666
# n_stocks_contributing                                           0.040849
# sector_index                                                    0.322421
# sector_volume                                                   0.058561
# consumer_price_index(CPI)_monthly                               0.134870
# ...                                                                  ...
# foreign_reserve_Liquid(USD)_monthly                             1.000000
# Year                                                            0.059941
# Month_idx                                                      -0.096226
# foreign_reserve_gross(USD)_daily                                0.969719
# foreign_reserve_liquid(USD)_daily                               0.971192
#
#                                          Year  Month_idx  \
# weighted_sector_returns              0.029180   0.007373
# n_stocks_contributing                0.909361  -0.001014
# sector_index                         0.794263  -0.076155
# sector_volume                        0.326554  -0.011213
# consumer_price_index(CPI)_monthly    0.939833  -0.028351
# ...                                       ...        ...
# foreign_reserve_Liquid(USD)_monthly  0.059941  -0.096226
# Year                                 1.000000  -0.131171
# Month_idx                           -0.131171   1.000000
# foreign_reserve_gross(USD)_daily     0.111809  -0.074016
# foreign_reserve_liquid(USD)_daily    0.109941  -0.071864
#
#                                      foreign_reserve_gross(USD)_daily  \
# weighted_sector_returns                                     -0.059885
# n_stocks_contributing                                        0.057298
# sector_index                                                 0.406158
# sector_volume                                                0.112582
# consumer_price_index(CPI)_monthly                            0.215572
# ...                                                               ...
# foreign_reserve_Liquid(USD)_monthly                          0.969719
# Year                                                         0.111809
# Month_idx                                                   -0.074016
# foreign_reserve_gross(USD)_daily                             1.000000
# foreign_reserve_liquid(USD)_daily                            0.998873
#
#                                      foreign_reserve_liquid(USD)_daily
# weighted_sector_returns                                      -0.061164
# n_stocks_contributing                                         0.056909
# sector_index                                                  0.402043
# sector_volume                                                 0.110399
# consumer_price_index(CPI)_monthly                             0.209259
# ...                                                                ...
# foreign_reserve_Liquid(USD)_monthly                           0.971192
# Year                                                          0.109941
# Month_idx                                                    -0.071864
# foreign_reserve_gross(USD)_daily                              0.998873
# foreign_reserve_liquid(USD)_daily                             1.000000
#
# [85 rows x 85 columns]

# %%
sector_corr = fin_sec_corr['weighted_sector_returns']
# strong_corr = sector_corr[sector_corr.abs() >= 0.5]

sector_corr
# Out:
# weighted_sector_returns                1.000000
# n_stocks_contributing                  0.013134
# sector_index                           0.036320
# sector_volume                          0.078945
# consumer_price_index(CPI)_monthly      0.036956
#                                          ...
# foreign_reserve_Liquid(USD)_monthly   -0.063666
# Year                                   0.029180
# Month_idx                              0.007373
# foreign_reserve_gross(USD)_daily      -0.059885
# foreign_reserve_liquid(USD)_daily     -0.061164
# Name: weighted_sector_returns, Length: 85, dtype: float64

# %%
finance_sector_ME_df.columns
# Out:
# Index(['date', 'sector', 'weighted_sector_returns', 'n_stocks_contributing',
#        'sector_index', 'sector_volume', 'Quarter', 'Month',
#        'consumer_price_index(CPI)_monthly', 'Crude Oil Price_monthly',
#        'Domestic Production_monthly', 'Crude Oil Export_monthly',
#        'Inflation_allItemsAverage_monthly', 'Money Supply(M2)_monthly',
#        'currency in circulation_monthly', 'bank reserves_monthly',
#        'netForeignAssets_monthly', 'netDomesticAssets_monthly',
#        'netDomesticCredit_monthly', 'creditToGovernment_monthly',
#        'creditToPrivateSector_monthly', 'MonetaryPolicyRate_monthly',
#        'TreasuryBillRate_monthly', 'Lending_Rate_monthly',
#        'Exchange_Rate(USD-EOP)_monthly', 'Premium_Motor_Spirit(PMS)_monthly',
#        'GDP_AGRICULTURE(agric)_quarterly',
#        'gdp_agric_Crop Production_quarterly', 'gdp_agric_Livestock_quarterly',
#        'gdp_agric_Forestry_quarterly', ' gdp_Fishing_quarterly',
#        'GDP_INDUSTRY(ind)_quarterly',
#        'gdp_ind_Mining and Quarrying(MQ)_quarterly',
#        'gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly',
#        'gdp_ind_MQ_Coal Mining_quarterly', 'gdp_ind_MQ_Metal Ores_quarterly',
#        'gdp_ind_MQ_Quarrying and Other Minerals_quarterly',
#        'gdp_ind_Manufacturing(mfg)_quarterly',
#        'gdp_ind_mfg_Oil Refining_quarterly', 'gdp_ind_mfg_Cement_quarterly',
#        'gdp_ind_mfg_Food, Beverage and Tobacco_quarterly',
#        'gdp_ind_mfg_Textile, Apparel and Footwear_quarterly',
#        'gdp_ind_mfg_Wood and Wood Products_quarterly',
#        'gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly',
#        'gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly',
#        'gdp_ind_mfg_Non-Metallic Products_quarterly',
#        'gdp_ind_mfg_Plastic and Rubber Products_quarterly',
#        'gdp_ind_mfg_Electrical and Electronics_quarterly',
#        'gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly',
#        'gdp_ind_mfg_Motor Vehicles and Assembly_quarterly',
#        'gdp_ind_mfg_Other Manufacturing_quarterly',
#        'gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly',
#        'gdp_ind_Water supply, Sewage, Waste Management_quarterly',
#        'gdp_ind_Construction_quarterly', 'GDP_SERVICES(svc)_quarterly',
#        'gdp_svc_Trade_quarterly',
#        'gdp_svc_Accommodation and Food Services_quarterly',
#        'gdp_svc_Transportation and Storage(TS)_quarterly',
#        'gdp_svc_TS_RoadTransport_quarterly',
#        'gdp_svc_TS_Rail Transport & Pipelines_quarterly',
#        'gdp_svc_TS_Water Transport_quarterly',
#        'gdp_svc_TS_Air Transport_quarterly',
#        'gdp_svc_TS_Transport Services_quarterly',
#        'gdp_svc_TS_Post and Courier Services_quarterly',
#        'gdp_svc_Information and Communication(IC)_quarterly',
#        'gdp_svc_IC_Telecommunications and Information Services_quarterly',
#        'gdp_svc_IC_Publishing_quarterly',
#        'gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly',
#        'gdp_svc_IC_Broadcasting_quarterly',
#        'gdp_svc_Arts, Entertainment & Recreation_quarterly',
#        'gdp_svc_Financial and Insurance(FI)_quarterly',
#        'gdp_svc_FI_Financial Institutions_quarterly',
#        'gdp_svc_FI_Insurance_quarterly', 'gdp_svc_Real Estate_quarterly',
#        'gdp_svc_Professional, Scientific & Technical Services_quarterly',
#        'gdp_svc_Administrative and Support Services_quarterly',
#        'gdp_svc_Public Administration_quarterly',
#        'gdp_svc_Education_quarterly',
#        'gdp_svc_Human Health & Social Services_quarterly',
#        'gdp_svc_Other Services_quarterly',
#        'GDP at Current Basic Prices_quarterly',
#        'Net Taxes on Products_quarterly',
#        'GDP at Current Market Prices_quarterly',
#        'foreign_reserve_Gross(USD)_monthly',
#        'foreign_reserve_Liquid(USD)_monthly', 'Year', 'Month_idx',
#        'foreign_reserve_gross(USD)_daily',
#        'foreign_reserve_liquid(USD)_daily'],
#       dtype='str')

# %%
finance_sector_ME_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2152 entries, 64 to 2277
# Data columns (total 89 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   date                                                                        2152 non-null   datetime64[us]
#  1   sector                                                                      2152 non-null   str
#  2   weighted_sector_returns                                                     2152 non-null   float64
#  3   n_stocks_contributing                                                       2152 non-null   float64
#  4   sector_index                                                                2152 non-null   float64
#  5   sector_volume                                                               2152 non-null   float64
#  6   Quarter                                                                     2152 non-null   str
#  7   Month                                                                       2152 non-null   str
#  8   consumer_price_index(CPI)_monthly                                           2152 non-null   float64
#  9   Crude Oil Price_monthly                                                     2152 non-null   float64
#  10  Domestic Production_monthly                                                 2152 non-null   float64
#  11  Crude Oil Export_monthly                                                    2152 non-null   float64
#  12  Inflation_allItemsAverage_monthly                                           2152 non-null   float64
#  13  Money Supply(M2)_monthly                                                    2152 non-null   float64
#  14  currency in circulation_monthly                                             2152 non-null   float64
#  15  bank reserves_monthly                                                       2152 non-null   float64
#  16  netForeignAssets_monthly                                                    2152 non-null   float64
#  17  netDomesticAssets_monthly                                                   2152 non-null   float64
#  18  netDomesticCredit_monthly                                                   2152 non-null   float64
#  19  creditToGovernment_monthly                                                  2152 non-null   float64
#  20  creditToPrivateSector_monthly                                               2152 non-null   float64
#  21  MonetaryPolicyRate_monthly                                                  2152 non-null   float64
#  22  TreasuryBillRate_monthly                                                    2152 non-null   float64
#  23  Lending_Rate_monthly                                                        2152 non-null   float64
#  24  Exchange_Rate(USD-EOP)_monthly                                              2152 non-null   float64
#  25  Premium_Motor_Spirit(PMS)_monthly                                           2152 non-null   float64
#  26  GDP_AGRICULTURE(agric)_quarterly                                            2152 non-null   float64
#  27  gdp_agric_Crop Production_quarterly                                         2152 non-null   float64
#  28  gdp_agric_Livestock_quarterly                                               2152 non-null   float64
#  29  gdp_agric_Forestry_quarterly                                                2152 non-null   float64
#  30   gdp_Fishing_quarterly                                                      2152 non-null   float64
#  31  GDP_INDUSTRY(ind)_quarterly                                                 2152 non-null   float64
#  32  gdp_ind_Mining and Quarrying(MQ)_quarterly                                  2152 non-null   float64
#  33  gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly                        2152 non-null   float64
#  34  gdp_ind_MQ_Coal Mining_quarterly                                            2152 non-null   float64
#  35  gdp_ind_MQ_Metal Ores_quarterly                                             2152 non-null   float64
#  36  gdp_ind_MQ_Quarrying and Other Minerals_quarterly                           2152 non-null   float64
#  37  gdp_ind_Manufacturing(mfg)_quarterly                                        2152 non-null   float64
#  38  gdp_ind_mfg_Oil Refining_quarterly                                          2152 non-null   float64
#  39  gdp_ind_mfg_Cement_quarterly                                                2152 non-null   float64
#  40  gdp_ind_mfg_Food, Beverage and Tobacco_quarterly                            2152 non-null   float64
#  41  gdp_ind_mfg_Textile, Apparel and Footwear_quarterly                         2152 non-null   float64
#  42  gdp_ind_mfg_Wood and Wood Products_quarterly                                2152 non-null   float64
#  43  gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly                        2152 non-null   float64
#  44  gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly                  2152 non-null   float64
#  45  gdp_ind_mfg_Non-Metallic Products_quarterly                                 2152 non-null   float64
#  46  gdp_ind_mfg_Plastic and Rubber Products_quarterly                           2152 non-null   float64
#  47  gdp_ind_mfg_Electrical and Electronics_quarterly                            2152 non-null   float64
#  48  gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly                           2152 non-null   float64
#  49  gdp_ind_mfg_Motor Vehicles and Assembly_quarterly                           2152 non-null   float64
#  50  gdp_ind_mfg_Other Manufacturing_quarterly                                   2152 non-null   float64
#  51  gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly                 2152 non-null   float64
#  52  gdp_ind_Water supply, Sewage, Waste Management_quarterly                    2152 non-null   float64
#  53  gdp_ind_Construction_quarterly                                              2152 non-null   float64
#  54  GDP_SERVICES(svc)_quarterly                                                 2152 non-null   float64
#  55  gdp_svc_Trade_quarterly                                                     2152 non-null   float64
#  56  gdp_svc_Accommodation and Food Services_quarterly                           2152 non-null   float64
#  57  gdp_svc_Transportation and Storage(TS)_quarterly                            2152 non-null   float64
#  58  gdp_svc_TS_RoadTransport_quarterly                                          2152 non-null   float64
#  59  gdp_svc_TS_Rail Transport & Pipelines_quarterly                             2152 non-null   float64
#  60  gdp_svc_TS_Water Transport_quarterly                                        2152 non-null   float64
#  61  gdp_svc_TS_Air Transport_quarterly                                          2152 non-null   float64
#  62  gdp_svc_TS_Transport Services_quarterly                                     2152 non-null   float64
#  63  gdp_svc_TS_Post and Courier Services_quarterly                              2152 non-null   float64
#  64  gdp_svc_Information and Communication(IC)_quarterly                         2152 non-null   float64
#  65  gdp_svc_IC_Telecommunications and Information Services_quarterly            2152 non-null   float64
#  66  gdp_svc_IC_Publishing_quarterly                                             2152 non-null   float64
#  67  gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly  2152 non-null   float64
#  68  gdp_svc_IC_Broadcasting_quarterly                                           2152 non-null   float64
#  69  gdp_svc_Arts, Entertainment & Recreation_quarterly                          2152 non-null   float64
#  70  gdp_svc_Financial and Insurance(FI)_quarterly                               2152 non-null   float64
#  71  gdp_svc_FI_Financial Institutions_quarterly                                 2152 non-null   float64
#  72  gdp_svc_FI_Insurance_quarterly                                              2152 non-null   float64
#  73  gdp_svc_Real Estate_quarterly                                               2152 non-null   float64
#  74  gdp_svc_Professional, Scientific & Technical Services_quarterly             2152 non-null   float64
#  75  gdp_svc_Administrative and Support Services_quarterly                       2152 non-null   float64
#  76  gdp_svc_Public Administration_quarterly                                     2152 non-null   float64
#  77  gdp_svc_Education_quarterly                                                 2152 non-null   float64
#  78  gdp_svc_Human Health & Social Services_quarterly                            2152 non-null   float64
#  79  gdp_svc_Other Services_quarterly                                            2152 non-null   float64
#  80  GDP at Current Basic Prices_quarterly                                       2152 non-null   float64
#  81  Net Taxes on Products_quarterly                                             2152 non-null   float64
#  82  GDP at Current Market Prices_quarterly                                      2152 non-null   float64
#  83  foreign_reserve_Gross(USD)_monthly                                          2152 non-null   float64
#  84  foreign_reserve_Liquid(USD)_monthly                                         2152 non-null   float64
#  85  Year                                                                        2152 non-null   float64
#  86  Month_idx                                                                   2152 non-null   float64
#  87  foreign_reserve_gross(USD)_daily                                            2152 non-null   float64
#  88  foreign_reserve_liquid(USD)_daily                                           2152 non-null   float64
# dtypes: datetime64[us](1), float64(85), str(3)
# memory usage: 1.5 MB

# %%
## LET US DROP COLUMNS THAT WONT HAVE ANY EFFECT AT ALL (eg date, index etc)

# %%
finance_sector_ME_df2=finance_sector_ME_df.drop(columns=['foreign_reserve_Gross(USD)_monthly','foreign_reserve_Liquid(USD)_monthly', 'Year', 'Month_idx','date', 'sector','Quarter', 'Month'])

# %%
finance_sector_ME_df2.shape
# Out:
# (2152, 81)

# %%
## We will need to lag the sector_volume by 1 day to avoid leakage
finance_sector_ME_df['sector_volume']=finance_sector_ME_df['sector_volume'].shift(1)
finance_sector_ME_df['sector_volume'].head()
# Out:
# 64            NaN
# 65     51906903.0
# 66     45091739.0
# 67     96410309.0
# 68    101585127.0
# Name: sector_volume, dtype: float64

# %%
finance_sector_ME_df=finance_sector_ME_df.dropna()

# %% [markdown]
# We will perform a quick training to see the performance. We will apply xgboost because it is tree based.
#
# NOTE: WHen doing the splitting we use time series method instead of a random split because this data is a time series data

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np

# %%
## The needed features for this training (Check Cloud AI for explanation)
X_y_finance_features = [
    #target feature
    'weighted_sector_returns',

    'sector_volume',  # consider lagging — see caveat below

    # Prices / inflation
    'consumer_price_index(CPI)_monthly',
    'Inflation_allItemsAverage_monthly',
    'Premium_Motor_Spirit(PMS)_monthly',

    # Oil
    'Crude Oil Price_monthly',
    'Domestic Production_monthly',
    'Crude Oil Export_monthly',

    # Money supply / banking system
    'Money Supply(M2)_monthly',
    'currency in circulation_monthly',
    'bank reserves_monthly',
    'netForeignAssets_monthly',
    'netDomesticAssets_monthly',
    'netDomesticCredit_monthly',
    'creditToGovernment_monthly',
    'creditToPrivateSector_monthly',

    # Interest rates
    'MonetaryPolicyRate_monthly',
    'TreasuryBillRate_monthly',
    'Lending_Rate_monthly',

    # Exchange rate
    'Exchange_Rate(USD-EOP)_monthly',

    # Broad economy GDP
    'GDP_AGRICULTURE(agric)_quarterly',
    'GDP_INDUSTRY(ind)_quarterly',
    'GDP at Current Market Prices_quarterly',

    # Financial sector-specific GDP
    'gdp_svc_FI_Financial Institutions_quarterly',

    # Foreign reserves (pick one frequency — daily shown here)
    'foreign_reserve_gross(USD)_daily',
    'foreign_reserve_liquid(USD)_daily',
]

# %%
len(X_y_finance_features)
# Out:
# 26

# %%
financial_sec_feat=finance_sector_ME_df[X_y_finance_features]

# %%
## We will inspect the correlations to remove redundant features ie avoidng collinearity
financial_sec_feat.corr()
# Out:
#                                              weighted_sector_returns  \
# weighted_sector_returns                                     1.000000
# sector_volume                                               0.034559
# consumer_price_index(CPI)_monthly                           0.036788
# Inflation_allItemsAverage_monthly                           0.057614
# Premium_Motor_Spirit(PMS)_monthly                           0.037428
# Crude Oil Price_monthly                                    -0.040990
# Domestic Production_monthly                                -0.030321
# Crude Oil Export_monthly                                   -0.030321
# Money Supply(M2)_monthly                                    0.036900
# currency in circulation_monthly                             0.033725
# bank reserves_monthly                                       0.040210
# netForeignAssets_monthly                                    0.004136
# netDomesticAssets_monthly                                   0.044282
# netDomesticCredit_monthly                                   0.046168
# creditToGovernment_monthly                                  0.051951
# creditToPrivateSector_monthly                               0.041317
# MonetaryPolicyRate_monthly                                  0.044230
# TreasuryBillRate_monthly                                    0.027193
# Lending_Rate_monthly                                        0.027322
# Exchange_Rate(USD-EOP)_monthly                              0.038416
# GDP_AGRICULTURE(agric)_quarterly                            0.033296
# GDP_INDUSTRY(ind)_quarterly                                 0.033946
# GDP at Current Market Prices_quarterly                      0.033132
# gdp_svc_FI_Financial Institutions_quarterly                 0.034103
# foreign_reserve_gross(USD)_daily                           -0.060217
# foreign_reserve_liquid(USD)_daily                          -0.061498
#
#                                              sector_volume  \
# weighted_sector_returns                           0.034559
# sector_volume                                     1.000000
# consumer_price_index(CPI)_monthly                 0.390069
# Inflation_allItemsAverage_monthly                 0.264882
# Premium_Motor_Spirit(PMS)_monthly                 0.385354
# Crude Oil Price_monthly                           0.061151
# Domestic Production_monthly                      -0.108977
# Crude Oil Export_monthly                         -0.108977
# Money Supply(M2)_monthly                          0.384723
# currency in circulation_monthly                   0.358076
# bank reserves_monthly                             0.390276
# netForeignAssets_monthly                          0.336442
# netDomesticAssets_monthly                         0.361334
# netDomesticCredit_monthly                         0.352500
# creditToGovernment_monthly                        0.295017
# creditToPrivateSector_monthly                     0.364151
# MonetaryPolicyRate_monthly                        0.379395
# TreasuryBillRate_monthly                          0.258623
# Lending_Rate_monthly                              0.260255
# Exchange_Rate(USD-EOP)_monthly                    0.368635
# GDP_AGRICULTURE(agric)_quarterly                  0.372103
# GDP_INDUSTRY(ind)_quarterly                       0.262271
# GDP at Current Market Prices_quarterly            0.397952
# gdp_svc_FI_Financial Institutions_quarterly       0.368102
# foreign_reserve_gross(USD)_daily                  0.114115
# foreign_reserve_liquid(USD)_daily                 0.111998
#
#                                              consumer_price_index(CPI)_monthly  \
# weighted_sector_returns                                               0.036788
# sector_volume                                                         0.390069
# consumer_price_index(CPI)_monthly                                     1.000000
# Inflation_allItemsAverage_monthly                                     0.709470
# Premium_Motor_Spirit(PMS)_monthly                                     0.938913
# Crude Oil Price_monthly                                               0.375995
# Domestic Production_monthly                                          -0.512593
# Crude Oil Export_monthly                                             -0.512593
# Money Supply(M2)_monthly                                              0.993408
# currency in circulation_monthly                                       0.936904
# bank reserves_monthly                                                 0.988509
# netForeignAssets_monthly                                              0.716061
# netDomesticAssets_monthly                                             0.966531
# netDomesticCredit_monthly                                             0.970244
# creditToGovernment_monthly                                            0.870374
# creditToPrivateSector_monthly                                         0.974360
# MonetaryPolicyRate_monthly                                            0.926271
# TreasuryBillRate_monthly                                              0.555632
# Lending_Rate_monthly                                                  0.418807
# Exchange_Rate(USD-EOP)_monthly                                        0.942293
# GDP_AGRICULTURE(agric)_quarterly                                      0.878492
# GDP_INDUSTRY(ind)_quarterly                                           0.870827
# GDP at Current Market Prices_quarterly                                0.961467
# gdp_svc_FI_Financial Institutions_quarterly                           0.942385
# foreign_reserve_gross(USD)_daily                                      0.214907
# foreign_reserve_liquid(USD)_daily                                     0.208585
#
#                                              Inflation_allItemsAverage_monthly  \
# weighted_sector_returns                                               0.057614
# sector_volume                                                         0.264882
# consumer_price_index(CPI)_monthly                                     0.709470
# Inflation_allItemsAverage_monthly                                     1.000000
# Premium_Motor_Spirit(PMS)_monthly                                     0.642471
# Crude Oil Price_monthly                                               0.360213
# Domestic Production_monthly                                          -0.540425
# Crude Oil Export_monthly                                             -0.540425
# Money Supply(M2)_monthly                                              0.746231
# currency in circulation_monthly                                       0.609236
# bank reserves_monthly                                                 0.664852
# netForeignAssets_monthly                                              0.428372
# netDomesticAssets_monthly                                             0.763039
# netDomesticCredit_monthly                                             0.781944
# creditToGovernment_monthly                                            0.706519
# creditToPrivateSector_monthly                                         0.782836
# MonetaryPolicyRate_monthly                                            0.764461
# TreasuryBillRate_monthly                                              0.528143
# Lending_Rate_monthly                                                  0.296194
# Exchange_Rate(USD-EOP)_monthly                                        0.796574
# GDP_AGRICULTURE(agric)_quarterly                                      0.507435
# GDP_INDUSTRY(ind)_quarterly                                           0.717676
# GDP at Current Market Prices_quarterly                                0.561274
# gdp_svc_FI_Financial Institutions_quarterly                           0.737271
# foreign_reserve_gross(USD)_daily                                     -0.150168
# foreign_reserve_liquid(USD)_daily                                    -0.163339
#
#                                              Premium_Motor_Spirit(PMS)_monthly  \
# weighted_sector_returns                                               0.037428
# sector_volume                                                         0.385354
# consumer_price_index(CPI)_monthly                                     0.938913
# Inflation_allItemsAverage_monthly                                     0.642471
# Premium_Motor_Spirit(PMS)_monthly                                     1.000000
# Crude Oil Price_monthly                                               0.270276
# Domestic Production_monthly                                          -0.300621
# Crude Oil Export_monthly                                             -0.300621
# Money Supply(M2)_monthly                                              0.940199
# currency in circulation_monthly                                       0.894628
# bank reserves_monthly                                                 0.929906
# netForeignAssets_monthly                                              0.767662
# netDomesticAssets_monthly                                             0.898956
# netDomesticCredit_monthly                                             0.897996
# creditToGovernment_monthly                                            0.780633
# creditToPrivateSector_monthly                                         0.913749
# MonetaryPolicyRate_monthly                                            0.926396
# TreasuryBillRate_monthly                                              0.663997
# Lending_Rate_monthly                                                  0.585364
# Exchange_Rate(USD-EOP)_monthly                                        0.921414
# GDP_AGRICULTURE(agric)_quarterly                                      0.792128
# GDP_INDUSTRY(ind)_quarterly                                           0.781481
# GDP at Current Market Prices_quarterly                                0.899733
# gdp_svc_FI_Financial Institutions_quarterly                           0.906764
# foreign_reserve_gross(USD)_daily                                      0.262585
# foreign_reserve_liquid(USD)_daily                                     0.254381
#
#                                              Crude Oil Price_monthly  \
# weighted_sector_returns                                    -0.040990
# sector_volume                                               0.061151
# consumer_price_index(CPI)_monthly                           0.375995
# Inflation_allItemsAverage_monthly                           0.360213
# Premium_Motor_Spirit(PMS)_monthly                           0.270276
# Crude Oil Price_monthly                                     1.000000
# Domestic Production_monthly                                -0.585350
# Crude Oil Export_monthly                                   -0.585350
# Money Supply(M2)_monthly                                    0.349511
# currency in circulation_monthly                             0.347724
# bank reserves_monthly                                       0.298465
# netForeignAssets_monthly                                    0.076944
# netDomesticAssets_monthly                                   0.382128
# netDomesticCredit_monthly                                   0.416194
# creditToGovernment_monthly                                  0.466343
# creditToPrivateSector_monthly                               0.373415
# MonetaryPolicyRate_monthly                                  0.251566
# TreasuryBillRate_monthly                                    0.072344
# Lending_Rate_monthly                                       -0.122648
# Exchange_Rate(USD-EOP)_monthly                              0.259164
# GDP_AGRICULTURE(agric)_quarterly                            0.215951
# GDP_INDUSTRY(ind)_quarterly                                 0.525015
# GDP at Current Market Prices_quarterly                      0.297553
# gdp_svc_FI_Financial Institutions_quarterly                 0.354519
# foreign_reserve_gross(USD)_daily                            0.234410
# foreign_reserve_liquid(USD)_daily                           0.232559
#
#                                              Domestic Production_monthly  \
# weighted_sector_returns                                        -0.030321
# sector_volume                                                  -0.108977
# consumer_price_index(CPI)_monthly                              -0.512593
# Inflation_allItemsAverage_monthly                              -0.540425
# Premium_Motor_Spirit(PMS)_monthly                              -0.300621
# Crude Oil Price_monthly                                        -0.585350
# Domestic Production_monthly                                     1.000000
# Crude Oil Export_monthly                                        1.000000
# Money Supply(M2)_monthly                                       -0.489953
# currency in circulation_monthly                                -0.482229
# bank reserves_monthly                                          -0.505720
# netForeignAssets_monthly                                        0.014666
# netDomesticAssets_monthly                                      -0.559377
# netDomesticCredit_monthly                                      -0.585572
# creditToGovernment_monthly                                     -0.646486
# creditToPrivateSector_monthly                                  -0.530002
# MonetaryPolicyRate_monthly                                     -0.293811
# TreasuryBillRate_monthly                                        0.156622
# Lending_Rate_monthly                                            0.413686
# Exchange_Rate(USD-EOP)_monthly                                 -0.391947
# GDP_AGRICULTURE(agric)_quarterly                               -0.419765
# GDP_INDUSTRY(ind)_quarterly                                    -0.701822
# GDP at Current Market Prices_quarterly                         -0.420385
# gdp_svc_FI_Financial Institutions_quarterly                    -0.438209
# foreign_reserve_gross(USD)_daily                                0.222102
# foreign_reserve_liquid(USD)_daily                               0.213903
#
#                                              Crude Oil Export_monthly  \
# weighted_sector_returns                                     -0.030321
# sector_volume                                               -0.108977
# consumer_price_index(CPI)_monthly                           -0.512593
# Inflation_allItemsAverage_monthly                           -0.540425
# Premium_Motor_Spirit(PMS)_monthly                           -0.300621
# Crude Oil Price_monthly                                     -0.585350
# Domestic Production_monthly                                  1.000000
# Crude Oil Export_monthly                                     1.000000
# Money Supply(M2)_monthly                                    -0.489953
# currency in circulation_monthly                             -0.482229
# bank reserves_monthly                                       -0.505720
# netForeignAssets_monthly                                     0.014666
# netDomesticAssets_monthly                                   -0.559377
# netDomesticCredit_monthly                                   -0.585572
# creditToGovernment_monthly                                  -0.646486
# creditToPrivateSector_monthly                               -0.530002
# MonetaryPolicyRate_monthly                                  -0.293811
# TreasuryBillRate_monthly                                     0.156622
# Lending_Rate_monthly                                         0.413686
# Exchange_Rate(USD-EOP)_monthly                              -0.391947
# GDP_AGRICULTURE(agric)_quarterly                            -0.419765
# GDP_INDUSTRY(ind)_quarterly                                 -0.701822
# GDP at Current Market Prices_quarterly                      -0.420385
# gdp_svc_FI_Financial Institutions_quarterly                 -0.438209
# foreign_reserve_gross(USD)_daily                             0.222102
# foreign_reserve_liquid(USD)_daily                            0.213903
#
#                                              Money Supply(M2)_monthly  \
# weighted_sector_returns                                      0.036900
# sector_volume                                                0.384723
# consumer_price_index(CPI)_monthly                            0.993408
# Inflation_allItemsAverage_monthly                            0.746231
# Premium_Motor_Spirit(PMS)_monthly                            0.940199
# Crude Oil Price_monthly                                      0.349511
# Domestic Production_monthly                                 -0.489953
# Crude Oil Export_monthly                                    -0.489953
# Money Supply(M2)_monthly                                     1.000000
# currency in circulation_monthly                              0.938204
# bank reserves_monthly                                        0.979204
# netForeignAssets_monthly                                     0.747475
# netDomesticAssets_monthly                                    0.966082
# netDomesticCredit_monthly                                    0.971304
# creditToGovernment_monthly                                   0.849772
# creditToPrivateSector_monthly                                0.985749
# MonetaryPolicyRate_monthly                                   0.945928
# TreasuryBillRate_monthly                                     0.600021
# Lending_Rate_monthly                                         0.440887
# Exchange_Rate(USD-EOP)_monthly                               0.971839
# GDP_AGRICULTURE(agric)_quarterly                             0.851138
# GDP_INDUSTRY(ind)_quarterly                                  0.863730
# GDP at Current Market Prices_quarterly                       0.939999
# gdp_svc_FI_Financial Institutions_quarterly                  0.953609
# foreign_reserve_gross(USD)_daily                             0.190025
# foreign_reserve_liquid(USD)_daily                            0.182679
#
#                                              currency in circulation_monthly  \
# weighted_sector_returns                                             0.033725
# sector_volume                                                       0.358076
# consumer_price_index(CPI)_monthly                                   0.936904
# Inflation_allItemsAverage_monthly                                   0.609236
# Premium_Motor_Spirit(PMS)_monthly                                   0.894628
# Crude Oil Price_monthly                                             0.347724
# Domestic Production_monthly                                        -0.482229
# Crude Oil Export_monthly                                           -0.482229
# Money Supply(M2)_monthly                                            0.938204
# currency in circulation_monthly                                     1.000000
# bank reserves_monthly                                               0.928672
# netForeignAssets_monthly                                            0.684555
# netDomesticAssets_monthly                                           0.923767
# netDomesticCredit_monthly                                           0.893359
# creditToGovernment_monthly                                          0.776542
# creditToPrivateSector_monthly                                       0.909059
# MonetaryPolicyRate_monthly                                          0.831393
# TreasuryBillRate_monthly                                            0.524282
# Lending_Rate_monthly                                                0.367484
# Exchange_Rate(USD-EOP)_monthly                                      0.889486
# GDP_AGRICULTURE(agric)_quarterly                                    0.844631
# GDP_INDUSTRY(ind)_quarterly                                         0.800373
# GDP at Current Market Prices_quarterly                              0.918321
# gdp_svc_FI_Financial Institutions_quarterly                         0.889172
# foreign_reserve_gross(USD)_daily                                    0.274077
# foreign_reserve_liquid(USD)_daily                                   0.276003
#
#                                              ...  MonetaryPolicyRate_monthly  \
# weighted_sector_returns                      ...                    0.044230
# sector_volume                                ...                    0.379395
# consumer_price_index(CPI)_monthly            ...                    0.926271
# Inflation_allItemsAverage_monthly            ...                    0.764461
# Premium_Motor_Spirit(PMS)_monthly            ...                    0.926396
# Crude Oil Price_monthly                      ...                    0.251566
# Domestic Production_monthly                  ...                   -0.293811
# Crude Oil Export_monthly                     ...                   -0.293811
# Money Supply(M2)_monthly                     ...                    0.945928
# currency in circulation_monthly              ...                    0.831393
# bank reserves_monthly                        ...                    0.896805
# netForeignAssets_monthly                     ...                    0.804407
# netDomesticAssets_monthly                    ...                    0.890024
# netDomesticCredit_monthly                    ...                    0.903870
# creditToGovernment_monthly                   ...                    0.763032
# creditToPrivateSector_monthly                ...                    0.930603
# MonetaryPolicyRate_monthly                   ...                    1.000000
# TreasuryBillRate_monthly                     ...                    0.766699
# Lending_Rate_monthly                         ...                    0.647788
# Exchange_Rate(USD-EOP)_monthly               ...                    0.963006
# GDP_AGRICULTURE(agric)_quarterly             ...                    0.753599
# GDP_INDUSTRY(ind)_quarterly                  ...                    0.747973
# GDP at Current Market Prices_quarterly       ...                    0.858277
# gdp_svc_FI_Financial Institutions_quarterly  ...                    0.927812
# foreign_reserve_gross(USD)_daily             ...                    0.193404
# foreign_reserve_liquid(USD)_daily            ...                    0.174915
#
#                                              TreasuryBillRate_monthly  \
# weighted_sector_returns                                      0.027193
# sector_volume                                                0.258623
# consumer_price_index(CPI)_monthly                            0.555632
# Inflation_allItemsAverage_monthly                            0.528143
# Premium_Motor_Spirit(PMS)_monthly                            0.663997
# Crude Oil Price_monthly                                      0.072344
# Domestic Production_monthly                                  0.156622
# Crude Oil Export_monthly                                     0.156622
# Money Supply(M2)_monthly                                     0.600021
# currency in circulation_monthly                              0.524282
# bank reserves_monthly                                        0.498941
# netForeignAssets_monthly                                     0.755005
# netDomesticAssets_monthly                                    0.516941
# netDomesticCredit_monthly                                    0.508609
# creditToGovernment_monthly                                   0.330152
# creditToPrivateSector_monthly                                0.571176
# MonetaryPolicyRate_monthly                                   0.766699
# TreasuryBillRate_monthly                                     1.000000
# Lending_Rate_monthly                                         0.836225
# Exchange_Rate(USD-EOP)_monthly                               0.691095
# GDP_AGRICULTURE(agric)_quarterly                             0.396332
# GDP_INDUSTRY(ind)_quarterly                                  0.295594
# GDP at Current Market Prices_quarterly                       0.511819
# gdp_svc_FI_Financial Institutions_quarterly                  0.605502
# foreign_reserve_gross(USD)_daily                             0.270337
# foreign_reserve_liquid(USD)_daily                            0.249381
#
#                                              Lending_Rate_monthly  \
# weighted_sector_returns                                  0.027322
# sector_volume                                            0.260255
# consumer_price_index(CPI)_monthly                        0.418807
# Inflation_allItemsAverage_monthly                        0.296194
# Premium_Motor_Spirit(PMS)_monthly                        0.585364
# Crude Oil Price_monthly                                 -0.122648
# Domestic Production_monthly                              0.413686
# Crude Oil Export_monthly                                 0.413686
# Money Supply(M2)_monthly                                 0.440887
# currency in circulation_monthly                          0.367484
# bank reserves_monthly                                    0.387619
# netForeignAssets_monthly                                 0.679620
# netDomesticAssets_monthly                                0.348740
# netDomesticCredit_monthly                                0.336295
# creditToGovernment_monthly                               0.183788
# creditToPrivateSector_monthly                            0.394195
# MonetaryPolicyRate_monthly                               0.647788
# TreasuryBillRate_monthly                                 0.836225
# Lending_Rate_monthly                                     1.000000
# Exchange_Rate(USD-EOP)_monthly                           0.504463
# GDP_AGRICULTURE(agric)_quarterly                         0.361078
# GDP_INDUSTRY(ind)_quarterly                              0.069977
# GDP at Current Market Prices_quarterly                   0.450472
# gdp_svc_FI_Financial Institutions_quarterly              0.461116
# foreign_reserve_gross(USD)_daily                         0.388745
# foreign_reserve_liquid(USD)_daily                        0.365644
#
#                                              Exchange_Rate(USD-EOP)_monthly  \
# weighted_sector_returns                                            0.038416
# sector_volume                                                      0.368635
# consumer_price_index(CPI)_monthly                                  0.942293
# Inflation_allItemsAverage_monthly                                  0.796574
# Premium_Motor_Spirit(PMS)_monthly                                  0.921414
# Crude Oil Price_monthly                                            0.259164
# Domestic Production_monthly                                       -0.391947
# Crude Oil Export_monthly                                          -0.391947
# Money Supply(M2)_monthly                                           0.971839
# currency in circulation_monthly                                    0.889486
# bank reserves_monthly                                              0.923213
# netForeignAssets_monthly                                           0.794225
# netDomesticAssets_monthly                                          0.922592
# netDomesticCredit_monthly                                          0.928572
# creditToGovernment_monthly                                         0.768550
# creditToPrivateSector_monthly                                      0.963382
# MonetaryPolicyRate_monthly                                         0.963006
# TreasuryBillRate_monthly                                           0.691095
# Lending_Rate_monthly                                               0.504463
# Exchange_Rate(USD-EOP)_monthly                                     1.000000
# GDP_AGRICULTURE(agric)_quarterly                                   0.761735
# GDP_INDUSTRY(ind)_quarterly                                        0.802733
# GDP at Current Market Prices_quarterly                             0.857824
# gdp_svc_FI_Financial Institutions_quarterly                        0.937651
# foreign_reserve_gross(USD)_daily                                   0.126597
# foreign_reserve_liquid(USD)_daily                                  0.116147
#
#                                              GDP_AGRICULTURE(agric)_quarterly  \
# weighted_sector_returns                                              0.033296
# sector_volume                                                        0.372103
# consumer_price_index(CPI)_monthly                                    0.878492
# Inflation_allItemsAverage_monthly                                    0.507435
# Premium_Motor_Spirit(PMS)_monthly                                    0.792128
# Crude Oil Price_monthly                                              0.215951
# Domestic Production_monthly                                         -0.419765
# Crude Oil Export_monthly                                            -0.419765
# Money Supply(M2)_monthly                                             0.851138
# currency in circulation_monthly                                      0.844631
# bank reserves_monthly                                                0.884735
# netForeignAssets_monthly                                             0.612610
# netDomesticAssets_monthly                                            0.824813
# netDomesticCredit_monthly                                            0.826460
# creditToGovernment_monthly                                           0.751895
# creditToPrivateSector_monthly                                        0.824934
# MonetaryPolicyRate_monthly                                           0.753599
# TreasuryBillRate_monthly                                             0.396332
# Lending_Rate_monthly                                                 0.361078
# Exchange_Rate(USD-EOP)_monthly                                       0.761735
# GDP_AGRICULTURE(agric)_quarterly                                     1.000000
# GDP_INDUSTRY(ind)_quarterly                                          0.724056
# GDP at Current Market Prices_quarterly                               0.955608
# gdp_svc_FI_Financial Institutions_quarterly                          0.736153
# foreign_reserve_gross(USD)_daily                                     0.307253
# foreign_reserve_liquid(USD)_daily                                    0.306467
#
#                                              GDP_INDUSTRY(ind)_quarterly  \
# weighted_sector_returns                                         0.033946
# sector_volume                                                   0.262271
# consumer_price_index(CPI)_monthly                               0.870827
# Inflation_allItemsAverage_monthly                               0.717676
# Premium_Motor_Spirit(PMS)_monthly                               0.781481
# Crude Oil Price_monthly                                         0.525015
# Domestic Production_monthly                                    -0.701822
# Crude Oil Export_monthly                                       -0.701822
# Money Supply(M2)_monthly                                        0.863730
# currency in circulation_monthly                                 0.800373
# bank reserves_monthly                                           0.858798
# netForeignAssets_monthly                                        0.442028
# netDomesticAssets_monthly                                       0.886815
# netDomesticCredit_monthly                                       0.924557
# creditToGovernment_monthly                                      0.902174
# creditToPrivateSector_monthly                                   0.893613
# MonetaryPolicyRate_monthly                                      0.747973
# TreasuryBillRate_monthly                                        0.295594
# Lending_Rate_monthly                                            0.069977
# Exchange_Rate(USD-EOP)_monthly                                  0.802733
# GDP_AGRICULTURE(agric)_quarterly                                0.724056
# GDP_INDUSTRY(ind)_quarterly                                     1.000000
# GDP at Current Market Prices_quarterly                          0.780284
# gdp_svc_FI_Financial Institutions_quarterly                     0.820247
# foreign_reserve_gross(USD)_daily                                0.039713
# foreign_reserve_liquid(USD)_daily                               0.035875
#
#                                              GDP at Current Market Prices_quarterly  \
# weighted_sector_returns                                                    0.033132
# sector_volume                                                              0.397952
# consumer_price_index(CPI)_monthly                                          0.961467
# Inflation_allItemsAverage_monthly                                          0.561274
# Premium_Motor_Spirit(PMS)_monthly                                          0.899733
# Crude Oil Price_monthly                                                    0.297553
# Domestic Production_monthly                                               -0.420385
# Crude Oil Export_monthly                                                  -0.420385
# Money Supply(M2)_monthly                                                   0.939999
# currency in circulation_monthly                                            0.918321
# bank reserves_monthly                                                      0.958844
# netForeignAssets_monthly                                                   0.711096
# netDomesticAssets_monthly                                                  0.903544
# netDomesticCredit_monthly                                                  0.902376
# creditToGovernment_monthly                                                 0.808922
# creditToPrivateSector_monthly                                              0.906478
# MonetaryPolicyRate_monthly                                                 0.858277
# TreasuryBillRate_monthly                                                   0.511819
# Lending_Rate_monthly                                                       0.450472
# Exchange_Rate(USD-EOP)_monthly                                             0.857824
# GDP_AGRICULTURE(agric)_quarterly                                           0.955608
# GDP_INDUSTRY(ind)_quarterly                                                0.780284
# GDP at Current Market Prices_quarterly                                     1.000000
# gdp_svc_FI_Financial Institutions_quarterly                                0.858160
# foreign_reserve_gross(USD)_daily                                           0.330260
# foreign_reserve_liquid(USD)_daily                                          0.327091
#
#                                              gdp_svc_FI_Financial Institutions_quarterly  \
# weighted_sector_returns                                                         0.034103
# sector_volume                                                                   0.368102
# consumer_price_index(CPI)_monthly                                               0.942385
# Inflation_allItemsAverage_monthly                                               0.737271
# Premium_Motor_Spirit(PMS)_monthly                                               0.906764
# Crude Oil Price_monthly                                                         0.354519
# Domestic Production_monthly                                                    -0.438209
# Crude Oil Export_monthly                                                       -0.438209
# Money Supply(M2)_monthly                                                        0.953609
# currency in circulation_monthly                                                 0.889172
# bank reserves_monthly                                                           0.923530
# netForeignAssets_monthly                                                        0.693288
# netDomesticAssets_monthly                                                       0.929415
# netDomesticCredit_monthly                                                       0.926252
# creditToGovernment_monthly                                                      0.812385
# creditToPrivateSector_monthly                                                   0.939056
# MonetaryPolicyRate_monthly                                                      0.927812
# TreasuryBillRate_monthly                                                        0.605502
# Lending_Rate_monthly                                                            0.461116
# Exchange_Rate(USD-EOP)_monthly                                                  0.937651
# GDP_AGRICULTURE(agric)_quarterly                                                0.736153
# GDP_INDUSTRY(ind)_quarterly                                                     0.820247
# GDP at Current Market Prices_quarterly                                          0.858160
# gdp_svc_FI_Financial Institutions_quarterly                                     1.000000
# foreign_reserve_gross(USD)_daily                                                0.167125
# foreign_reserve_liquid(USD)_daily                                               0.157994
#
#                                              foreign_reserve_gross(USD)_daily  \
# weighted_sector_returns                                             -0.060217
# sector_volume                                                        0.114115
# consumer_price_index(CPI)_monthly                                    0.214907
# Inflation_allItemsAverage_monthly                                   -0.150168
# Premium_Motor_Spirit(PMS)_monthly                                    0.262585
# Crude Oil Price_monthly                                              0.234410
# Domestic Production_monthly                                          0.222102
# Crude Oil Export_monthly                                             0.222102
# Money Supply(M2)_monthly                                             0.190025
# currency in circulation_monthly                                      0.274077
# bank reserves_monthly                                                0.188460
# netForeignAssets_monthly                                             0.356417
# netDomesticAssets_monthly                                            0.122612
# netDomesticCredit_monthly                                            0.120639
# creditToGovernment_monthly                                           0.108339
# creditToPrivateSector_monthly                                        0.121094
# MonetaryPolicyRate_monthly                                           0.193404
# TreasuryBillRate_monthly                                             0.270337
# Lending_Rate_monthly                                                 0.388745
# Exchange_Rate(USD-EOP)_monthly                                       0.126597
# GDP_AGRICULTURE(agric)_quarterly                                     0.307253
# GDP_INDUSTRY(ind)_quarterly                                          0.039713
# GDP at Current Market Prices_quarterly                               0.330260
# gdp_svc_FI_Financial Institutions_quarterly                          0.167125
# foreign_reserve_gross(USD)_daily                                     1.000000
# foreign_reserve_liquid(USD)_daily                                    0.998872
#
#                                              foreign_reserve_liquid(USD)_daily
# weighted_sector_returns                                              -0.061498
# sector_volume                                                         0.111998
# consumer_price_index(CPI)_monthly                                     0.208585
# Inflation_allItemsAverage_monthly                                    -0.163339
# Premium_Motor_Spirit(PMS)_monthly                                     0.254381
# Crude Oil Price_monthly                                               0.232559
# Domestic Production_monthly                                           0.213903
# Crude Oil Export_monthly                                              0.213903
# Money Supply(M2)_monthly                                              0.182679
# currency in circulation_monthly                                       0.276003
# bank reserves_monthly                                                 0.184589
# netForeignAssets_monthly                                              0.345407
# netDomesticAssets_monthly                                             0.116971
# netDomesticCredit_monthly                                             0.111808
# creditToGovernment_monthly                                            0.100386
# creditToPrivateSector_monthly                                         0.112240
# MonetaryPolicyRate_monthly                                            0.174915
# TreasuryBillRate_monthly                                              0.249381
# Lending_Rate_monthly                                                  0.365644
# Exchange_Rate(USD-EOP)_monthly                                        0.116147
# GDP_AGRICULTURE(agric)_quarterly                                      0.306467
# GDP_INDUSTRY(ind)_quarterly                                           0.035875
# GDP at Current Market Prices_quarterly                                0.327091
# gdp_svc_FI_Financial Institutions_quarterly                           0.157994
# foreign_reserve_gross(USD)_daily                                      0.998872
# foreign_reserve_liquid(USD)_daily                                     1.000000
#
# [26 rows x 26 columns]

# %%
## We will set a threshold for this exercise eg 0.85
## Note: this threshold is determined by the DOMAIN EXPERT
## For now we will use 0.90
## Let us improve the below

def correlation(dataset, threshold):
    col_corr = set()
    col_pair = set()
    
    corr_matrix = dataset.corr()

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname1 = corr_matrix.columns[i]
                colname2 = corr_matrix.columns[j]

                col_pair.add((colname1, colname2, corr_matrix.iloc[i, j]))
                col_corr.add(colname1)

    return col_corr, col_pair

# %%
## We will use the correlation() function we created.
## This will identify features that are highly correlated to each other
correlated_features,column_pairs =correlation(financial_sec_feat,0.85)
correlated_features

## The column pairing is good for investigative purposes
# Out:
# {'Crude Oil Export_monthly',
#  'Exchange_Rate(USD-EOP)_monthly',
#  'GDP at Current Market Prices_quarterly',
#  'GDP_AGRICULTURE(agric)_quarterly',
#  'GDP_INDUSTRY(ind)_quarterly',
#  'MonetaryPolicyRate_monthly',
#  'Money Supply(M2)_monthly',
#  'Premium_Motor_Spirit(PMS)_monthly',
#  'bank reserves_monthly',
#  'creditToGovernment_monthly',
#  'creditToPrivateSector_monthly',
#  'currency in circulation_monthly',
#  'foreign_reserve_liquid(USD)_daily',
#  'gdp_svc_FI_Financial Institutions_quarterly',
#  'netDomesticAssets_monthly',
#  'netDomesticCredit_monthly'}

# %%
column_pairs
# Out:
# {('Crude Oil Export_monthly',
#   'Domestic Production_monthly',
#   np.float64(0.9999999999999998)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.963005924212574)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9718386491774184)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9214136482702564)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9232133674542858)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9422931038722505)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9633817411889825)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.889486406658956)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9225921107107503)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9285721834559336)),
#  ('GDP at Current Market Prices_quarterly',
#   'Exchange_Rate(USD-EOP)_monthly',
#   np.float64(0.8578244745522008)),
#  ('GDP at Current Market Prices_quarterly',
#   'GDP_AGRICULTURE(agric)_quarterly',
#   np.float64(0.9556080902764711)),
#  ('GDP at Current Market Prices_quarterly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.85827718514173)),
#  ('GDP at Current Market Prices_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9399986181791238)),
#  ('GDP at Current Market Prices_quarterly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8997331271060133)),
#  ('GDP at Current Market Prices_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.9588442523066327)),
#  ('GDP at Current Market Prices_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9614674208652414)),
#  ('GDP at Current Market Prices_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9064777379108854)),
#  ('GDP at Current Market Prices_quarterly',
#   'currency in circulation_monthly',
#   np.float64(0.9183205383154911)),
#  ('GDP at Current Market Prices_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9035436896450181)),
#  ('GDP at Current Market Prices_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9023760072585345)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.8511381817858177)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.88473461935549)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8784921761357524)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.8637301203661936)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.858797623138937)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8708273810284519)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'creditToGovernment_monthly',
#   np.float64(0.9021740645387394)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.8936128145595746)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.886815292793497)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9245566422374517)),
#  ('MonetaryPolicyRate_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9459280575199603)),
#  ('MonetaryPolicyRate_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9263961244934045)),
#  ('MonetaryPolicyRate_monthly',
#   'bank reserves_monthly',
#   np.float64(0.8968052851246248)),
#  ('MonetaryPolicyRate_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9262710610712299)),
#  ('MonetaryPolicyRate_monthly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9306027803464241)),
#  ('MonetaryPolicyRate_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.8900237638731597)),
#  ('MonetaryPolicyRate_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9038699693636645)),
#  ('Money Supply(M2)_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9401993902050456)),
#  ('Money Supply(M2)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9934077341104154)),
#  ('Premium_Motor_Spirit(PMS)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9389129356271994)),
#  ('bank reserves_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9792044057772457)),
#  ('bank reserves_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9299063044577892)),
#  ('bank reserves_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9885088832100655)),
#  ('bank reserves_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9286719427841106)),
#  ('creditToGovernment_monthly',
#   'bank reserves_monthly',
#   np.float64(0.8558213577037572)),
#  ('creditToGovernment_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8703740458801453)),
#  ('creditToGovernment_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9133193511890015)),
#  ('creditToGovernment_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9358730144906805)),
#  ('creditToPrivateSector_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9857491662081507)),
#  ('creditToPrivateSector_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9137488369092426)),
#  ('creditToPrivateSector_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9562911481952058)),
#  ('creditToPrivateSector_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9743604957049907)),
#  ('creditToPrivateSector_monthly',
#   'creditToGovernment_monthly',
#   np.float64(0.8629779954332866)),
#  ('creditToPrivateSector_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9090588750480685)),
#  ('creditToPrivateSector_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9648100509663785)),
#  ('creditToPrivateSector_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9856533377158321)),
#  ('currency in circulation_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9382037405323014)),
#  ('currency in circulation_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8946279556310451)),
#  ('currency in circulation_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9369040327260718)),
#  ('foreign_reserve_liquid(USD)_daily',
#   'foreign_reserve_gross(USD)_daily',
#   np.float64(0.9988717860285592)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Exchange_Rate(USD-EOP)_monthly',
#   np.float64(0.9376509079044997)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'GDP at Current Market Prices_quarterly',
#   np.float64(0.8581604995114338)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.9278124053334997)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9536094010182748)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.906763608997728)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.9235301824099758)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9423852000216606)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9390563481243084)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'currency in circulation_monthly',
#   np.float64(0.889172451750516)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9294151929900526)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9262522181233819)),
#  ('netDomesticAssets_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9660820747994185)),
#  ('netDomesticAssets_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8989563044463242)),
#  ('netDomesticAssets_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9520154061886821)),
#  ('netDomesticAssets_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9665310861018933)),
#  ('netDomesticAssets_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9237672136371382)),
#  ('netDomesticCredit_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9713036895111336)),
#  ('netDomesticCredit_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8979963662240095)),
#  ('netDomesticCredit_monthly',
#   'bank reserves_monthly',
#   np.float64(0.952781570373185)),
#  ('netDomesticCredit_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9702440034739734)),
#  ('netDomesticCredit_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.8933590825148879)),
#  ('netDomesticCredit_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9779302919522995))}

# %% [markdown]
# There are too many features that are highly correlated. This should be because a lot of these macro economic variables increase over that. The correlation might not necessarily be due to actual economic relationship but rather of common driver direction.
#
# (Check Claude AI pinned chat for more)
#
# We will carryout the following steps to get actual reasonable relatonship:
# 1. Drop the near-duplicate (Crude Oil Export or Domestic Production — pick one).
# 2. Convert all remaining trending macro levels to % change / differenced versions.
# 3. Re-run correlation on the differenced set — expect it to shrink substantially.
# 4. For whatever real correlation remains (likely the money-supply/credit cluster), use VIF to prune, or lean on Lasso/ElasticNet to handle it automatically rather than manually picking.

# %%
## Before we drop 'Crude Oil Export_monthly' lets carry out 2 to 4 and see the perfromance
collinear_features=[
    'Crude Oil Export_monthly',
    'Exchange_Rate(USD-EOP)_monthly',
    'GDP at Current Market Prices_quarterly',
    'GDP_AGRICULTURE(agric)_quarterly',
    'GDP_INDUSTRY(ind)_quarterly',
    'MonetaryPolicyRate_monthly',
    'Money Supply(M2)_monthly',
    'Premium_Motor_Spirit(PMS)_monthly',
    'bank reserves_monthly',
    'creditToGovernment_monthly',
    'creditToPrivateSector_monthly',
    'currency in circulation_monthly',
    'foreign_reserve_liquid(USD)_daily',
    'gdp_svc_FI_Financial Institutions_quarterly',
    'netDomesticAssets_monthly',
    'netDomesticCredit_monthly'
]

# %%
## We will perform the percent change for the collinear_features
financial_sec_feat[collinear_features]=financial_sec_feat[collinear_features].pct_change()

# %%
financial_sec_feat=financial_sec_feat.dropna()

# %%
financial_sec_feat.head()
# Out:
#     weighted_sector_returns  sector_volume  consumer_price_index(CPI)_monthly  \
# 66                 0.584640     45091739.0                          204.45661
# 67                -0.282732     96410309.0                          204.45661
# 68                 0.624710    101585127.0                          204.45661
# 69                -0.184162     51494340.0                          204.45661
# 70                -0.462029     24515324.0                          204.45661
#
#     Inflation_allItemsAverage_monthly  Premium_Motor_Spirit(PMS)_monthly  \
# 66                              17.32                                0.0
# 67                              17.32                                0.0
# 68                              17.32                                0.0
# 69                              17.32                                0.0
# 70                              17.32                                0.0
#
#     Crude Oil Price_monthly  Domestic Production_monthly  \
# 66                    52.13                          1.6
# 67                    52.13                          1.6
# 68                    52.13                          1.6
# 69                    52.13                          1.6
# 70                    52.13                          1.6
#
#     Crude Oil Export_monthly  Money Supply(M2)_monthly  \
# 66                       0.0                       0.0
# 67                       0.0                       0.0
# 68                       0.0                       0.0
# 69                       0.0                       0.0
# 70                       0.0                       0.0
#
#     currency in circulation_monthly  ...  MonetaryPolicyRate_monthly  \
# 66                              0.0  ...                         0.0
# 67                              0.0  ...                         0.0
# 68                              0.0  ...                         0.0
# 69                              0.0  ...                         0.0
# 70                              0.0  ...                         0.0
#
#     TreasuryBillRate_monthly  Lending_Rate_monthly  \
# 66                      13.6                 17.43
# 67                      13.6                 17.43
# 68                      13.6                 17.43
# 69                      13.6                 17.43
# 70                      13.6                 17.43
#
#     Exchange_Rate(USD-EOP)_monthly  GDP_AGRICULTURE(agric)_quarterly  \
# 66                             0.0                               0.0
# 67                             0.0                               0.0
# 68                             0.0                               0.0
# 69                             0.0                               0.0
# 70                             0.0                               0.0
#
#     GDP_INDUSTRY(ind)_quarterly  GDP at Current Market Prices_quarterly  \
# 66                          0.0                                     0.0
# 67                          0.0                                     0.0
# 68                          0.0                                     0.0
# 69                          0.0                                     0.0
# 70                          0.0                                     0.0
#
#     gdp_svc_FI_Financial Institutions_quarterly  \
# 66                                          0.0
# 67                                          0.0
# 68                                          0.0
# 69                                          0.0
# 70                                          0.0
#
#     foreign_reserve_gross(USD)_daily  foreign_reserve_liquid(USD)_daily
# 66                      3.032576e+10                           0.000290
# 67                      3.034555e+10                           0.000708
# 68                      3.036654e+10                           0.000732
# 69                      3.039389e+10                           0.000964
# 70                      3.039392e+10                           0.000002
#
# [5 rows x 26 columns]

# %%
financial_sec_feat.columns
# Out:
# Index(['weighted_sector_returns', 'sector_volume',
#        'consumer_price_index(CPI)_monthly',
#        'Inflation_allItemsAverage_monthly',
#        'Premium_Motor_Spirit(PMS)_monthly', 'Crude Oil Price_monthly',
#        'Domestic Production_monthly', 'Crude Oil Export_monthly',
#        'Money Supply(M2)_monthly', 'currency in circulation_monthly',
#        'bank reserves_monthly', 'netForeignAssets_monthly',
#        'netDomesticAssets_monthly', 'netDomesticCredit_monthly',
#        'creditToGovernment_monthly', 'creditToPrivateSector_monthly',
#        'MonetaryPolicyRate_monthly', 'TreasuryBillRate_monthly',
#        'Lending_Rate_monthly', 'Exchange_Rate(USD-EOP)_monthly',
#        'GDP_AGRICULTURE(agric)_quarterly', 'GDP_INDUSTRY(ind)_quarterly',
#        'GDP at Current Market Prices_quarterly',
#        'gdp_svc_FI_Financial Institutions_quarterly',
#        'foreign_reserve_gross(USD)_daily',
#        'foreign_reserve_liquid(USD)_daily'],
#       dtype='str')

# %%
## Now let us run the correlations again
correlated_features,column_pairs =correlation(financial_sec_feat,0.85)
correlated_features
# Out:
# set()

# %%
column_pairs
# Out:
# set()

# %%
financial_sec_feat.corr()
# Out:
#                                              weighted_sector_returns  \
# weighted_sector_returns                                     1.000000
# sector_volume                                               0.034492
# consumer_price_index(CPI)_monthly                           0.036653
# Inflation_allItemsAverage_monthly                           0.057603
# Premium_Motor_Spirit(PMS)_monthly                           0.003415
# Crude Oil Price_monthly                                    -0.041147
# Domestic Production_monthly                                -0.030304
# Crude Oil Export_monthly                                    0.028092
# Money Supply(M2)_monthly                                    0.007552
# currency in circulation_monthly                            -0.012657
# bank reserves_monthly                                      -0.018342
# netForeignAssets_monthly                                    0.004033
# netDomesticAssets_monthly                                  -0.002095
# netDomesticCredit_monthly                                  -0.003249
# creditToGovernment_monthly                                 -0.008230
# creditToPrivateSector_monthly                               0.000996
# MonetaryPolicyRate_monthly                                  0.013220
# TreasuryBillRate_monthly                                    0.027303
# Lending_Rate_monthly                                        0.027442
# Exchange_Rate(USD-EOP)_monthly                              0.045452
# GDP_AGRICULTURE(agric)_quarterly                           -0.035434
# GDP_INDUSTRY(ind)_quarterly                                -0.002806
# GDP at Current Market Prices_quarterly                     -0.012243
# gdp_svc_FI_Financial Institutions_quarterly                 0.021613
# foreign_reserve_gross(USD)_daily                           -0.060494
# foreign_reserve_liquid(USD)_daily                           0.042313
#
#                                              sector_volume  \
# weighted_sector_returns                           0.034492
# sector_volume                                     1.000000
# consumer_price_index(CPI)_monthly                 0.389935
# Inflation_allItemsAverage_monthly                 0.264876
# Premium_Motor_Spirit(PMS)_monthly                 0.033217
# Crude Oil Price_monthly                           0.060906
# Domestic Production_monthly                      -0.108951
# Crude Oil Export_monthly                          0.013147
# Money Supply(M2)_monthly                          0.038449
# currency in circulation_monthly                   0.011591
# bank reserves_monthly                            -0.015902
# netForeignAssets_monthly                          0.336322
# netDomesticAssets_monthly                        -0.007420
# netDomesticCredit_monthly                         0.009699
# creditToGovernment_monthly                       -0.000279
# creditToPrivateSector_monthly                     0.016966
# MonetaryPolicyRate_monthly                        0.014136
# TreasuryBillRate_monthly                          0.258872
# Lending_Rate_monthly                              0.260524
# Exchange_Rate(USD-EOP)_monthly                    0.021206
# GDP_AGRICULTURE(agric)_quarterly                 -0.001449
# GDP_INDUSTRY(ind)_quarterly                      -0.000178
# GDP at Current Market Prices_quarterly            0.010839
# gdp_svc_FI_Financial Institutions_quarterly      -0.000091
# foreign_reserve_gross(USD)_daily                  0.113776
# foreign_reserve_liquid(USD)_daily                 0.089309
#
#                                              consumer_price_index(CPI)_monthly  \
# weighted_sector_returns                                               0.036653
# sector_volume                                                         0.389935
# consumer_price_index(CPI)_monthly                                     1.000000
# Inflation_allItemsAverage_monthly                                     0.709617
# Premium_Motor_Spirit(PMS)_monthly                                     0.019704
# Crude Oil Price_monthly                                               0.375653
# Domestic Production_monthly                                          -0.512666
# Crude Oil Export_monthly                                              0.012869
# Money Supply(M2)_monthly                                              0.013772
# currency in circulation_monthly                                       0.011407
# bank reserves_monthly                                                -0.004323
# netForeignAssets_monthly                                              0.715968
# netDomesticAssets_monthly                                             0.002553
# netDomesticCredit_monthly                                             0.005476
# creditToGovernment_monthly                                            0.005209
# creditToPrivateSector_monthly                                         0.004756
# MonetaryPolicyRate_monthly                                            0.023133
# TreasuryBillRate_monthly                                              0.556264
# Lending_Rate_monthly                                                  0.419420
# Exchange_Rate(USD-EOP)_monthly                                        0.006356
# GDP_AGRICULTURE(agric)_quarterly                                      0.000651
# GDP_INDUSTRY(ind)_quarterly                                          -0.009626
# GDP at Current Market Prices_quarterly                                0.018593
# gdp_svc_FI_Financial Institutions_quarterly                           0.016886
# foreign_reserve_gross(USD)_daily                                      0.214241
# foreign_reserve_liquid(USD)_daily                                     0.076734
#
#                                              Inflation_allItemsAverage_monthly  \
# weighted_sector_returns                                               0.057603
# sector_volume                                                         0.264876
# consumer_price_index(CPI)_monthly                                     0.709617
# Inflation_allItemsAverage_monthly                                     1.000000
# Premium_Motor_Spirit(PMS)_monthly                                     0.031571
# Crude Oil Price_monthly                                               0.360264
# Domestic Production_monthly                                          -0.540422
# Crude Oil Export_monthly                                              0.025883
# Money Supply(M2)_monthly                                              0.034992
# currency in circulation_monthly                                       0.027223
# bank reserves_monthly                                                 0.000322
# netForeignAssets_monthly                                              0.428398
# netDomesticAssets_monthly                                             0.007476
# netDomesticCredit_monthly                                             0.007564
# creditToGovernment_monthly                                            0.007716
# creditToPrivateSector_monthly                                         0.018814
# MonetaryPolicyRate_monthly                                            0.056620
# TreasuryBillRate_monthly                                              0.528257
# Lending_Rate_monthly                                                  0.296282
# Exchange_Rate(USD-EOP)_monthly                                        0.028604
# GDP_AGRICULTURE(agric)_quarterly                                      0.011589
# GDP_INDUSTRY(ind)_quarterly                                           0.005814
# GDP at Current Market Prices_quarterly                                0.024600
# gdp_svc_FI_Financial Institutions_quarterly                           0.028755
# foreign_reserve_gross(USD)_daily                                     -0.150351
# foreign_reserve_liquid(USD)_daily                                     0.132869
#
#                                              Premium_Motor_Spirit(PMS)_monthly  \
# weighted_sector_returns                                               0.003415
# sector_volume                                                         0.033217
# consumer_price_index(CPI)_monthly                                     0.019704
# Inflation_allItemsAverage_monthly                                     0.031571
# Premium_Motor_Spirit(PMS)_monthly                                     1.000000
# Crude Oil Price_monthly                                               0.014436
# Domestic Production_monthly                                          -0.031047
# Crude Oil Export_monthly                                              0.323752
# Money Supply(M2)_monthly                                              0.025574
# currency in circulation_monthly                                       0.035051
# bank reserves_monthly                                                 0.016562
# netForeignAssets_monthly                                             -0.022542
# netDomesticAssets_monthly                                            -0.007763
# netDomesticCredit_monthly                                             0.035854
# creditToGovernment_monthly                                            0.016103
# creditToPrivateSector_monthly                                         0.016694
# MonetaryPolicyRate_monthly                                            0.093459
# TreasuryBillRate_monthly                                             -0.013433
# Lending_Rate_monthly                                                 -0.001615
# Exchange_Rate(USD-EOP)_monthly                                        0.022557
# GDP_AGRICULTURE(agric)_quarterly                                      0.054497
# GDP_INDUSTRY(ind)_quarterly                                           0.085926
# GDP at Current Market Prices_quarterly                                0.055555
# gdp_svc_FI_Financial Institutions_quarterly                          -0.012748
# foreign_reserve_gross(USD)_daily                                     -0.009238
# foreign_reserve_liquid(USD)_daily                                    -0.015755
#
#                                              Crude Oil Price_monthly  \
# weighted_sector_returns                                    -0.041147
# sector_volume                                               0.060906
# consumer_price_index(CPI)_monthly                           0.375653
# Inflation_allItemsAverage_monthly                           0.360264
# Premium_Motor_Spirit(PMS)_monthly                           0.014436
# Crude Oil Price_monthly                                     1.000000
# Domestic Production_monthly                                -0.585444
# Crude Oil Export_monthly                                    0.023483
# Money Supply(M2)_monthly                                    0.011084
# currency in circulation_monthly                            -0.003144
# bank reserves_monthly                                      -0.016758
# netForeignAssets_monthly                                    0.076587
# netDomesticAssets_monthly                                   0.013209
# netDomesticCredit_monthly                                   0.002431
# creditToGovernment_monthly                                  0.005475
# creditToPrivateSector_monthly                              -0.000139
# MonetaryPolicyRate_monthly                                  0.080696
# TreasuryBillRate_monthly                                    0.072776
# Lending_Rate_monthly                                       -0.122272
# Exchange_Rate(USD-EOP)_monthly                              0.005025
# GDP_AGRICULTURE(agric)_quarterly                           -0.012390
# GDP_INDUSTRY(ind)_quarterly                                -0.007936
# GDP at Current Market Prices_quarterly                     -0.012738
# gdp_svc_FI_Financial Institutions_quarterly                 0.006976
# foreign_reserve_gross(USD)_daily                            0.233760
# foreign_reserve_liquid(USD)_daily                          -0.059462
#
#                                              Domestic Production_monthly  \
# weighted_sector_returns                                        -0.030304
# sector_volume                                                  -0.108951
# consumer_price_index(CPI)_monthly                              -0.512666
# Inflation_allItemsAverage_monthly                              -0.540422
# Premium_Motor_Spirit(PMS)_monthly                              -0.031047
# Crude Oil Price_monthly                                        -0.585444
# Domestic Production_monthly                                     1.000000
# Crude Oil Export_monthly                                        0.020443
# Money Supply(M2)_monthly                                       -0.026183
# currency in circulation_monthly                                -0.021195
# bank reserves_monthly                                           0.018195
# netForeignAssets_monthly                                        0.014717
# netDomesticAssets_monthly                                      -0.016314
# netDomesticCredit_monthly                                      -0.019488
# creditToGovernment_monthly                                     -0.007683
# creditToPrivateSector_monthly                                  -0.017387
# MonetaryPolicyRate_monthly                                     -0.070467
# TreasuryBillRate_monthly                                        0.156595
# Lending_Rate_monthly                                            0.413703
# Exchange_Rate(USD-EOP)_monthly                                 -0.023251
# GDP_AGRICULTURE(agric)_quarterly                               -0.003585
# GDP_INDUSTRY(ind)_quarterly                                     0.000383
# GDP at Current Market Prices_quarterly                         -0.016440
# gdp_svc_FI_Financial Institutions_quarterly                    -0.010130
# foreign_reserve_gross(USD)_daily                                0.222371
# foreign_reserve_liquid(USD)_daily                               0.019817
#
#                                              Crude Oil Export_monthly  \
# weighted_sector_returns                                      0.028092
# sector_volume                                                0.013147
# consumer_price_index(CPI)_monthly                            0.012869
# Inflation_allItemsAverage_monthly                            0.025883
# Premium_Motor_Spirit(PMS)_monthly                            0.323752
# Crude Oil Price_monthly                                      0.023483
# Domestic Production_monthly                                  0.020443
# Crude Oil Export_monthly                                     1.000000
# Money Supply(M2)_monthly                                     0.099519
# currency in circulation_monthly                             -0.158560
# bank reserves_monthly                                        0.039866
# netForeignAssets_monthly                                    -0.000357
# netDomesticAssets_monthly                                    0.021233
# netDomesticCredit_monthly                                    0.004301
# creditToGovernment_monthly                                  -0.046637
# creditToPrivateSector_monthly                                0.073244
# MonetaryPolicyRate_monthly                                  -0.079577
# TreasuryBillRate_monthly                                     0.016074
# Lending_Rate_monthly                                         0.020171
# Exchange_Rate(USD-EOP)_monthly                               0.077740
# GDP_AGRICULTURE(agric)_quarterly                             0.031618
# GDP_INDUSTRY(ind)_quarterly                                 -0.012352
# GDP at Current Market Prices_quarterly                       0.034383
# gdp_svc_FI_Financial Institutions_quarterly                  0.082607
# foreign_reserve_gross(USD)_daily                            -0.005196
# foreign_reserve_liquid(USD)_daily                           -0.012409
#
#                                              Money Supply(M2)_monthly  \
# weighted_sector_returns                                      0.007552
# sector_volume                                                0.038449
# consumer_price_index(CPI)_monthly                            0.013772
# Inflation_allItemsAverage_monthly                            0.034992
# Premium_Motor_Spirit(PMS)_monthly                            0.025574
# Crude Oil Price_monthly                                      0.011084
# Domestic Production_monthly                                 -0.026183
# Crude Oil Export_monthly                                     0.099519
# Money Supply(M2)_monthly                                     1.000000
# currency in circulation_monthly                              0.181880
# bank reserves_monthly                                        0.207747
# netForeignAssets_monthly                                     0.010496
# netDomesticAssets_monthly                                   -0.004924
# netDomesticCredit_monthly                                    0.251478
# creditToGovernment_monthly                                  -0.063066
# creditToPrivateSector_monthly                                0.594437
# MonetaryPolicyRate_monthly                                   0.044556
# TreasuryBillRate_monthly                                    -0.047953
# Lending_Rate_monthly                                        -0.032984
# Exchange_Rate(USD-EOP)_monthly                               0.669239
# GDP_AGRICULTURE(agric)_quarterly                             0.028576
# GDP_INDUSTRY(ind)_quarterly                                  0.019237
# GDP at Current Market Prices_quarterly                       0.175865
# gdp_svc_FI_Financial Institutions_quarterly                  0.145521
# foreign_reserve_gross(USD)_daily                            -0.038235
# foreign_reserve_liquid(USD)_daily                           -0.011807
#
#                                              currency in circulation_monthly  \
# weighted_sector_returns                                            -0.012657
# sector_volume                                                       0.011591
# consumer_price_index(CPI)_monthly                                   0.011407
# Inflation_allItemsAverage_monthly                                   0.027223
# Premium_Motor_Spirit(PMS)_monthly                                   0.035051
# Crude Oil Price_monthly                                            -0.003144
# Domestic Production_monthly                                        -0.021195
# Crude Oil Export_monthly                                           -0.158560
# Money Supply(M2)_monthly                                            0.181880
# currency in circulation_monthly                                     1.000000
# bank reserves_monthly                                              -0.059934
# netForeignAssets_monthly                                           -0.002169
# netDomesticAssets_monthly                                          -0.203402
# netDomesticCredit_monthly                                           0.053074
# creditToGovernment_monthly                                          0.037315
# creditToPrivateSector_monthly                                       0.103597
# MonetaryPolicyRate_monthly                                         -0.019247
# TreasuryBillRate_monthly                                           -0.005673
# Lending_Rate_monthly                                               -0.003574
# Exchange_Rate(USD-EOP)_monthly                                      0.038894
# GDP_AGRICULTURE(agric)_quarterly                                   -0.125308
# GDP_INDUSTRY(ind)_quarterly                                         0.103426
# GDP at Current Market Prices_quarterly                             -0.017993
# gdp_svc_FI_Financial Institutions_quarterly                         0.197330
# foreign_reserve_gross(USD)_daily                                   -0.015252
# foreign_reserve_liquid(USD)_daily                                   0.015722
#
#                                              ...  MonetaryPolicyRate_monthly  \
# weighted_sector_returns                      ...                    0.013220
# sector_volume                                ...                    0.014136
# consumer_price_index(CPI)_monthly            ...                    0.023133
# Inflation_allItemsAverage_monthly            ...                    0.056620
# Premium_Motor_Spirit(PMS)_monthly            ...                    0.093459
# Crude Oil Price_monthly                      ...                    0.080696
# Domestic Production_monthly                  ...                   -0.070467
# Crude Oil Export_monthly                     ...                   -0.079577
# Money Supply(M2)_monthly                     ...                    0.044556
# currency in circulation_monthly              ...                   -0.019247
# bank reserves_monthly                        ...                   -0.014667
# netForeignAssets_monthly                     ...                    0.004099
# netDomesticAssets_monthly                    ...                   -0.012167
# netDomesticCredit_monthly                    ...                    0.078122
# creditToGovernment_monthly                   ...                    0.005298
# creditToPrivateSector_monthly                ...                    0.087129
# MonetaryPolicyRate_monthly                   ...                    1.000000
# TreasuryBillRate_monthly                     ...                    0.015492
# Lending_Rate_monthly                         ...                   -0.025327
# Exchange_Rate(USD-EOP)_monthly               ...                    0.099781
# GDP_AGRICULTURE(agric)_quarterly             ...                   -0.003968
# GDP_INDUSTRY(ind)_quarterly                  ...                    0.007397
# GDP at Current Market Prices_quarterly       ...                   -0.002078
# gdp_svc_FI_Financial Institutions_quarterly  ...                    0.067407
# foreign_reserve_gross(USD)_daily             ...                   -0.033253
# foreign_reserve_liquid(USD)_daily            ...                   -0.042540
#
#                                              TreasuryBillRate_monthly  \
# weighted_sector_returns                                      0.027303
# sector_volume                                                0.258872
# consumer_price_index(CPI)_monthly                            0.556264
# Inflation_allItemsAverage_monthly                            0.528257
# Premium_Motor_Spirit(PMS)_monthly                           -0.013433
# Crude Oil Price_monthly                                      0.072776
# Domestic Production_monthly                                  0.156595
# Crude Oil Export_monthly                                     0.016074
# Money Supply(M2)_monthly                                    -0.047953
# currency in circulation_monthly                             -0.005673
# bank reserves_monthly                                       -0.017886
# netForeignAssets_monthly                                     0.755503
# netDomesticAssets_monthly                                   -0.021499
# netDomesticCredit_monthly                                   -0.024966
# creditToGovernment_monthly                                  -0.001599
# creditToPrivateSector_monthly                               -0.036135
# MonetaryPolicyRate_monthly                                   0.015492
# TreasuryBillRate_monthly                                     1.000000
# Lending_Rate_monthly                                         0.836174
# Exchange_Rate(USD-EOP)_monthly                              -0.031395
# GDP_AGRICULTURE(agric)_quarterly                             0.012178
# GDP_INDUSTRY(ind)_quarterly                                 -0.003520
# GDP at Current Market Prices_quarterly                       0.009360
# gdp_svc_FI_Financial Institutions_quarterly                 -0.003202
# foreign_reserve_gross(USD)_daily                             0.271209
# foreign_reserve_liquid(USD)_daily                            0.132124
#
#                                              Lending_Rate_monthly  \
# weighted_sector_returns                                  0.027442
# sector_volume                                            0.260524
# consumer_price_index(CPI)_monthly                        0.419420
# Inflation_allItemsAverage_monthly                        0.296282
# Premium_Motor_Spirit(PMS)_monthly                       -0.001615
# Crude Oil Price_monthly                                 -0.122272
# Domestic Production_monthly                              0.413703
# Crude Oil Export_monthly                                 0.020171
# Money Supply(M2)_monthly                                -0.032984
# currency in circulation_monthly                         -0.003574
# bank reserves_monthly                                    0.009155
# netForeignAssets_monthly                                 0.680132
# netDomesticAssets_monthly                               -0.014652
# netDomesticCredit_monthly                               -0.028692
# creditToGovernment_monthly                              -0.008610
# creditToPrivateSector_monthly                           -0.026776
# MonetaryPolicyRate_monthly                              -0.025327
# TreasuryBillRate_monthly                                 0.836174
# Lending_Rate_monthly                                     1.000000
# Exchange_Rate(USD-EOP)_monthly                          -0.029856
# GDP_AGRICULTURE(agric)_quarterly                         0.002839
# GDP_INDUSTRY(ind)_quarterly                             -0.010455
# GDP at Current Market Prices_quarterly                   0.004592
# gdp_svc_FI_Financial Institutions_quarterly              0.000499
# foreign_reserve_gross(USD)_daily                         0.389773
# foreign_reserve_liquid(USD)_daily                        0.146091
#
#                                              Exchange_Rate(USD-EOP)_monthly  \
# weighted_sector_returns                                            0.045452
# sector_volume                                                      0.021206
# consumer_price_index(CPI)_monthly                                  0.006356
# Inflation_allItemsAverage_monthly                                  0.028604
# Premium_Motor_Spirit(PMS)_monthly                                  0.022557
# Crude Oil Price_monthly                                            0.005025
# Domestic Production_monthly                                       -0.023251
# Crude Oil Export_monthly                                           0.077740
# Money Supply(M2)_monthly                                           0.669239
# currency in circulation_monthly                                    0.038894
# bank reserves_monthly                                             -0.036388
# netForeignAssets_monthly                                           0.001571
# netDomesticAssets_monthly                                         -0.001474
# netDomesticCredit_monthly                                          0.296164
# creditToGovernment_monthly                                         0.026521
# creditToPrivateSector_monthly                                      0.583946
# MonetaryPolicyRate_monthly                                         0.099781
# TreasuryBillRate_monthly                                          -0.031395
# Lending_Rate_monthly                                              -0.029856
# Exchange_Rate(USD-EOP)_monthly                                     1.000000
# GDP_AGRICULTURE(agric)_quarterly                                   0.043343
# GDP_INDUSTRY(ind)_quarterly                                       -0.008754
# GDP at Current Market Prices_quarterly                             0.006221
# gdp_svc_FI_Financial Institutions_quarterly                       -0.070331
# foreign_reserve_gross(USD)_daily                                  -0.046861
# foreign_reserve_liquid(USD)_daily                                 -0.042075
#
#                                              GDP_AGRICULTURE(agric)_quarterly  \
# weighted_sector_returns                                             -0.035434
# sector_volume                                                       -0.001449
# consumer_price_index(CPI)_monthly                                    0.000651
# Inflation_allItemsAverage_monthly                                    0.011589
# Premium_Motor_Spirit(PMS)_monthly                                    0.054497
# Crude Oil Price_monthly                                             -0.012390
# Domestic Production_monthly                                         -0.003585
# Crude Oil Export_monthly                                             0.031618
# Money Supply(M2)_monthly                                             0.028576
# currency in circulation_monthly                                     -0.125308
# bank reserves_monthly                                                0.018737
# netForeignAssets_monthly                                             0.005203
# netDomesticAssets_monthly                                            0.006511
# netDomesticCredit_monthly                                            0.235206
# creditToGovernment_monthly                                           0.126629
# creditToPrivateSector_monthly                                        0.154439
# MonetaryPolicyRate_monthly                                          -0.003968
# TreasuryBillRate_monthly                                             0.012178
# Lending_Rate_monthly                                                 0.002839
# Exchange_Rate(USD-EOP)_monthly                                       0.043343
# GDP_AGRICULTURE(agric)_quarterly                                     1.000000
# GDP_INDUSTRY(ind)_quarterly                                          0.363874
# GDP at Current Market Prices_quarterly                               0.816518
# gdp_svc_FI_Financial Institutions_quarterly                         -0.347082
# foreign_reserve_gross(USD)_daily                                    -0.013307
# foreign_reserve_liquid(USD)_daily                                    0.043229
#
#                                              GDP_INDUSTRY(ind)_quarterly  \
# weighted_sector_returns                                        -0.002806
# sector_volume                                                  -0.000178
# consumer_price_index(CPI)_monthly                              -0.009626
# Inflation_allItemsAverage_monthly                               0.005814
# Premium_Motor_Spirit(PMS)_monthly                               0.085926
# Crude Oil Price_monthly                                        -0.007936
# Domestic Production_monthly                                     0.000383
# Crude Oil Export_monthly                                       -0.012352
# Money Supply(M2)_monthly                                        0.019237
# currency in circulation_monthly                                 0.103426
# bank reserves_monthly                                           0.060859
# netForeignAssets_monthly                                       -0.029024
# netDomesticAssets_monthly                                       0.005696
# netDomesticCredit_monthly                                       0.138512
# creditToGovernment_monthly                                      0.097320
# creditToPrivateSector_monthly                                  -0.010948
# MonetaryPolicyRate_monthly                                      0.007397
# TreasuryBillRate_monthly                                       -0.003520
# Lending_Rate_monthly                                           -0.010455
# Exchange_Rate(USD-EOP)_monthly                                 -0.008754
# GDP_AGRICULTURE(agric)_quarterly                                0.363874
# GDP_INDUSTRY(ind)_quarterly                                     1.000000
# GDP at Current Market Prices_quarterly                          0.361502
# gdp_svc_FI_Financial Institutions_quarterly                    -0.222106
# foreign_reserve_gross(USD)_daily                                0.025980
# foreign_reserve_liquid(USD)_daily                               0.088020
#
#                                              GDP at Current Market Prices_quarterly  \
# weighted_sector_returns                                                   -0.012243
# sector_volume                                                              0.010839
# consumer_price_index(CPI)_monthly                                          0.018593
# Inflation_allItemsAverage_monthly                                          0.024600
# Premium_Motor_Spirit(PMS)_monthly                                          0.055555
# Crude Oil Price_monthly                                                   -0.012738
# Domestic Production_monthly                                               -0.016440
# Crude Oil Export_monthly                                                   0.034383
# Money Supply(M2)_monthly                                                   0.175865
# currency in circulation_monthly                                           -0.017993
# bank reserves_monthly                                                      0.072784
# netForeignAssets_monthly                                                   0.022107
# netDomesticAssets_monthly                                                  0.005742
# netDomesticCredit_monthly                                                  0.202170
# creditToGovernment_monthly                                                 0.119424
# creditToPrivateSector_monthly                                              0.113516
# MonetaryPolicyRate_monthly                                                -0.002078
# TreasuryBillRate_monthly                                                   0.009360
# Lending_Rate_monthly                                                       0.004592
# Exchange_Rate(USD-EOP)_monthly                                             0.006221
# GDP_AGRICULTURE(agric)_quarterly                                           0.816518
# GDP_INDUSTRY(ind)_quarterly                                                0.361502
# GDP at Current Market Prices_quarterly                                     1.000000
# gdp_svc_FI_Financial Institutions_quarterly                               -0.068956
# foreign_reserve_gross(USD)_daily                                          -0.007059
# foreign_reserve_liquid(USD)_daily                                          0.055286
#
#                                              gdp_svc_FI_Financial Institutions_quarterly  \
# weighted_sector_returns                                                         0.021613
# sector_volume                                                                  -0.000091
# consumer_price_index(CPI)_monthly                                               0.016886
# Inflation_allItemsAverage_monthly                                               0.028755
# Premium_Motor_Spirit(PMS)_monthly                                              -0.012748
# Crude Oil Price_monthly                                                         0.006976
# Domestic Production_monthly                                                    -0.010130
# Crude Oil Export_monthly                                                        0.082607
# Money Supply(M2)_monthly                                                        0.145521
# currency in circulation_monthly                                                 0.197330
# bank reserves_monthly                                                           0.096139
# netForeignAssets_monthly                                                       -0.008187
# netDomesticAssets_monthly                                                       0.017943
# netDomesticCredit_monthly                                                      -0.047269
# creditToGovernment_monthly                                                     -0.003599
# creditToPrivateSector_monthly                                                  -0.044908
# MonetaryPolicyRate_monthly                                                      0.067407
# TreasuryBillRate_monthly                                                       -0.003202
# Lending_Rate_monthly                                                            0.000499
# Exchange_Rate(USD-EOP)_monthly                                                 -0.070331
# GDP_AGRICULTURE(agric)_quarterly                                               -0.347082
# GDP_INDUSTRY(ind)_quarterly                                                    -0.222106
# GDP at Current Market Prices_quarterly                                         -0.068956
# gdp_svc_FI_Financial Institutions_quarterly                                     1.000000
# foreign_reserve_gross(USD)_daily                                               -0.007969
# foreign_reserve_liquid(USD)_daily                                               0.009691
#
#                                              foreign_reserve_gross(USD)_daily  \
# weighted_sector_returns                                             -0.060494
# sector_volume                                                        0.113776
# consumer_price_index(CPI)_monthly                                    0.214241
# Inflation_allItemsAverage_monthly                                   -0.150351
# Premium_Motor_Spirit(PMS)_monthly                                   -0.009238
# Crude Oil Price_monthly                                              0.233760
# Domestic Production_monthly                                          0.222371
# Crude Oil Export_monthly                                            -0.005196
# Money Supply(M2)_monthly                                            -0.038235
# currency in circulation_monthly                                     -0.015252
# bank reserves_monthly                                               -0.013255
# netForeignAssets_monthly                                             0.356095
# netDomesticAssets_monthly                                           -0.008721
# netDomesticCredit_monthly                                           -0.004470
# creditToGovernment_monthly                                           0.000620
# creditToPrivateSector_monthly                                       -0.024239
# MonetaryPolicyRate_monthly                                          -0.033253
# TreasuryBillRate_monthly                                             0.271209
# Lending_Rate_monthly                                                 0.389773
# Exchange_Rate(USD-EOP)_monthly                                      -0.046861
# GDP_AGRICULTURE(agric)_quarterly                                    -0.013307
# GDP_INDUSTRY(ind)_quarterly                                          0.025980
# GDP at Current Market Prices_quarterly                              -0.007059
# gdp_svc_FI_Financial Institutions_quarterly                         -0.007969
# foreign_reserve_gross(USD)_daily                                     1.000000
# foreign_reserve_liquid(USD)_daily                                    0.032382
#
#                                              foreign_reserve_liquid(USD)_daily
# weighted_sector_returns                                               0.042313
# sector_volume                                                         0.089309
# consumer_price_index(CPI)_monthly                                     0.076734
# Inflation_allItemsAverage_monthly                                     0.132869
# Premium_Motor_Spirit(PMS)_monthly                                    -0.015755
# Crude Oil Price_monthly                                              -0.059462
# Domestic Production_monthly                                           0.019817
# Crude Oil Export_monthly                                             -0.012409
# Money Supply(M2)_monthly                                             -0.011807
# currency in circulation_monthly                                       0.015722
# bank reserves_monthly                                                -0.001342
# netForeignAssets_monthly                                              0.076900
# netDomesticAssets_monthly                                            -0.004760
# netDomesticCredit_monthly                                             0.018123
# creditToGovernment_monthly                                           -0.016709
# creditToPrivateSector_monthly                                         0.017480
# MonetaryPolicyRate_monthly                                           -0.042540
# TreasuryBillRate_monthly                                              0.132124
# Lending_Rate_monthly                                                  0.146091
# Exchange_Rate(USD-EOP)_monthly                                       -0.042075
# GDP_AGRICULTURE(agric)_quarterly                                      0.043229
# GDP_INDUSTRY(ind)_quarterly                                           0.088020
# GDP at Current Market Prices_quarterly                                0.055286
# gdp_svc_FI_Financial Institutions_quarterly                           0.009691
# foreign_reserve_gross(USD)_daily                                      0.032382
# foreign_reserve_liquid(USD)_daily                                     1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# ### FANTASTIC!!!
#
# We have handled the issue of multicollinearity. Percent change has a better economic meaning than the actual values.

# %%
## Independent features
X=financial_sec_feat.drop(columns=['weighted_sector_returns'])

# %%
## dependent features
y=financial_sec_feat['weighted_sector_returns']

# %%
## Apply standard scaler
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# %%
# X: independent features, y: sector returns
# CRITICAL: X and y must already be sorted by date, ascending
# X = X.sort_values('date')  # or however df is indexed. Our df is 
# y = y.loc[X.index]

tscv = TimeSeriesSplit(n_splits=5)  # 5 sequential folds

rmse_scores = []
r2scores = []
for fold, (train_idx, test_idx) in enumerate(tscv.split(X)):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx] ## This area uses the index to pick the data from X and y
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    ## Apply standardscaler to standardize the data
    # Fit to the training data (calculates mean and std)
    scaler.fit(X_train)

    # Transform the training and testing data
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)


    model = Ridge(alpha=1.0)
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)

    rmse = np.sqrt(mean_squared_error(y_test, preds))
    rmse_scores.append(rmse)

    r2_=r2_score(y_true=y_test,y_pred=preds)
    r2scores.append(r2_)

    print(f"Fold {fold}: train={len(X_train)} rows ({X_train.index.min()} to {X_train.index.max()}), "
          f"test={len(X_test)} rows ({X_test.index.min()} to {X_test.index.max()}), RMSE={rmse:.4f}, r2score={r2_:.4f}")
    
print(f"\nMean RMSE across folds: {np.mean(rmse_scores):.4f}")
print(f"\nMean R2_score across folds: {np.mean(r2scores):.4f}")
# Out:
# Fold 0: train=360 rows (66 to 426), test=358 rows (427 to 787), RMSE=7.9962, r2score=-16.1008
# Fold 1: train=718 rows (66 to 787), test=358 rows (788 to 1158), RMSE=2.8566, r2score=-2.4645
# Fold 2: train=1076 rows (66 to 1158), test=358 rows (1159 to 1527), RMSE=1.3649, r2score=-1.1822
# Fold 3: train=1434 rows (66 to 1527), test=358 rows (1529 to 1912), RMSE=2.1874, r2score=-0.1836
# Fold 4: train=1792 rows (66 to 1912), test=358 rows (1913 to 2277), RMSE=1.5165, r2score=-0.0187
#
# Mean RMSE across folds: 3.1843
#
# Mean R2_score across folds: -3.9899

# %% [markdown]
# ## VERY, VERY BAD! Please revisit.

# %% [markdown]
# # NGX PRACTICE

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
ngx_api_key=os.getenv("NGX_API_KEY")

ngx_market_url = "https://www.ngxpulse.ng/api/ngxdata/market"
ngx_stocks_url = "https://www.ngxpulse.ng/api/ngxdata/stocks"

headers = {
    "X-API-Key": f"{ngx_api_key}",
    "Content-Type": "application/json"
}

# %%
response = requests.get(ngx_stocks_url, headers=headers)

print(response.status_code)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(response.text)
# Out:
# 200
# {'stocks': [{'symbol': 'AIRTELAFRI', 'name': 'Airtel Africa Plc', 'current_price': 5801.4, 'previous_close': 5801.4, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 7865, 'market_cap': 21802540135305.598, 'shares_outstanding': 3758151504, 'sector': 'ICT', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'DANGCEM', 'name': 'Dangote Cement Plc', 'current_price': 1047, 'previous_close': 1047, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 388188, 'market_cap': 17666616535797, 'shares_outstanding': 16873559251, 'sector': 'INDUSTRIAL GOODS', 'market': 'Premium Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'MTNN', 'name': 'MTN Nigeria Communications Plc', 'current_price': 826.5, 'previous_close': 823.5, 'change_percent': 0.36, 'official_change_percent': 0.36, 'pct_change_7d': 2.04, 'volume': 1405579, 'market_cap': 17352830425129.5, 'shares_outstanding': 20995560103, 'sector': 'ICT', 'market': 'Premium Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'BUAFOODS', 'name': 'BUA Foods Plc', 'current_price': 939, 'previous_close': 939, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 67968, 'market_cap': 16902000000000, 'shares_outstanding': 18000000000, 'sector': 'CONSUMER GOODS', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'BUACEMENT', 'name': 'BUA Cement Plc', 'current_price': 275.6, 'previous_close': 275.6, 'change_percent': -0.58, 'official_change_percent': -0.58, 'pct_change_7d': -18.99, 'volume': 17411684, 'market_cap': 9333015978936, 'shares_outstanding': 33864354060, 'sector': 'INDUSTRIAL GOODS', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'SEPLAT', 'name': 'Seplat Energy Plc', 'current_price': 11363.9, 'previous_close': 11363.9, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 56856, 'market_cap': 6817709996747.899, 'shares_outstanding': 599944561, 'sector': 'OIL AND GAS', 'market': 'Premium Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'ARADEL', 'name': 'Aradel Holdings Plc', 'current_price': 1526.8, 'previous_close': 1526.8, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 512357, 'market_cap': 6633708368848, 'shares_outstanding': 4344844360, 'sector': 'OIL AND GAS', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'GTCO', 'name': 'Guaranty Trust Holding Company Plc', 'current_price': 129.2, 'previous_close': 127, 'change_percent': 1.73, 'official_change_percent': 1.73, 'pct_change_7d': 2.54, 'volume': 9579089, 'market_cap': 4722289653208.8, 'shares_outstanding': 36550229514, 'sector': 'FINANCIAL SERVICES', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'ZENITHBANK', 'name': 'Zenith Bank Plc', 'current_price': 114, 'previous_close': 111, 'change_percent': 2.7, 'official_change_percent': 2.7, 'pct_change_7d': 2.89, 'volume': 41520455, 'market_cap': 4681960620000, 'shares_outstanding': 41069830000, 'sector': 'FINANCIAL SERVICES', 'market': 'Premium Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'FIRSTHOLDCO', 'name': 'First HoldCo Plc', 'current_price': 95.95, 'previous_close': 87.25, 'change_percent': 9.97, 'official_change_percent': 9.97, 'pct_change_7d': 38.66, 'volume': 225912721, 'market_cap': 4265331856207.3003, 'shares_outstanding': 44453693134, 'sector': 'FINANCIAL SERVICES', 'market': 'Premium Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'PRESCO', 'name': 'Presco Plc', 'current_price': 2300, 'previous_close': 2300, 'change_percent': 0, 'official_change_percent': None, 'pct_change_7d': 0, 'volume': 128724, 'market_cap': 2683333334100, 'shares_outstanding': 1166666667, 'sector': 'AGRICULTURE', 'market': 'Main Board', 'trade_date': '2026-07-17T00:00:00'}, {'symbol': 'STANBIC', 'name': 'Stanbic IBTC Holdings Plc', 'current_price': 166.9, 'previous_close': 166.9, 'chang ...

# %%
len(data['stocks'])
# Out:
# 146

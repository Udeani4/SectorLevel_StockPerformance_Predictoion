# %% [markdown]
# ## Monthly Data Training
#
# We will sort the daily data to fit monthly

# %%
import pandas as pd
from datetime import datetime as dt

# 1. Generate the date range from January 1, 2017, up to today
date_series = pd.date_range(start='2017-01-01', end=dt.now(), freq='ME')

# 2. Create the DataFrame and format the dates as %Y-%m-%d
df = pd.DataFrame()
df['date'] = date_series.strftime('%Y-%m-%d')

# %%
df
# Out:
#            date
# 0    2017-01-31
# 1    2017-02-28
# 2    2017-03-31
# 3    2017-04-30
# 4    2017-05-31
# ..          ...
# 110  2026-03-31
# 111  2026-04-30
# 112  2026-05-31
# 113  2026-06-30
# 114  2026-07-31
#
# [115 rows x 1 columns]

# %%
md=pd.read_csv('macroeconomic_data/macro_data(csv)')
md
# Out:
#        year      month  month_idx  consumer_price_index(CPI)_monthly  \
# 0    2017.0    january          1                         198.041241
# 1       NaN   february          2                         201.001141
# 2       NaN      march          3                         204.456610
# 3       NaN      april          4                         207.729678
# 4       NaN        may          5                         211.637809
# ..      ...        ...        ...                                ...
# 115     NaN     august          8                                NaN
# 116     NaN  september          9                                NaN
# 117     NaN    october         10                                NaN
# 118     NaN   november         11                                NaN
# 119     NaN   december         12                                NaN
#
#      Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                      55.01                         1.84
# 1                      46.39                         1.82
# 2                      52.13                         1.60
# 3                      52.94                         1.79
# 4                      50.57                         1.87
# ..                       ...                          ...
# 115                      NaN                          NaN
# 116                      NaN                          NaN
# 117                      NaN                          NaN
# 118                      NaN                          NaN
# 119                      NaN                          NaN
#
#      Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                        1.39                              16.44
# 1                        1.37                              16.96
# 2                        1.15                              17.32
# 3                        1.34                              17.59
# 4                        1.42                              17.63
# ..                        ...                                ...
# 115                       NaN                                NaN
# 116                       NaN                                NaN
# 117                       NaN                                NaN
# 118                       NaN                                NaN
# 119                       NaN                                NaN
#
#      Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0                 23096526.55                       1994577.62  ...
# 1                 22210954.84                       1978886.94  ...
# 2                 22304267.84                       1983633.07  ...
# 3                 21768241.12                       1975812.32  ...
# 4                 22047770.68                       1897917.15  ...
# ..                        ...                              ...  ...
# 115                       NaN                              NaN  ...
# 116                       NaN                              NaN  ...
# 117                       NaN                              NaN  ...
# 118                       NaN                              NaN  ...
# 119                       NaN                              NaN  ...
#
#      gdp_svc_Public Administration_quarterly  gdp_svc_Education_quarterly  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                     680.04                       587.79
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ..                                       ...                          ...
# 115                                      NaN                          NaN
# 116                                      NaN                          NaN
# 117                                      NaN                          NaN
# 118                                      NaN                          NaN
# 119                                      NaN                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    01/31/2017                        2.817423e+10
# 1    02/28/2017                        2.964668e+10
# 2    03/31/2017                        3.029795e+10
# 3    04/28/2017                        3.086463e+10
# 4    05/31/2017                        3.032964e+10
# ..          ...                                 ...
# 115  07/16/2026                        5.191564e+10
# 116         NaN                                 NaN
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly
# 0                           2.745703e+10
# 1                           2.894094e+10
# 2                           2.962647e+10
# 3                           3.017061e+10
# 4                           2.961376e+10
# ..                                   ...
# 115                         5.129593e+10
# 116                                  NaN
# 117                                  NaN
# 118                                  NaN
# 119                                  NaN
#
# [120 rows x 81 columns]

# %%
mde=pd.read_excel('macroeconomic_data/NGX_Macro_project_data(complete).xlsx')
mde
# Out:
#        year      month  month_idx  consumer_price_index(CPI)_monthly  \
# 0    2017.0    january          1                         198.041241
# 1       NaN   february          2                         201.001141
# 2       NaN      march          3                         204.456610
# 3       NaN      april          4                         207.729678
# 4       NaN        may          5                         211.637809
# ..      ...        ...        ...                                ...
# 115     NaN     august          8                                NaN
# 116     NaN  september          9                                NaN
# 117     NaN    october         10                                NaN
# 118     NaN   november         11                                NaN
# 119     NaN   december         12                                NaN
#
#      Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                      55.01                         1.84
# 1                      46.39                         1.82
# 2                      52.13                         1.60
# 3                      52.94                         1.79
# 4                      50.57                         1.87
# ..                       ...                          ...
# 115                      NaN                          NaN
# 116                      NaN                          NaN
# 117                      NaN                          NaN
# 118                      NaN                          NaN
# 119                      NaN                          NaN
#
#      Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                        1.39                              16.44
# 1                        1.37                              16.96
# 2                        1.15                              17.32
# 3                        1.34                              17.59
# 4                        1.42                              17.63
# ..                        ...                                ...
# 115                       NaN                                NaN
# 116                       NaN                                NaN
# 117                       NaN                                NaN
# 118                       NaN                                NaN
# 119                       NaN                                NaN
#
#      Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0                 23096526.55                       1994577.62  ...
# 1                 22210954.84                       1978886.94  ...
# 2                 22304267.84                       1983633.07  ...
# 3                 21768241.12                       1975812.32  ...
# 4                 22047770.68                       1897917.15  ...
# ..                        ...                              ...  ...
# 115                       NaN                              NaN  ...
# 116                       NaN                              NaN  ...
# 117                       NaN                              NaN  ...
# 118                       NaN                              NaN  ...
# 119                       NaN                              NaN  ...
#
#      gdp_svc_Public Administration_quarterly  gdp_svc_Education_quarterly  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                     680.04                       587.79
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ..                                       ...                          ...
# 115                                      NaN                          NaN
# 116                                      NaN                          NaN
# 117                                      NaN                          NaN
# 118                                      NaN                          NaN
# 119                                      NaN                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    01/31/2017                        2.817423e+10
# 1    02/28/2017                        2.964668e+10
# 2    03/31/2017                        3.029795e+10
# 3    04/28/2017                        3.086463e+10
# 4    05/31/2017                        3.032964e+10
# ..          ...                                 ...
# 115  07/16/2026                        5.191564e+10
# 116         NaN                                 NaN
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly
# 0                           2.745703e+10
# 1                           2.894094e+10
# 2                           2.962647e+10
# 3                           3.017061e+10
# 4                           2.961376e+10
# ..                                   ...
# 115                         5.129593e+10
# 116                                  NaN
# 117                                  NaN
# 118                                  NaN
# 119                                  NaN
#
# [120 rows x 81 columns]

# %%
mde2=pd.read_excel('macroeconomic_data/NGX_Macro_project_data(complete22).xlsx')
mde2
# Out:
#        year      month  month_idx  consumer_price_index(CPI)_monthly  \
# 0    2017.0    january          1                         198.041241
# 1       NaN   february          2                         201.001141
# 2       NaN      march          3                         204.456610
# 3       NaN      april          4                         207.729678
# 4       NaN        may          5                         211.637809
# ..      ...        ...        ...                                ...
# 115     NaN     august          8                                NaN
# 116     NaN  september          9                                NaN
# 117     NaN    october         10                                NaN
# 118     NaN   november         11                                NaN
# 119     NaN   december         12                                NaN
#
#      Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                      55.01                         1.84
# 1                      46.39                         1.82
# 2                      52.13                         1.60
# 3                      52.94                         1.79
# 4                      50.57                         1.87
# ..                       ...                          ...
# 115                      NaN                          NaN
# 116                      NaN                          NaN
# 117                      NaN                          NaN
# 118                      NaN                          NaN
# 119                      NaN                          NaN
#
#      Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                        1.39                              16.44
# 1                        1.37                              16.96
# 2                        1.15                              17.32
# 3                        1.34                              17.59
# 4                        1.42                              17.63
# ..                        ...                                ...
# 115                       NaN                                NaN
# 116                       NaN                                NaN
# 117                       NaN                                NaN
# 118                       NaN                                NaN
# 119                       NaN                                NaN
#
#      Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0                 23096526.55                       1994577.62  ...
# 1                 22210954.84                       1978886.94  ...
# 2                 22304267.84                       1983633.07  ...
# 3                 21768241.12                       1975812.32  ...
# 4                 22047770.68                       1897917.15  ...
# ..                        ...                              ...  ...
# 115                       NaN                              NaN  ...
# 116                       NaN                              NaN  ...
# 117                       NaN                              NaN  ...
# 118                       NaN                              NaN  ...
# 119                       NaN                              NaN  ...
#
#      gdp_svc_Public Administration_quarterly  gdp_svc_Education_quarterly  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                     680.04                       587.79
# 3                                     680.04                       587.79
# 4                                     680.04                       587.79
# ..                                       ...                          ...
# 115                                      NaN                          NaN
# 116                                      NaN                          NaN
# 117                                      NaN                          NaN
# 118                                      NaN                          NaN
# 119                                      NaN                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    01/31/2017                        2.817423e+10
# 1    02/28/2017                        2.964668e+10
# 2    03/31/2017                        3.029795e+10
# 3    04/28/2017                        3.086463e+10
# 4    05/31/2017                        3.032964e+10
# ..          ...                                 ...
# 115  07/16/2026                        5.191564e+10
# 116         NaN                                 NaN
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly
# 0                           2.745703e+10
# 1                           2.894094e+10
# 2                           2.962647e+10
# 3                           3.017061e+10
# 4                           2.961376e+10
# ..                                   ...
# 115                         5.129593e+10
# 116                                  NaN
# 117                                  NaN
# 118                                  NaN
# 119                                  NaN
#
# [120 rows x 81 columns]

# %%
mde2['FR_Date'] = pd.to_datetime(mde2['FR_Date']).dt.strftime('%Y-%m-%d')

# %%
mde2["date"] = pd.date_range(
    start="2017-01-31",
    periods=len(mde2),
    freq="ME"
)

# %%
mde2
# Out:
#        year      month  month_idx  consumer_price_index(CPI)_monthly  \
# 0    2017.0    january          1                         198.041241
# 1       NaN   february          2                         201.001141
# 2       NaN      march          3                         204.456610
# 3       NaN      april          4                         207.729678
# 4       NaN        may          5                         211.637809
# ..      ...        ...        ...                                ...
# 115     NaN     august          8                                NaN
# 116     NaN  september          9                                NaN
# 117     NaN    october         10                                NaN
# 118     NaN   november         11                                NaN
# 119     NaN   december         12                                NaN
#
#      Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                      55.01                         1.84
# 1                      46.39                         1.82
# 2                      52.13                         1.60
# 3                      52.94                         1.79
# 4                      50.57                         1.87
# ..                       ...                          ...
# 115                      NaN                          NaN
# 116                      NaN                          NaN
# 117                      NaN                          NaN
# 118                      NaN                          NaN
# 119                      NaN                          NaN
#
#      Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                        1.39                              16.44
# 1                        1.37                              16.96
# 2                        1.15                              17.32
# 3                        1.34                              17.59
# 4                        1.42                              17.63
# ..                        ...                                ...
# 115                       NaN                                NaN
# 116                       NaN                                NaN
# 117                       NaN                                NaN
# 118                       NaN                                NaN
# 119                       NaN                                NaN
#
#      Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0                 23096526.55                       1994577.62  ...
# 1                 22210954.84                       1978886.94  ...
# 2                 22304267.84                       1983633.07  ...
# 3                 21768241.12                       1975812.32  ...
# 4                 22047770.68                       1897917.15  ...
# ..                        ...                              ...  ...
# 115                       NaN                              NaN  ...
# 116                       NaN                              NaN  ...
# 117                       NaN                              NaN  ...
# 118                       NaN                              NaN  ...
# 119                       NaN                              NaN  ...
#
#      gdp_svc_Education_quarterly  \
# 0                            NaN
# 1                            NaN
# 2                         587.79
# 3                         587.79
# 4                         587.79
# ..                           ...
# 115                          NaN
# 116                          NaN
# 117                          NaN
# 118                          NaN
# 119                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                        2.817423e+10
# 1    2017-02-28                        2.964668e+10
# 2    2017-03-31                        3.029795e+10
# 3    2017-04-28                        3.086463e+10
# 4    2017-05-31                        3.032964e+10
# ..          ...                                 ...
# 115  2026-07-16                        5.191564e+10
# 116         NaN                                 NaN
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date
# 0                           2.745703e+10 2017-01-31
# 1                           2.894094e+10 2017-02-28
# 2                           2.962647e+10 2017-03-31
# 3                           3.017061e+10 2017-04-30
# 4                           2.961376e+10 2017-05-31
# ..                                   ...        ...
# 115                         5.129593e+10 2026-08-31
# 116                                  NaN 2026-09-30
# 117                                  NaN 2026-10-31
# 118                                  NaN 2026-11-30
# 119                                  NaN 2026-12-31
#
# [120 rows x 82 columns]

# %% [markdown]
# shift the foreign reserve data to avoid look ahead bias we will shift the monthly data by 1 month. So the information is used to predict the next months returns.

# %%
mde2[['foreign_reserve_Gross(USD)_monthly','foreign_reserve_Liquid(USD)_monthly']]=mde2[['foreign_reserve_Gross(USD)_monthly','foreign_reserve_Liquid(USD)_monthly']].shift(1)

# %%
mde2
# Out:
#        year      month  month_idx  consumer_price_index(CPI)_monthly  \
# 0    2017.0    january          1                         198.041241
# 1       NaN   february          2                         201.001141
# 2       NaN      march          3                         204.456610
# 3       NaN      april          4                         207.729678
# 4       NaN        may          5                         211.637809
# ..      ...        ...        ...                                ...
# 115     NaN     august          8                                NaN
# 116     NaN  september          9                                NaN
# 117     NaN    october         10                                NaN
# 118     NaN   november         11                                NaN
# 119     NaN   december         12                                NaN
#
#      Crude Oil Price_monthly  Domestic Production_monthly  \
# 0                      55.01                         1.84
# 1                      46.39                         1.82
# 2                      52.13                         1.60
# 3                      52.94                         1.79
# 4                      50.57                         1.87
# ..                       ...                          ...
# 115                      NaN                          NaN
# 116                      NaN                          NaN
# 117                      NaN                          NaN
# 118                      NaN                          NaN
# 119                      NaN                          NaN
#
#      Crude Oil Export_monthly  Inflation_allItemsAverage_monthly  \
# 0                        1.39                              16.44
# 1                        1.37                              16.96
# 2                        1.15                              17.32
# 3                        1.34                              17.59
# 4                        1.42                              17.63
# ..                        ...                                ...
# 115                       NaN                                NaN
# 116                       NaN                                NaN
# 117                       NaN                                NaN
# 118                       NaN                                NaN
# 119                       NaN                                NaN
#
#      Money Supply(M2)_monthly  currency in circulation_monthly  ...  \
# 0                 23096526.55                       1994577.62  ...
# 1                 22210954.84                       1978886.94  ...
# 2                 22304267.84                       1983633.07  ...
# 3                 21768241.12                       1975812.32  ...
# 4                 22047770.68                       1897917.15  ...
# ..                        ...                              ...  ...
# 115                       NaN                              NaN  ...
# 116                       NaN                              NaN  ...
# 117                       NaN                              NaN  ...
# 118                       NaN                              NaN  ...
# 119                       NaN                              NaN  ...
#
#      gdp_svc_Education_quarterly  \
# 0                            NaN
# 1                            NaN
# 2                         587.79
# 3                         587.79
# 4                         587.79
# ..                           ...
# 115                          NaN
# 116                          NaN
# 117                          NaN
# 118                          NaN
# 119                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                                 NaN
# 1    2017-02-28                        2.817423e+10
# 2    2017-03-31                        2.964668e+10
# 3    2017-04-28                        3.029795e+10
# 4    2017-05-31                        3.086463e+10
# ..          ...                                 ...
# 115  2026-07-16                        5.145923e+10
# 116         NaN                        5.191564e+10
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date
# 0                                    NaN 2017-01-31
# 1                           2.745703e+10 2017-02-28
# 2                           2.894094e+10 2017-03-31
# 3                           2.962647e+10 2017-04-30
# 4                           3.017061e+10 2017-05-31
# ..                                   ...        ...
# 115                         5.081045e+10 2026-08-31
# 116                         5.129593e+10 2026-09-30
# 117                                  NaN 2026-10-31
# 118                                  NaN 2026-11-30
# 119                                  NaN 2026-12-31
#
# [120 rows x 82 columns]

# %%
mde3=mde2.drop(columns=['year','month','month_idx'])

# %%
mde3
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 0                           198.041241                    55.01
# 1                           201.001141                    46.39
# 2                           204.456610                    52.13
# 3                           207.729678                    52.94
# 4                           211.637809                    50.57
# ..                                 ...                      ...
# 115                                NaN                      NaN
# 116                                NaN                      NaN
# 117                                NaN                      NaN
# 118                                NaN                      NaN
# 119                                NaN                      NaN
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 0                           1.84                      1.39
# 1                           1.82                      1.37
# 2                           1.60                      1.15
# 3                           1.79                      1.34
# 4                           1.87                      1.42
# ..                           ...                       ...
# 115                          NaN                       NaN
# 116                          NaN                       NaN
# 117                          NaN                       NaN
# 118                          NaN                       NaN
# 119                          NaN                       NaN
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 0                                16.44               23096526.55
# 1                                16.96               22210954.84
# 2                                17.32               22304267.84
# 3                                17.59               21768241.12
# 4                                17.63               22047770.68
# ..                                 ...                       ...
# 115                                NaN                       NaN
# 116                                NaN                       NaN
# 117                                NaN                       NaN
# 118                                NaN                       NaN
# 119                                NaN                       NaN
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 0                         1994577.62             3311609.44
# 1                         1978886.94             3234760.81
# 2                         1983633.07             3309947.53
# 3                         1975812.32             3536407.29
# 4                         1897917.15             3254006.25
# ..                               ...                    ...
# 115                              NaN                    NaN
# 116                              NaN                    NaN
# 117                              NaN                    NaN
# 118                              NaN                    NaN
# 119                              NaN                    NaN
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 0                  9473002.48                19005647.02  ...
# 1                  7977399.24                19746640.86  ...
# 2                  7628543.46                20342546.55  ...
# 3                  7269852.64                20347360.25  ...
# 4                  8540084.49                19499233.11  ...
# ..                        ...                        ...  ...
# 115                       NaN                        NaN  ...
# 116                       NaN                        NaN  ...
# 117                       NaN                        NaN  ...
# 118                       NaN                        NaN  ...
# 119                       NaN                        NaN  ...
#
#      gdp_svc_Education_quarterly  \
# 0                            NaN
# 1                            NaN
# 2                         587.79
# 3                         587.79
# 4                         587.79
# ..                           ...
# 115                          NaN
# 116                          NaN
# 117                          NaN
# 118                          NaN
# 119                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                                 NaN
# 1    2017-02-28                        2.817423e+10
# 2    2017-03-31                        2.964668e+10
# 3    2017-04-28                        3.029795e+10
# 4    2017-05-31                        3.086463e+10
# ..          ...                                 ...
# 115  2026-07-16                        5.145923e+10
# 116         NaN                        5.191564e+10
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date
# 0                                    NaN 2017-01-31
# 1                           2.745703e+10 2017-02-28
# 2                           2.894094e+10 2017-03-31
# 3                           2.962647e+10 2017-04-30
# 4                           3.017061e+10 2017-05-31
# ..                                   ...        ...
# 115                         5.081045e+10 2026-08-31
# 116                         5.129593e+10 2026-09-30
# 117                                  NaN 2026-10-31
# 118                                  NaN 2026-11-30
# 119                                  NaN 2026-12-31
#
# [120 rows x 79 columns]

# %%
for column in mde3.columns:
    if column.endswith('_monthly'):
        mde3[column]=mde3[column].shift(1)

# %%
## We performed the shift in mde2
mde3
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 0                                  NaN                      NaN
# 1                           198.041241                    55.01
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# ..                                 ...                      ...
# 115                                NaN                      NaN
# 116                                NaN                      NaN
# 117                                NaN                      NaN
# 118                                NaN                      NaN
# 119                                NaN                      NaN
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 0                            NaN                       NaN
# 1                           1.84                      1.39
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# ..                           ...                       ...
# 115                          NaN                       NaN
# 116                          NaN                       NaN
# 117                          NaN                       NaN
# 118                          NaN                       NaN
# 119                          NaN                       NaN
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 0                                  NaN                       NaN
# 1                                16.44               23096526.55
# 2                                16.96               22210954.84
# 3                                17.32               22304267.84
# 4                                17.59               21768241.12
# ..                                 ...                       ...
# 115                                NaN                       NaN
# 116                                NaN                       NaN
# 117                                NaN                       NaN
# 118                                NaN                       NaN
# 119                                NaN                       NaN
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 0                                NaN                    NaN
# 1                         1994577.62             3311609.44
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# ..                               ...                    ...
# 115                              NaN                    NaN
# 116                              NaN                    NaN
# 117                              NaN                    NaN
# 118                              NaN                    NaN
# 119                              NaN                    NaN
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 0                         NaN                        NaN  ...
# 1                  9473002.48                19005647.02  ...
# 2                  7977399.24                19746640.86  ...
# 3                  7628543.46                20342546.55  ...
# 4                  7269852.64                20347360.25  ...
# ..                        ...                        ...  ...
# 115                       NaN                        NaN  ...
# 116                       NaN                        NaN  ...
# 117                       NaN                        NaN  ...
# 118                       NaN                        NaN  ...
# 119                       NaN                        NaN  ...
#
#      gdp_svc_Education_quarterly  \
# 0                            NaN
# 1                            NaN
# 2                         587.79
# 3                         587.79
# 4                         587.79
# ..                           ...
# 115                          NaN
# 116                          NaN
# 117                          NaN
# 118                          NaN
# 119                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                                 NaN
# 1    2017-02-28                                 NaN
# 2    2017-03-31                        2.817423e+10
# 3    2017-04-28                        2.964668e+10
# 4    2017-05-31                        3.029795e+10
# ..          ...                                 ...
# 115  2026-07-16                        4.958097e+10
# 116         NaN                        5.145923e+10
# 117         NaN                        5.191564e+10
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date
# 0                                    NaN 2017-01-31
# 1                                    NaN 2017-02-28
# 2                           2.745703e+10 2017-03-31
# 3                           2.894094e+10 2017-04-30
# 4                           2.962647e+10 2017-05-31
# ..                                   ...        ...
# 115                         4.889970e+10 2026-08-31
# 116                         5.081045e+10 2026-09-30
# 117                         5.129593e+10 2026-10-31
# 118                                  NaN 2026-11-30
# 119                                  NaN 2026-12-31
#
# [120 rows x 79 columns]

# %%
mde3[['foreign_reserve_Gross(USD)_monthly','foreign_reserve_Liquid(USD)_monthly']]=mde3[['foreign_reserve_Gross(USD)_monthly','foreign_reserve_Liquid(USD)_monthly']].shift(-1)

# %%
mde3
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 0                                  NaN                      NaN
# 1                           198.041241                    55.01
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# ..                                 ...                      ...
# 115                                NaN                      NaN
# 116                                NaN                      NaN
# 117                                NaN                      NaN
# 118                                NaN                      NaN
# 119                                NaN                      NaN
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 0                            NaN                       NaN
# 1                           1.84                      1.39
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# ..                           ...                       ...
# 115                          NaN                       NaN
# 116                          NaN                       NaN
# 117                          NaN                       NaN
# 118                          NaN                       NaN
# 119                          NaN                       NaN
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 0                                  NaN                       NaN
# 1                                16.44               23096526.55
# 2                                16.96               22210954.84
# 3                                17.32               22304267.84
# 4                                17.59               21768241.12
# ..                                 ...                       ...
# 115                                NaN                       NaN
# 116                                NaN                       NaN
# 117                                NaN                       NaN
# 118                                NaN                       NaN
# 119                                NaN                       NaN
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 0                                NaN                    NaN
# 1                         1994577.62             3311609.44
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# ..                               ...                    ...
# 115                              NaN                    NaN
# 116                              NaN                    NaN
# 117                              NaN                    NaN
# 118                              NaN                    NaN
# 119                              NaN                    NaN
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 0                         NaN                        NaN  ...
# 1                  9473002.48                19005647.02  ...
# 2                  7977399.24                19746640.86  ...
# 3                  7628543.46                20342546.55  ...
# 4                  7269852.64                20347360.25  ...
# ..                        ...                        ...  ...
# 115                       NaN                        NaN  ...
# 116                       NaN                        NaN  ...
# 117                       NaN                        NaN  ...
# 118                       NaN                        NaN  ...
# 119                       NaN                        NaN  ...
#
#      gdp_svc_Education_quarterly  \
# 0                            NaN
# 1                            NaN
# 2                         587.79
# 3                         587.79
# 4                         587.79
# ..                           ...
# 115                          NaN
# 116                          NaN
# 117                          NaN
# 118                          NaN
# 119                          NaN
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                                 NaN
# 1    2017-02-28                        2.817423e+10
# 2    2017-03-31                        2.964668e+10
# 3    2017-04-28                        3.029795e+10
# 4    2017-05-31                        3.086463e+10
# ..          ...                                 ...
# 115  2026-07-16                        5.145923e+10
# 116         NaN                        5.191564e+10
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date
# 0                                    NaN 2017-01-31
# 1                           2.745703e+10 2017-02-28
# 2                           2.894094e+10 2017-03-31
# 3                           2.962647e+10 2017-04-30
# 4                           3.017061e+10 2017-05-31
# ..                                   ...        ...
# 115                         5.081045e+10 2026-08-31
# 116                         5.129593e+10 2026-09-30
# 117                                  NaN 2026-10-31
# 118                                  NaN 2026-11-30
# 119                                  NaN 2026-12-31
#
# [120 rows x 79 columns]

# %% [markdown]
# We are now done with the macroeconomic variables. We will head over to the stock_data. We will start with the finance sector stock data.

# %%
fin_sec_data=pd.read_csv('feature_engineering/stocks_sectors/financial_services/financial_services_sector')

# %%
fin_sec_data
# Out:
#             date              sector  weighted_sector_returns  \
# 0     2017-01-03  financial_services                 0.000000
# 1     2017-01-04  financial_services                 0.353432
# 2     2017-01-05  financial_services                -0.182223
# 3     2017-01-06  financial_services                 1.397196
# 4     2017-01-09  financial_services                 3.645896
# ...          ...                 ...                      ...
# 2258  2026-07-13  financial_services                -0.746327
# 2259  2026-07-14  financial_services                 0.906947
# 2260  2026-07-15  financial_services                 0.779799
# 2261  2026-07-16  financial_services                 1.505893
# 2262  2026-07-17  financial_services                 1.536021
#
#       n_stocks_contributing  sector_index  sector_volume
# 0                      20.0    100.000000     48125518.0
# 1                      20.0    100.353432     26705191.0
# 2                      20.0    100.170565     66991076.0
# 3                      20.0    101.570144     97521276.0
# 4                      20.0    105.273286     99013315.0
# ...                     ...           ...            ...
# 2258                   35.0   2695.019313    290562049.0
# 2259                   35.0   2719.461701    163509442.0
# 2260                   35.0   2740.668037    258362267.0
# 2261                   35.0   2781.939574    261040578.0
# 2262                   35.0   2824.670764    295044834.0
#
# [2263 rows x 6 columns]

# %%
fin_sec_data_clean=fin_sec_data.copy()

# %%
fin_sec_data_clean['sector_volume']=fin_sec_data_clean['sector_volume'].shift(1)

# %%
fin_sec_data_clean=fin_sec_data_clean.drop('sector',axis=1)

# %%
fin_sec_data_clean
# Out:
#             date  weighted_sector_returns  n_stocks_contributing  \
# 0     2017-01-03                 0.000000                   20.0
# 1     2017-01-04                 0.353432                   20.0
# 2     2017-01-05                -0.182223                   20.0
# 3     2017-01-06                 1.397196                   20.0
# 4     2017-01-09                 3.645896                   20.0
# ...          ...                      ...                    ...
# 2258  2026-07-13                -0.746327                   35.0
# 2259  2026-07-14                 0.906947                   35.0
# 2260  2026-07-15                 0.779799                   35.0
# 2261  2026-07-16                 1.505893                   35.0
# 2262  2026-07-17                 1.536021                   35.0
#
#       sector_index  sector_volume
# 0       100.000000            NaN
# 1       100.353432     48125518.0
# 2       100.170565     26705191.0
# 3       101.570144     66991076.0
# 4       105.273286     97521276.0
# ...            ...            ...
# 2258   2695.019313    242350071.0
# 2259   2719.461701    290562049.0
# 2260   2740.668037    163509442.0
# 2261   2781.939574    258362267.0
# 2262   2824.670764    261040578.0
#
# [2263 rows x 5 columns]

# %%
fin_sec_data_clean=fin_sec_data_clean.dropna()

# %%
fin_sec_data_clean['date']=pd.to_datetime(fin_sec_data_clean['date'])

# %%
print(fin_sec_data_clean['date'].dtypes)
# Out:
# datetime64[us]

# %%
mde3["month"] = mde3["date"].dt.to_period("M")
fin_sec_data_clean["month"] = fin_sec_data_clean["date"].dt.to_period("M")

# %%
mde3
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 0                                  NaN                      NaN
# 1                           198.041241                    55.01
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# ..                                 ...                      ...
# 115                                NaN                      NaN
# 116                                NaN                      NaN
# 117                                NaN                      NaN
# 118                                NaN                      NaN
# 119                                NaN                      NaN
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 0                            NaN                       NaN
# 1                           1.84                      1.39
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# ..                           ...                       ...
# 115                          NaN                       NaN
# 116                          NaN                       NaN
# 117                          NaN                       NaN
# 118                          NaN                       NaN
# 119                          NaN                       NaN
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 0                                  NaN                       NaN
# 1                                16.44               23096526.55
# 2                                16.96               22210954.84
# 3                                17.32               22304267.84
# 4                                17.59               21768241.12
# ..                                 ...                       ...
# 115                                NaN                       NaN
# 116                                NaN                       NaN
# 117                                NaN                       NaN
# 118                                NaN                       NaN
# 119                                NaN                       NaN
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 0                                NaN                    NaN
# 1                         1994577.62             3311609.44
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# ..                               ...                    ...
# 115                              NaN                    NaN
# 116                              NaN                    NaN
# 117                              NaN                    NaN
# 118                              NaN                    NaN
# 119                              NaN                    NaN
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 0                         NaN                        NaN  ...
# 1                  9473002.48                19005647.02  ...
# 2                  7977399.24                19746640.86  ...
# 3                  7628543.46                20342546.55  ...
# 4                  7269852.64                20347360.25  ...
# ..                        ...                        ...  ...
# 115                       NaN                        NaN  ...
# 116                       NaN                        NaN  ...
# 117                       NaN                        NaN  ...
# 118                       NaN                        NaN  ...
# 119                       NaN                        NaN  ...
#
#      gdp_svc_Human Health & Social Services_quarterly  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              186.24
# 3                                              186.24
# 4                                              186.24
# ..                                                ...
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      gdp_svc_Other Services_quarterly  GDP at Current Basic Prices_quarterly  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                             1237.68                               26028.36
# 3                             1237.68                               26028.36
# 4                             1237.68                               26028.36
# ..                                ...                                    ...
# 115                               NaN                                    NaN
# 116                               NaN                                    NaN
# 117                               NaN                                    NaN
# 118                               NaN                                    NaN
# 119                               NaN                                    NaN
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                              200.5                                26228.85
# 3                              200.5                                26228.85
# 4                              200.5                                26228.85
# ..                               ...                                     ...
# 115                              NaN                                     NaN
# 116                              NaN                                     NaN
# 117                              NaN                                     NaN
# 118                              NaN                                     NaN
# 119                              NaN                                     NaN
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 0    2017-01-31                                 NaN
# 1    2017-02-28                        2.817423e+10
# 2    2017-03-31                        2.964668e+10
# 3    2017-04-28                        3.029795e+10
# 4    2017-05-31                        3.086463e+10
# ..          ...                                 ...
# 115  2026-07-16                        5.145923e+10
# 116         NaN                        5.191564e+10
# 117         NaN                                 NaN
# 118         NaN                                 NaN
# 119         NaN                                 NaN
#
#      foreign_reserve_Liquid(USD)_monthly       date    month
# 0                                    NaN 2017-01-31  2017-01
# 1                           2.745703e+10 2017-02-28  2017-02
# 2                           2.894094e+10 2017-03-31  2017-03
# 3                           2.962647e+10 2017-04-30  2017-04
# 4                           3.017061e+10 2017-05-31  2017-05
# ..                                   ...        ...      ...
# 115                         5.081045e+10 2026-08-31  2026-08
# 116                         5.129593e+10 2026-09-30  2026-09
# 117                                  NaN 2026-10-31  2026-10
# 118                                  NaN 2026-11-30  2026-11
# 119                                  NaN 2026-12-31  2026-12
#
# [120 rows x 80 columns]

# %%
fin_sec_data_clean
# Out:
#            date  weighted_sector_returns  n_stocks_contributing  sector_index  \
# 1    2017-01-04                 0.353432                   20.0    100.353432
# 2    2017-01-05                -0.182223                   20.0    100.170565
# 3    2017-01-06                 1.397196                   20.0    101.570144
# 4    2017-01-09                 3.645896                   20.0    105.273286
# 5    2017-01-10                -1.454119                   20.0    103.742486
# ...         ...                      ...                    ...           ...
# 2258 2026-07-13                -0.746327                   35.0   2695.019313
# 2259 2026-07-14                 0.906947                   35.0   2719.461701
# 2260 2026-07-15                 0.779799                   35.0   2740.668037
# 2261 2026-07-16                 1.505893                   35.0   2781.939574
# 2262 2026-07-17                 1.536021                   35.0   2824.670764
#
#       sector_volume    month
# 1        48125518.0  2017-01
# 2        26705191.0  2017-01
# 3        66991076.0  2017-01
# 4        97521276.0  2017-01
# 5        99013315.0  2017-01
# ...             ...      ...
# 2258    242350071.0  2026-07
# 2259    290562049.0  2026-07
# 2260    163509442.0  2026-07
# 2261    258362267.0  2026-07
# 2262    261040578.0  2026-07
#
# [2262 rows x 6 columns]

# %%
## Get last day of the month
fin_sec_monthly = (
    fin_sec_data_clean
    .sort_values("date")
    .groupby("month")
    .last()
    .reset_index()
)

# %%
fin_sec_monthly
# Out:
#        month       date  weighted_sector_returns  n_stocks_contributing  \
# 0    2017-01 2017-01-31                -0.996463                   20.0
# 1    2017-02 2017-02-28                 0.649545                   21.0
# 2    2017-03 2017-03-31                -0.017945                   21.0
# 3    2017-04 2017-04-28                 1.815887                   20.0
# 4    2017-05 2017-05-31                -2.338342                   21.0
# ..       ...        ...                      ...                    ...
# 110  2026-03 2026-03-31                -1.878773                   35.0
# 111  2026-04 2026-04-30                 1.404651                   35.0
# 112  2026-05 2026-05-29                -0.883768                   35.0
# 113  2026-06 2026-06-30                -1.000082                   35.0
# 114  2026-07 2026-07-17                 1.536021                   35.0
#
#      sector_index  sector_volume
# 0      109.001843     87259637.0
# 1      107.626307    169938472.0
# 2      105.456849    141367620.0
# 3      115.418966    120760980.0
# 4      138.127184    261656035.0
# ..            ...            ...
# 110   2347.696835    294022203.0
# 111   2856.819058    809264585.0
# 112   2959.843133    341760831.0
# 113   2664.183854    480278073.0
# 114   2824.670764    261040578.0
#
# [115 rows x 6 columns]

# %%
## We will merge based on the month
fin_sector_merged = mde3.merge(
    fin_sec_monthly.drop(columns="date"),
    on="month",
    how="left"
)

# %%
fin_sector_merged
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 0                                  NaN                      NaN
# 1                           198.041241                    55.01
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# ..                                 ...                      ...
# 115                                NaN                      NaN
# 116                                NaN                      NaN
# 117                                NaN                      NaN
# 118                                NaN                      NaN
# 119                                NaN                      NaN
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 0                            NaN                       NaN
# 1                           1.84                      1.39
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# ..                           ...                       ...
# 115                          NaN                       NaN
# 116                          NaN                       NaN
# 117                          NaN                       NaN
# 118                          NaN                       NaN
# 119                          NaN                       NaN
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 0                                  NaN                       NaN
# 1                                16.44               23096526.55
# 2                                16.96               22210954.84
# 3                                17.32               22304267.84
# 4                                17.59               21768241.12
# ..                                 ...                       ...
# 115                                NaN                       NaN
# 116                                NaN                       NaN
# 117                                NaN                       NaN
# 118                                NaN                       NaN
# 119                                NaN                       NaN
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 0                                NaN                    NaN
# 1                         1994577.62             3311609.44
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# ..                               ...                    ...
# 115                              NaN                    NaN
# 116                              NaN                    NaN
# 117                              NaN                    NaN
# 118                              NaN                    NaN
# 119                              NaN                    NaN
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 0                         NaN                        NaN  ...
# 1                  9473002.48                19005647.02  ...
# 2                  7977399.24                19746640.86  ...
# 3                  7628543.46                20342546.55  ...
# 4                  7269852.64                20347360.25  ...
# ..                        ...                        ...  ...
# 115                       NaN                        NaN  ...
# 116                       NaN                        NaN  ...
# 117                       NaN                        NaN  ...
# 118                       NaN                        NaN  ...
# 119                       NaN                        NaN  ...
#
#      GDP at Current Market Prices_quarterly     FR_Date  \
# 0                                       NaN  2017-01-31
# 1                                       NaN  2017-02-28
# 2                                  26228.85  2017-03-31
# 3                                  26228.85  2017-04-28
# 4                                  26228.85  2017-05-31
# ..                                      ...         ...
# 115                                     NaN  2026-07-16
# 116                                     NaN         NaN
# 117                                     NaN         NaN
# 118                                     NaN         NaN
# 119                                     NaN         NaN
#
#      foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 0                                   NaN                                  NaN
# 1                          2.817423e+10                         2.745703e+10
# 2                          2.964668e+10                         2.894094e+10
# 3                          3.029795e+10                         2.962647e+10
# 4                          3.086463e+10                         3.017061e+10
# ..                                  ...                                  ...
# 115                        5.145923e+10                         5.081045e+10
# 116                        5.191564e+10                         5.129593e+10
# 117                                 NaN                                  NaN
# 118                                 NaN                                  NaN
# 119                                 NaN                                  NaN
#
#           date    month  weighted_sector_returns  n_stocks_contributing  \
# 0   2017-01-31  2017-01                -0.996463                   20.0
# 1   2017-02-28  2017-02                 0.649545                   21.0
# 2   2017-03-31  2017-03                -0.017945                   21.0
# 3   2017-04-30  2017-04                 1.815887                   20.0
# 4   2017-05-31  2017-05                -2.338342                   21.0
# ..         ...      ...                      ...                    ...
# 115 2026-08-31  2026-08                      NaN                    NaN
# 116 2026-09-30  2026-09                      NaN                    NaN
# 117 2026-10-31  2026-10                      NaN                    NaN
# 118 2026-11-30  2026-11                      NaN                    NaN
# 119 2026-12-31  2026-12                      NaN                    NaN
#
#      sector_index  sector_volume
# 0      109.001843     87259637.0
# 1      107.626307    169938472.0
# 2      105.456849    141367620.0
# 3      115.418966    120760980.0
# 4      138.127184    261656035.0
# ..            ...            ...
# 115           NaN            NaN
# 116           NaN            NaN
# 117           NaN            NaN
# 118           NaN            NaN
# 119           NaN            NaN
#
# [120 rows x 84 columns]

# %%
fin_sector_merged=fin_sector_merged.dropna()

# %%
fin_sector_merged
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# 5                           211.637809                    50.57
# 6                           214.982456                    47.42
# ..                                 ...                      ...
# 108                         917.368816                    68.05
# 109                         890.956254                    68.05
# 110                         908.860705                    72.33
# 111                         946.869623                   106.09
# 112                         967.050171                   126.71
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# 5                           1.87                      1.42
# 6                           1.95                      1.50
# ..                           ...                       ...
# 108                         1.46                      1.01
# 109                         1.46                      1.01
# 110                         1.31                      0.86
# 111                         1.38                      0.93
# 112                         1.49                      1.04
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 2                                16.96              2.221095e+07
# 3                                17.32              2.230427e+07
# 4                                17.59              2.176824e+07
# 5                                17.63              2.204777e+07
# 6                                17.58              2.198058e+07
# ..                                 ...                       ...
# 108                              23.01              1.244002e+08
# 109                              21.97              1.239393e+08
# 110                              21.03              1.231071e+08
# 111                              20.05              1.249763e+08
# 112                              19.16              1.249763e+08
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# 5                         1897917.15             3254006.25
# 6                         1873544.00             3256863.20
# ..                               ...                    ...
# 108                       5732860.29            32035734.52
# 109                       5731116.60            30254995.23
# 110                       5709846.43            32744055.08
# 111                       5646391.19            34603460.67
# 112                       5646391.19            34603460.67
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 2                  7977399.24               1.974664e+07  ...
# 3                  7628543.46               2.034255e+07  ...
# 4                  7269852.64               2.034736e+07  ...
# 5                  8540084.49               1.949923e+07  ...
# 6                  8468080.62               1.985120e+07  ...
# ..                        ...                        ...  ...
# 108               31505596.33               9.290425e+07  ...
# 109               27085821.33               9.686314e+07  ...
# 110               25569115.78               9.754761e+07  ...
# 111               24014048.35               1.009719e+08  ...
# 112               24014048.35               1.009719e+08  ...
#
#      GDP at Current Market Prices_quarterly     FR_Date  \
# 2                              26228.850000  2017-03-31
# 3                              26228.850000  2017-04-28
# 4                              26228.850000  2017-05-31
# 5                              27266.390000  2017-06-30
# 6                              27266.390000  2017-07-31
# ..                                      ...         ...
# 108                           126032.267589  2025-12-31
# 109                           126032.267589  2026-01-30
# 110                           113186.870120  2026-02-27
# 111                           113186.870120  2026-03-31
# 112                           113186.870120  2026-04-30
#
#      foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 2                          2.964668e+10                         2.894094e+10
# 3                          3.029795e+10                         2.962647e+10
# 4                          3.086463e+10                         3.017061e+10
# 5                          3.032964e+10                         2.961376e+10
# 6                          3.028841e+10                         2.957675e+10
# ..                                  ...                                  ...
# 108                        4.466827e+10                         4.411119e+10
# 109                        4.550244e+10                         4.493857e+10
# 110                        4.627990e+10                         4.572994e+10
# 111                        4.969398e+10                         4.899603e+10
# 112                        4.923846e+10                         4.849418e+10
#
#           date    month  weighted_sector_returns  n_stocks_contributing  \
# 2   2017-03-31  2017-03                -0.017945                   21.0
# 3   2017-04-30  2017-04                 1.815887                   20.0
# 4   2017-05-31  2017-05                -2.338342                   21.0
# 5   2017-06-30  2017-06                -0.251046                   21.0
# 6   2017-07-31  2017-07                -3.410985                   21.0
# ..         ...      ...                      ...                    ...
# 108 2026-01-31  2026-01                -0.149558                   35.0
# 109 2026-02-28  2026-02                 0.000000                   35.0
# 110 2026-03-31  2026-03                -1.878773                   35.0
# 111 2026-04-30  2026-04                 1.404651                   35.0
# 112 2026-05-31  2026-05                -0.883768                   35.0
#
#      sector_index  sector_volume
# 2      105.456849    141367620.0
# 3      115.418966    120760980.0
# 4      138.127184    261656035.0
# 5      162.591431    236727857.0
# 6      183.041162    130494807.0
# ..            ...            ...
# 108   1998.576704    254593845.0
# 109   2364.419520    383962151.0
# 110   2347.696835    294022203.0
# 111   2856.819058    809264585.0
# 112   2959.843133    341760831.0
#
# [111 rows x 84 columns]

# %%
## remove unuseful columns
fin_sector_merged_clean=fin_sector_merged.drop(columns=['date','month'])

# %%
fin_sector_merged_clean
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# 5                           211.637809                    50.57
# 6                           214.982456                    47.42
# ..                                 ...                      ...
# 108                         917.368816                    68.05
# 109                         890.956254                    68.05
# 110                         908.860705                    72.33
# 111                         946.869623                   106.09
# 112                         967.050171                   126.71
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# 5                           1.87                      1.42
# 6                           1.95                      1.50
# ..                           ...                       ...
# 108                         1.46                      1.01
# 109                         1.46                      1.01
# 110                         1.31                      0.86
# 111                         1.38                      0.93
# 112                         1.49                      1.04
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 2                                16.96              2.221095e+07
# 3                                17.32              2.230427e+07
# 4                                17.59              2.176824e+07
# 5                                17.63              2.204777e+07
# 6                                17.58              2.198058e+07
# ..                                 ...                       ...
# 108                              23.01              1.244002e+08
# 109                              21.97              1.239393e+08
# 110                              21.03              1.231071e+08
# 111                              20.05              1.249763e+08
# 112                              19.16              1.249763e+08
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# 5                         1897917.15             3254006.25
# 6                         1873544.00             3256863.20
# ..                               ...                    ...
# 108                       5732860.29            32035734.52
# 109                       5731116.60            30254995.23
# 110                       5709846.43            32744055.08
# 111                       5646391.19            34603460.67
# 112                       5646391.19            34603460.67
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 2                  7977399.24               1.974664e+07  ...
# 3                  7628543.46               2.034255e+07  ...
# 4                  7269852.64               2.034736e+07  ...
# 5                  8540084.49               1.949923e+07  ...
# 6                  8468080.62               1.985120e+07  ...
# ..                        ...                        ...  ...
# 108               31505596.33               9.290425e+07  ...
# 109               27085821.33               9.686314e+07  ...
# 110               25569115.78               9.754761e+07  ...
# 111               24014048.35               1.009719e+08  ...
# 112               24014048.35               1.009719e+08  ...
#
#      GDP at Current Basic Prices_quarterly  Net Taxes on Products_quarterly  \
# 2                             26028.360000                       200.500000
# 3                             26028.360000                       200.500000
# 4                             26028.360000                       200.500000
# 5                             27030.250000                       236.140000
# 6                             27030.250000                       236.140000
# ..                                     ...                              ...
# 108                          122810.658960                      3221.608629
# 109                          122810.658960                      3221.608629
# 110                          110786.347011                      2400.523110
# 111                          110786.347011                      2400.523110
# 112                          110786.347011                      2400.523110
#
#      GDP at Current Market Prices_quarterly     FR_Date  \
# 2                              26228.850000  2017-03-31
# 3                              26228.850000  2017-04-28
# 4                              26228.850000  2017-05-31
# 5                              27266.390000  2017-06-30
# 6                              27266.390000  2017-07-31
# ..                                      ...         ...
# 108                           126032.267589  2025-12-31
# 109                           126032.267589  2026-01-30
# 110                           113186.870120  2026-02-27
# 111                           113186.870120  2026-03-31
# 112                           113186.870120  2026-04-30
#
#      foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 2                          2.964668e+10                         2.894094e+10
# 3                          3.029795e+10                         2.962647e+10
# 4                          3.086463e+10                         3.017061e+10
# 5                          3.032964e+10                         2.961376e+10
# 6                          3.028841e+10                         2.957675e+10
# ..                                  ...                                  ...
# 108                        4.466827e+10                         4.411119e+10
# 109                        4.550244e+10                         4.493857e+10
# 110                        4.627990e+10                         4.572994e+10
# 111                        4.969398e+10                         4.899603e+10
# 112                        4.923846e+10                         4.849418e+10
#
#      weighted_sector_returns  n_stocks_contributing  sector_index  \
# 2                  -0.017945                   21.0    105.456849
# 3                   1.815887                   20.0    115.418966
# 4                  -2.338342                   21.0    138.127184
# 5                  -0.251046                   21.0    162.591431
# 6                  -3.410985                   21.0    183.041162
# ..                       ...                    ...           ...
# 108                -0.149558                   35.0   1998.576704
# 109                 0.000000                   35.0   2364.419520
# 110                -1.878773                   35.0   2347.696835
# 111                 1.404651                   35.0   2856.819058
# 112                -0.883768                   35.0   2959.843133
#
#      sector_volume
# 2      141367620.0
# 3      120760980.0
# 4      261656035.0
# 5      236727857.0
# 6      130494807.0
# ..             ...
# 108    254593845.0
# 109    383962151.0
# 110    294022203.0
# 111    809264585.0
# 112    341760831.0
#
# [111 rows x 82 columns]

# %% [markdown]
# SOmething is wrong with the weighted sector returns. It has to be the monthly difference not the daily difference. WE HAVE WORK TO DO. We will use the sector_index to get these values. ((new-old)/old) * 100

# %%
fin_sector_merged_clean['new_monthly_returns']=fin_sector_merged_clean['sector_index'].pct_change()*100

# %%
fin_sector_merged_clean
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# 5                           211.637809                    50.57
# 6                           214.982456                    47.42
# ..                                 ...                      ...
# 108                         917.368816                    68.05
# 109                         890.956254                    68.05
# 110                         908.860705                    72.33
# 111                         946.869623                   106.09
# 112                         967.050171                   126.71
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# 5                           1.87                      1.42
# 6                           1.95                      1.50
# ..                           ...                       ...
# 108                         1.46                      1.01
# 109                         1.46                      1.01
# 110                         1.31                      0.86
# 111                         1.38                      0.93
# 112                         1.49                      1.04
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 2                                16.96              2.221095e+07
# 3                                17.32              2.230427e+07
# 4                                17.59              2.176824e+07
# 5                                17.63              2.204777e+07
# 6                                17.58              2.198058e+07
# ..                                 ...                       ...
# 108                              23.01              1.244002e+08
# 109                              21.97              1.239393e+08
# 110                              21.03              1.231071e+08
# 111                              20.05              1.249763e+08
# 112                              19.16              1.249763e+08
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# 5                         1897917.15             3254006.25
# 6                         1873544.00             3256863.20
# ..                               ...                    ...
# 108                       5732860.29            32035734.52
# 109                       5731116.60            30254995.23
# 110                       5709846.43            32744055.08
# 111                       5646391.19            34603460.67
# 112                       5646391.19            34603460.67
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 2                  7977399.24               1.974664e+07  ...
# 3                  7628543.46               2.034255e+07  ...
# 4                  7269852.64               2.034736e+07  ...
# 5                  8540084.49               1.949923e+07  ...
# 6                  8468080.62               1.985120e+07  ...
# ..                        ...                        ...  ...
# 108               31505596.33               9.290425e+07  ...
# 109               27085821.33               9.686314e+07  ...
# 110               25569115.78               9.754761e+07  ...
# 111               24014048.35               1.009719e+08  ...
# 112               24014048.35               1.009719e+08  ...
#
#      Net Taxes on Products_quarterly  GDP at Current Market Prices_quarterly  \
# 2                         200.500000                            26228.850000
# 3                         200.500000                            26228.850000
# 4                         200.500000                            26228.850000
# 5                         236.140000                            27266.390000
# 6                         236.140000                            27266.390000
# ..                               ...                                     ...
# 108                      3221.608629                           126032.267589
# 109                      3221.608629                           126032.267589
# 110                      2400.523110                           113186.870120
# 111                      2400.523110                           113186.870120
# 112                      2400.523110                           113186.870120
#
#         FR_Date  foreign_reserve_Gross(USD)_monthly  \
# 2    2017-03-31                        2.964668e+10
# 3    2017-04-28                        3.029795e+10
# 4    2017-05-31                        3.086463e+10
# 5    2017-06-30                        3.032964e+10
# 6    2017-07-31                        3.028841e+10
# ..          ...                                 ...
# 108  2025-12-31                        4.466827e+10
# 109  2026-01-30                        4.550244e+10
# 110  2026-02-27                        4.627990e+10
# 111  2026-03-31                        4.969398e+10
# 112  2026-04-30                        4.923846e+10
#
#      foreign_reserve_Liquid(USD)_monthly  weighted_sector_returns  \
# 2                           2.894094e+10                -0.017945
# 3                           2.962647e+10                 1.815887
# 4                           3.017061e+10                -2.338342
# 5                           2.961376e+10                -0.251046
# 6                           2.957675e+10                -3.410985
# ..                                   ...                      ...
# 108                         4.411119e+10                -0.149558
# 109                         4.493857e+10                 0.000000
# 110                         4.572994e+10                -1.878773
# 111                         4.899603e+10                 1.404651
# 112                         4.849418e+10                -0.883768
#
#      n_stocks_contributing  sector_index  sector_volume  new_monthly_returns
# 2                     21.0    105.456849    141367620.0                  NaN
# 3                     20.0    115.418966    120760980.0             9.446628
# 4                     21.0    138.127184    261656035.0            19.674598
# 5                     21.0    162.591431    236727857.0            17.711392
# 6                     21.0    183.041162    130494807.0            12.577373
# ..                     ...           ...            ...                  ...
# 108                   35.0   1998.576704    254593845.0            10.900821
# 109                   35.0   2364.419520    383962151.0            18.305168
# 110                   35.0   2347.696835    294022203.0            -0.707264
# 111                   35.0   2856.819058    809264585.0            21.686029
# 112                   35.0   2959.843133    341760831.0             3.606251
#
# [111 rows x 83 columns]

# %% [markdown]
# We have to drop the daily sector returns

# %%
fin_sector_merged_clean=fin_sector_merged_clean.drop('weighted_sector_returns', axis=1)

# %%
fin_sector_merged_clean
# Out:
#      consumer_price_index(CPI)_monthly  Crude Oil Price_monthly  \
# 2                           201.001141                    46.39
# 3                           204.456610                    52.13
# 4                           207.729678                    52.94
# 5                           211.637809                    50.57
# 6                           214.982456                    47.42
# ..                                 ...                      ...
# 108                         917.368816                    68.05
# 109                         890.956254                    68.05
# 110                         908.860705                    72.33
# 111                         946.869623                   106.09
# 112                         967.050171                   126.71
#
#      Domestic Production_monthly  Crude Oil Export_monthly  \
# 2                           1.82                      1.37
# 3                           1.60                      1.15
# 4                           1.79                      1.34
# 5                           1.87                      1.42
# 6                           1.95                      1.50
# ..                           ...                       ...
# 108                         1.46                      1.01
# 109                         1.46                      1.01
# 110                         1.31                      0.86
# 111                         1.38                      0.93
# 112                         1.49                      1.04
#
#      Inflation_allItemsAverage_monthly  Money Supply(M2)_monthly  \
# 2                                16.96              2.221095e+07
# 3                                17.32              2.230427e+07
# 4                                17.59              2.176824e+07
# 5                                17.63              2.204777e+07
# 6                                17.58              2.198058e+07
# ..                                 ...                       ...
# 108                              23.01              1.244002e+08
# 109                              21.97              1.239393e+08
# 110                              21.03              1.231071e+08
# 111                              20.05              1.249763e+08
# 112                              19.16              1.249763e+08
#
#      currency in circulation_monthly  bank reserves_monthly  \
# 2                         1978886.94             3234760.81
# 3                         1983633.07             3309947.53
# 4                         1975812.32             3536407.29
# 5                         1897917.15             3254006.25
# 6                         1873544.00             3256863.20
# ..                               ...                    ...
# 108                       5732860.29            32035734.52
# 109                       5731116.60            30254995.23
# 110                       5709846.43            32744055.08
# 111                       5646391.19            34603460.67
# 112                       5646391.19            34603460.67
#
#      netForeignAssets_monthly  netDomesticAssets_monthly  ...  \
# 2                  7977399.24               1.974664e+07  ...
# 3                  7628543.46               2.034255e+07  ...
# 4                  7269852.64               2.034736e+07  ...
# 5                  8540084.49               1.949923e+07  ...
# 6                  8468080.62               1.985120e+07  ...
# ..                        ...                        ...  ...
# 108               31505596.33               9.290425e+07  ...
# 109               27085821.33               9.686314e+07  ...
# 110               25569115.78               9.754761e+07  ...
# 111               24014048.35               1.009719e+08  ...
# 112               24014048.35               1.009719e+08  ...
#
#      GDP at Current Basic Prices_quarterly  Net Taxes on Products_quarterly  \
# 2                             26028.360000                       200.500000
# 3                             26028.360000                       200.500000
# 4                             26028.360000                       200.500000
# 5                             27030.250000                       236.140000
# 6                             27030.250000                       236.140000
# ..                                     ...                              ...
# 108                          122810.658960                      3221.608629
# 109                          122810.658960                      3221.608629
# 110                          110786.347011                      2400.523110
# 111                          110786.347011                      2400.523110
# 112                          110786.347011                      2400.523110
#
#      GDP at Current Market Prices_quarterly     FR_Date  \
# 2                              26228.850000  2017-03-31
# 3                              26228.850000  2017-04-28
# 4                              26228.850000  2017-05-31
# 5                              27266.390000  2017-06-30
# 6                              27266.390000  2017-07-31
# ..                                      ...         ...
# 108                           126032.267589  2025-12-31
# 109                           126032.267589  2026-01-30
# 110                           113186.870120  2026-02-27
# 111                           113186.870120  2026-03-31
# 112                           113186.870120  2026-04-30
#
#      foreign_reserve_Gross(USD)_monthly  foreign_reserve_Liquid(USD)_monthly  \
# 2                          2.964668e+10                         2.894094e+10
# 3                          3.029795e+10                         2.962647e+10
# 4                          3.086463e+10                         3.017061e+10
# 5                          3.032964e+10                         2.961376e+10
# 6                          3.028841e+10                         2.957675e+10
# ..                                  ...                                  ...
# 108                        4.466827e+10                         4.411119e+10
# 109                        4.550244e+10                         4.493857e+10
# 110                        4.627990e+10                         4.572994e+10
# 111                        4.969398e+10                         4.899603e+10
# 112                        4.923846e+10                         4.849418e+10
#
#      n_stocks_contributing  sector_index  sector_volume  new_monthly_returns
# 2                     21.0    105.456849    141367620.0                  NaN
# 3                     20.0    115.418966    120760980.0             9.446628
# 4                     21.0    138.127184    261656035.0            19.674598
# 5                     21.0    162.591431    236727857.0            17.711392
# 6                     21.0    183.041162    130494807.0            12.577373
# ..                     ...           ...            ...                  ...
# 108                   35.0   1998.576704    254593845.0            10.900821
# 109                   35.0   2364.419520    383962151.0            18.305168
# 110                   35.0   2347.696835    294022203.0            -0.707264
# 111                   35.0   2856.819058    809264585.0            21.686029
# 112                   35.0   2959.843133    341760831.0             3.606251
#
# [111 rows x 82 columns]

# %% [markdown]
# I think its ok when we think of it.

# %%
fin_sector_merged_clean1=fin_sector_merged_clean.dropna()

# %%
fin_sector_merged_clean1=fin_sector_merged_clean1.drop('FR_Date',axis=1)

# %%
fin_sector_merged_clean1.rename(columns={'A. GDP_AGRICULTURE(agric)_quarterly':'GDP_AGRICULTURE(agric)_quarterly', ' gdp_ind_mfg_Oil Refining_quarterly':'gdp_ind_mfg_Oil Refining_quarterly'}, inplace=True)

# %%
fin_sector_merged_clean1.columns
# Out:
# Index(['consumer_price_index(CPI)_monthly', 'Crude Oil Price_monthly',
#        'Domestic Production_monthly', 'Crude Oil Export_monthly',
#        'Inflation_allItemsAverage_monthly', 'Money Supply(M2)_monthly',
#        'currency in circulation_monthly', 'bank reserves_monthly',
#        'netForeignAssets_monthly', 'netDomesticAssets_monthly',
#        'netDomesticCredit_monthly', 'creditToGovernment_monthly',
#        'creditToPrivateSector_monthly', 'MonetaryPolicyRate_monthly',
#        'TreasuryBillRate_monthly', 'Lending_Rate_monthly',
#        'Exchange_Rate(USD-EOP)_monthly', 'Premium_Motor_Spirit(PMS)_monthly',
#        'GDP_AGRICULTURE(agric)_quarterly',
#        'gdp_agric_Crop Production_quarterly', 'gdp_agric_Livestock_quarterly',
#        'gdp_agric_Forestry_quarterly', ' gdp_Fishing_quarterly',
#        'GDP_INDUSTRY(ind)_quarterly',
#        'gdp_ind_Mining and Quarrying(MQ)_quarterly',
#        'gdp_ind_MQ_Crude Petroleum and Natural Gas_quarterly',
#        'gdp_ind_MQ_Coal Mining_quarterly', 'gdp_ind_MQ_Metal Ores_quarterly',
#        'gdp_ind_MQ_Quarrying and Other Minerals_quarterly',
#        'gdp_ind_Manufacturing(mfg)_quarterly',
#        'gdp_ind_mfg_Oil Refining_quarterly', 'gdp_ind_mfg_Cement_quarterly',
#        'gdp_ind_mfg_Food, Beverage and Tobacco_quarterly',
#        'gdp_ind_mfg_Textile, Apparel and Footwear_quarterly',
#        'gdp_ind_mfg_Wood and Wood Products_quarterly',
#        'gdp_ind_mfg_Pulp, Paper and Paper Products_quarterly',
#        'gdp_ind_mfg_Chemical and Pharmaceutical Products_quarterly',
#        'gdp_ind_mfg_Non-Metallic Products_quarterly',
#        'gdp_ind_mfg_Plastic and Rubber Products_quarterly',
#        'gdp_ind_mfg_Electrical and Electronics_quarterly',
#        'gdp_ind_mfg_Basic Metal, Iron and Steel_quarterly',
#        'gdp_ind_mfg_Motor Vehicles and Assembly_quarterly',
#        'gdp_ind_mfg_Other Manufacturing_quarterly',
#        'gdp_ind_Electricity, Gas, Steam & Air conditioner_quarterly',
#        'gdp_ind_Water supply, Sewage, Waste Management_quarterly',
#        'gdp_ind_Construction_quarterly', 'GDP_SERVICES(svc)_quarterly',
#        'gdp_svc_Trade_quarterly',
#        'gdp_svc_Accommodation and Food Services_quarterly',
#        'gdp_svc_Transportation and Storage(TS)_quarterly',
#        'gdp_svc_TS_RoadTransport_quarterly',
#        'gdp_svc_TS_Rail Transport & Pipelines_quarterly',
#        'gdp_svc_TS_Water Transport_quarterly',
#        'gdp_svc_TS_Air Transport_quarterly',
#        'gdp_svc_TS_Transport Services_quarterly',
#        'gdp_svc_TS_Post and Courier Services_quarterly',
#        'gdp_svc_Information and Communication(IC)_quarterly',
#        'gdp_svc_IC_Telecommunications and Information Services_quarterly',
#        'gdp_svc_IC_Publishing_quarterly',
#        'gdp_svc_IC_Motion Pictures, Sound Recording and Music Production_quarterly',
#        'gdp_svc_IC_Broadcasting_quarterly',
#        'gdp_svc_Arts, Entertainment & Recreation_quarterly',
#        'gdp_svc_Financial and Insurance(FI)_quarterly',
#        'gdp_svc_FI_Financial Institutions_quarterly',
#        'gdp_svc_FI_Insurance_quarterly', 'gdp_svc_Real Estate_quarterly',
#        'gdp_svc_Professional, Scientific & Technical Services_quarterly',
#        'gdp_svc_Administrative and Support Services_quarterly',
#        'gdp_svc_Public Administration_quarterly',
#        'gdp_svc_Education_quarterly',
#        'gdp_svc_Human Health & Social Services_quarterly',
#        'gdp_svc_Other Services_quarterly',
#        'GDP at Current Basic Prices_quarterly',
#        'Net Taxes on Products_quarterly',
#        'GDP at Current Market Prices_quarterly',
#        'foreign_reserve_Gross(USD)_monthly',
#        'foreign_reserve_Liquid(USD)_monthly', 'n_stocks_contributing',
#        'sector_index', 'sector_volume', 'new_monthly_returns'],
#       dtype='str')

# %%
## The needed features for this training (Check Cloud AI for explanation)
X_y_finance_features = [
    #target feature
    'new_monthly_returns',

    'sector_volume',  # consider lagging — see caveat below

    # Prices / inflation
    'consumer_price_index(CPI)_monthly',
    'Inflation_allItemsAverage_monthly',
    'Premium_Motor_Spirit(PMS)_monthly',

    # Oil
    'Crude Oil Price_monthly',
    'Domestic Production_monthly',
    'Crude Oil Export_monthly',

    # Money supply / banking system
    'Money Supply(M2)_monthly',
    'currency in circulation_monthly',
    'bank reserves_monthly',
    'netForeignAssets_monthly',
    'netDomesticAssets_monthly',
    'netDomesticCredit_monthly',
    'creditToGovernment_monthly',
    'creditToPrivateSector_monthly',

    # Interest rates
    'MonetaryPolicyRate_monthly',
    'TreasuryBillRate_monthly',
    'Lending_Rate_monthly',

    # Exchange rate
    'Exchange_Rate(USD-EOP)_monthly',

    # Broad economy GDP
    'GDP_AGRICULTURE(agric)_quarterly',
    'GDP_INDUSTRY(ind)_quarterly',
    'GDP at Current Market Prices_quarterly',

    # Financial sector-specific GDP
    'gdp_svc_FI_Financial Institutions_quarterly',

    # Foreign reserves (pick one frequency — daily shown here)
    'foreign_reserve_Gross(USD)_monthly',
    'foreign_reserve_Liquid(USD)_monthly',

    # Misc
    'n_stocks_contributing'
]

# %%
fin_data_tr=fin_sector_merged_clean1[X_y_finance_features]

# %%
fin_data_tr.corr()
# Out:
#                                              new_monthly_returns  \
# new_monthly_returns                                     1.000000
# sector_volume                                           0.092346
# consumer_price_index(CPI)_monthly                       0.171637
# Inflation_allItemsAverage_monthly                       0.210366
# Premium_Motor_Spirit(PMS)_monthly                       0.183537
# Crude Oil Price_monthly                                -0.129958
# Domestic Production_monthly                            -0.109576
# Crude Oil Export_monthly                               -0.109576
# Money Supply(M2)_monthly                                0.168990
# currency in circulation_monthly                         0.156345
# bank reserves_monthly                                   0.182571
# netForeignAssets_monthly                                0.036765
# netDomesticAssets_monthly                               0.191517
# netDomesticCredit_monthly                               0.195194
# creditToGovernment_monthly                              0.213374
# creditToPrivateSector_monthly                           0.177087
# MonetaryPolicyRate_monthly                              0.184905
# TreasuryBillRate_monthly                                0.103557
# Lending_Rate_monthly                                    0.120148
# Exchange_Rate(USD-EOP)_monthly                          0.165206
# GDP_AGRICULTURE(agric)_quarterly                        0.164420
# GDP_INDUSTRY(ind)_quarterly                             0.129529
# GDP at Current Market Prices_quarterly                  0.173275
# gdp_svc_FI_Financial Institutions_quarterly             0.205102
# foreign_reserve_Gross(USD)_monthly                     -0.205736
# foreign_reserve_Liquid(USD)_monthly                    -0.209249
# n_stocks_contributing                                   0.044736
#
#                                              sector_volume  \
# new_monthly_returns                               0.092346
# sector_volume                                     1.000000
# consumer_price_index(CPI)_monthly                 0.325806
# Inflation_allItemsAverage_monthly                 0.176236
# Premium_Motor_Spirit(PMS)_monthly                 0.288739
# Crude Oil Price_monthly                           0.055435
# Domestic Production_monthly                      -0.100588
# Crude Oil Export_monthly                         -0.100588
# Money Supply(M2)_monthly                          0.307632
# currency in circulation_monthly                   0.271050
# bank reserves_monthly                             0.310483
# netForeignAssets_monthly                          0.276380
# netDomesticAssets_monthly                         0.286375
# netDomesticCredit_monthly                         0.261586
# creditToGovernment_monthly                        0.231554
# creditToPrivateSector_monthly                     0.263206
# MonetaryPolicyRate_monthly                        0.301306
# TreasuryBillRate_monthly                          0.194994
# Lending_Rate_monthly                              0.220726
# Exchange_Rate(USD-EOP)_monthly                    0.260912
# GDP_AGRICULTURE(agric)_quarterly                  0.365352
# GDP_INDUSTRY(ind)_quarterly                       0.224870
# GDP at Current Market Prices_quarterly            0.375271
# gdp_svc_FI_Financial Institutions_quarterly       0.282773
# foreign_reserve_Gross(USD)_monthly                0.118515
# foreign_reserve_Liquid(USD)_monthly               0.112915
# n_stocks_contributing                             0.212434
#
#                                              consumer_price_index(CPI)_monthly  \
# new_monthly_returns                                                   0.171637
# sector_volume                                                         0.325806
# consumer_price_index(CPI)_monthly                                     1.000000
# Inflation_allItemsAverage_monthly                                     0.724667
# Premium_Motor_Spirit(PMS)_monthly                                     0.936667
# Crude Oil Price_monthly                                               0.356898
# Domestic Production_monthly                                          -0.528580
# Crude Oil Export_monthly                                             -0.528580
# Money Supply(M2)_monthly                                              0.992826
# currency in circulation_monthly                                       0.929905
# bank reserves_monthly                                                 0.988114
# netForeignAssets_monthly                                              0.707653
# netDomesticAssets_monthly                                             0.961965
# netDomesticCredit_monthly                                             0.968294
# creditToGovernment_monthly                                            0.860484
# creditToPrivateSector_monthly                                         0.972690
# MonetaryPolicyRate_monthly                                            0.925462
# TreasuryBillRate_monthly                                              0.539539
# Lending_Rate_monthly                                                  0.393682
# Exchange_Rate(USD-EOP)_monthly                                        0.941353
# GDP_AGRICULTURE(agric)_quarterly                                      0.881655
# GDP_INDUSTRY(ind)_quarterly                                           0.865589
# GDP at Current Market Prices_quarterly                                0.964087
# gdp_svc_FI_Financial Institutions_quarterly                           0.941951
# foreign_reserve_Gross(USD)_monthly                                    0.091090
# foreign_reserve_Liquid(USD)_monthly                                   0.083398
# n_stocks_contributing                                                 0.775110
#
#                                              Inflation_allItemsAverage_monthly  \
# new_monthly_returns                                                   0.210366
# sector_volume                                                         0.176236
# consumer_price_index(CPI)_monthly                                     0.724667
# Inflation_allItemsAverage_monthly                                     1.000000
# Premium_Motor_Spirit(PMS)_monthly                                     0.666089
# Crude Oil Price_monthly                                               0.374906
# Domestic Production_monthly                                          -0.550428
# Crude Oil Export_monthly                                             -0.550428
# Money Supply(M2)_monthly                                              0.758753
# currency in circulation_monthly                                       0.613613
# bank reserves_monthly                                                 0.677221
# netForeignAssets_monthly                                              0.419665
# netDomesticAssets_monthly                                             0.778206
# netDomesticCredit_monthly                                             0.797853
# creditToGovernment_monthly                                            0.724645
# creditToPrivateSector_monthly                                         0.794040
# MonetaryPolicyRate_monthly                                            0.768819
# TreasuryBillRate_monthly                                              0.513605
# Lending_Rate_monthly                                                  0.283431
# Exchange_Rate(USD-EOP)_monthly                                        0.801148
# GDP_AGRICULTURE(agric)_quarterly                                      0.525731
# GDP_INDUSTRY(ind)_quarterly                                           0.746046
# GDP at Current Market Prices_quarterly                                0.580866
# gdp_svc_FI_Financial Institutions_quarterly                           0.777581
# foreign_reserve_Gross(USD)_monthly                                   -0.264406
# foreign_reserve_Liquid(USD)_monthly                                  -0.278871
# n_stocks_contributing                                                 0.529628
#
#                                              Premium_Motor_Spirit(PMS)_monthly  \
# new_monthly_returns                                                   0.183537
# sector_volume                                                         0.288739
# consumer_price_index(CPI)_monthly                                     0.936667
# Inflation_allItemsAverage_monthly                                     0.666089
# Premium_Motor_Spirit(PMS)_monthly                                     1.000000
# Crude Oil Price_monthly                                               0.241875
# Domestic Production_monthly                                          -0.317778
# Crude Oil Export_monthly                                             -0.317778
# Money Supply(M2)_monthly                                              0.939749
# currency in circulation_monthly                                       0.889637
# bank reserves_monthly                                                 0.927521
# netForeignAssets_monthly                                              0.767847
# netDomesticAssets_monthly                                             0.893248
# netDomesticCredit_monthly                                             0.894846
# creditToGovernment_monthly                                            0.763557
# creditToPrivateSector_monthly                                         0.913973
# MonetaryPolicyRate_monthly                                            0.930049
# TreasuryBillRate_monthly                                              0.655104
# Lending_Rate_monthly                                                  0.565611
# Exchange_Rate(USD-EOP)_monthly                                        0.926690
# GDP_AGRICULTURE(agric)_quarterly                                      0.794912
# GDP_INDUSTRY(ind)_quarterly                                           0.761874
# GDP at Current Market Prices_quarterly                                0.901900
# gdp_svc_FI_Financial Institutions_quarterly                           0.898998
# foreign_reserve_Gross(USD)_monthly                                    0.145498
# foreign_reserve_Liquid(USD)_monthly                                   0.134887
# n_stocks_contributing                                                 0.611132
#
#                                              Crude Oil Price_monthly  \
# new_monthly_returns                                        -0.129958
# sector_volume                                               0.055435
# consumer_price_index(CPI)_monthly                           0.356898
# Inflation_allItemsAverage_monthly                           0.374906
# Premium_Motor_Spirit(PMS)_monthly                           0.241875
# Crude Oil Price_monthly                                     1.000000
# Domestic Production_monthly                                -0.586880
# Crude Oil Export_monthly                                   -0.586880
# Money Supply(M2)_monthly                                    0.332297
# currency in circulation_monthly                             0.320598
# bank reserves_monthly                                       0.279004
# netForeignAssets_monthly                                    0.071759
# netDomesticAssets_monthly                                   0.358438
# netDomesticCredit_monthly                                   0.400243
# creditToGovernment_monthly                                  0.442367
# creditToPrivateSector_monthly                               0.360809
# MonetaryPolicyRate_monthly                                  0.238384
# TreasuryBillRate_monthly                                    0.059268
# Lending_Rate_monthly                                       -0.145855
# Exchange_Rate(USD-EOP)_monthly                              0.248405
# GDP_AGRICULTURE(agric)_quarterly                            0.208411
# GDP_INDUSTRY(ind)_quarterly                                 0.517094
# GDP at Current Market Prices_quarterly                      0.276090
# gdp_svc_FI_Financial Institutions_quarterly                 0.334272
# foreign_reserve_Gross(USD)_monthly                          0.217137
# foreign_reserve_Liquid(USD)_monthly                         0.217957
# n_stocks_contributing                                       0.475219
#
#                                              Domestic Production_monthly  \
# new_monthly_returns                                            -0.109576
# sector_volume                                                  -0.100588
# consumer_price_index(CPI)_monthly                              -0.528580
# Inflation_allItemsAverage_monthly                              -0.550428
# Premium_Motor_Spirit(PMS)_monthly                              -0.317778
# Crude Oil Price_monthly                                        -0.586880
# Domestic Production_monthly                                     1.000000
# Crude Oil Export_monthly                                        1.000000
# Money Supply(M2)_monthly                                       -0.502132
# currency in circulation_monthly                                -0.482465
# bank reserves_monthly                                          -0.521251
# netForeignAssets_monthly                                        0.014706
# netDomesticAssets_monthly                                      -0.571574
# netDomesticCredit_monthly                                      -0.600252
# creditToGovernment_monthly                                     -0.665566
# creditToPrivateSector_monthly                                  -0.540095
# MonetaryPolicyRate_monthly                                     -0.305103
# TreasuryBillRate_monthly                                        0.157513
# Lending_Rate_monthly                                            0.417685
# Exchange_Rate(USD-EOP)_monthly                                 -0.397901
# GDP_AGRICULTURE(agric)_quarterly                               -0.435900
# GDP_INDUSTRY(ind)_quarterly                                    -0.727369
# GDP at Current Market Prices_quarterly                         -0.439512
# gdp_svc_FI_Financial Institutions_quarterly                    -0.461398
# foreign_reserve_Gross(USD)_monthly                              0.269427
# foreign_reserve_Liquid(USD)_monthly                             0.258960
# n_stocks_contributing                                          -0.701794
#
#                                              Crude Oil Export_monthly  \
# new_monthly_returns                                         -0.109576
# sector_volume                                               -0.100588
# consumer_price_index(CPI)_monthly                           -0.528580
# Inflation_allItemsAverage_monthly                           -0.550428
# Premium_Motor_Spirit(PMS)_monthly                           -0.317778
# Crude Oil Price_monthly                                     -0.586880
# Domestic Production_monthly                                  1.000000
# Crude Oil Export_monthly                                     1.000000
# Money Supply(M2)_monthly                                    -0.502132
# currency in circulation_monthly                             -0.482465
# bank reserves_monthly                                       -0.521251
# netForeignAssets_monthly                                     0.014706
# netDomesticAssets_monthly                                   -0.571574
# netDomesticCredit_monthly                                   -0.600252
# creditToGovernment_monthly                                  -0.665566
# creditToPrivateSector_monthly                               -0.540095
# MonetaryPolicyRate_monthly                                  -0.305103
# TreasuryBillRate_monthly                                     0.157513
# Lending_Rate_monthly                                         0.417685
# Exchange_Rate(USD-EOP)_monthly                              -0.397901
# GDP_AGRICULTURE(agric)_quarterly                            -0.435900
# GDP_INDUSTRY(ind)_quarterly                                 -0.727369
# GDP at Current Market Prices_quarterly                      -0.439512
# gdp_svc_FI_Financial Institutions_quarterly                 -0.461398
# foreign_reserve_Gross(USD)_monthly                           0.269427
# foreign_reserve_Liquid(USD)_monthly                          0.258960
# n_stocks_contributing                                       -0.701794
#
#                                              Money Supply(M2)_monthly  \
# new_monthly_returns                                          0.168990
# sector_volume                                                0.307632
# consumer_price_index(CPI)_monthly                            0.992826
# Inflation_allItemsAverage_monthly                            0.758753
# Premium_Motor_Spirit(PMS)_monthly                            0.939749
# Crude Oil Price_monthly                                      0.332297
# Domestic Production_monthly                                 -0.502132
# Crude Oil Export_monthly                                    -0.502132
# Money Supply(M2)_monthly                                     1.000000
# currency in circulation_monthly                              0.932494
# bank reserves_monthly                                        0.977884
# netForeignAssets_monthly                                     0.741359
# netDomesticAssets_monthly                                    0.962107
# netDomesticCredit_monthly                                    0.969471
# creditToGovernment_monthly                                   0.838256
# creditToPrivateSector_monthly                                0.984947
# MonetaryPolicyRate_monthly                                   0.943508
# TreasuryBillRate_monthly                                     0.584151
# Lending_Rate_monthly                                         0.416599
# Exchange_Rate(USD-EOP)_monthly                               0.972108
# GDP_AGRICULTURE(agric)_quarterly                             0.851879
# GDP_INDUSTRY(ind)_quarterly                                  0.855237
# GDP at Current Market Prices_quarterly                       0.941845
# gdp_svc_FI_Financial Institutions_quarterly                  0.953595
# foreign_reserve_Gross(USD)_monthly                           0.064076
# foreign_reserve_Liquid(USD)_monthly                          0.055411
# n_stocks_contributing                                        0.755554
#
#                                              currency in circulation_monthly  \
# new_monthly_returns                                                 0.156345
# sector_volume                                                       0.271050
# consumer_price_index(CPI)_monthly                                   0.929905
# Inflation_allItemsAverage_monthly                                   0.613613
# Premium_Motor_Spirit(PMS)_monthly                                   0.889637
# Crude Oil Price_monthly                                             0.320598
# Domestic Production_monthly                                        -0.482465
# Crude Oil Export_monthly                                           -0.482465
# Money Supply(M2)_monthly                                            0.932494
# currency in circulation_monthly                                     1.000000
# bank reserves_monthly                                               0.921768
# netForeignAssets_monthly                                            0.681820
# netDomesticAssets_monthly                                           0.917232
# netDomesticCredit_monthly                                           0.880954
# creditToGovernment_monthly                                          0.750788
# creditToPrivateSector_monthly                                       0.900218
# MonetaryPolicyRate_monthly                                          0.824065
# TreasuryBillRate_monthly                                            0.516764
# Lending_Rate_monthly                                                0.348031
# Exchange_Rate(USD-EOP)_monthly                                      0.886734
# GDP_AGRICULTURE(agric)_quarterly                                    0.839732
# GDP_INDUSTRY(ind)_quarterly                                         0.774980
# GDP at Current Market Prices_quarterly                              0.917275
# gdp_svc_FI_Financial Institutions_quarterly                         0.883587
# foreign_reserve_Gross(USD)_monthly                                  0.165270
# foreign_reserve_Liquid(USD)_monthly                                 0.167388
# n_stocks_contributing                                               0.704714
#
#                                              ...  TreasuryBillRate_monthly  \
# new_monthly_returns                          ...                  0.103557
# sector_volume                                ...                  0.194994
# consumer_price_index(CPI)_monthly            ...                  0.539539
# Inflation_allItemsAverage_monthly            ...                  0.513605
# Premium_Motor_Spirit(PMS)_monthly            ...                  0.655104
# Crude Oil Price_monthly                      ...                  0.059268
# Domestic Production_monthly                  ...                  0.157513
# Crude Oil Export_monthly                     ...                  0.157513
# Money Supply(M2)_monthly                     ...                  0.584151
# currency in circulation_monthly              ...                  0.516764
# bank reserves_monthly                        ...                  0.479981
# netForeignAssets_monthly                     ...                  0.743369
# netDomesticAssets_monthly                    ...                  0.500356
# netDomesticCredit_monthly                    ...                  0.485984
# creditToGovernment_monthly                   ...                  0.300680
# creditToPrivateSector_monthly                ...                  0.550620
# MonetaryPolicyRate_monthly                   ...                  0.756705
# TreasuryBillRate_monthly                     ...                  1.000000
# Lending_Rate_monthly                         ...                  0.833241
# Exchange_Rate(USD-EOP)_monthly               ...                  0.676436
# GDP_AGRICULTURE(agric)_quarterly             ...                  0.386818
# GDP_INDUSTRY(ind)_quarterly                  ...                  0.254495
# GDP at Current Market Prices_quarterly       ...                  0.504962
# gdp_svc_FI_Financial Institutions_quarterly  ...                  0.595301
# foreign_reserve_Gross(USD)_monthly           ...                  0.198106
# foreign_reserve_Liquid(USD)_monthly          ...                  0.175511
# n_stocks_contributing                        ...                  0.076177
#
#                                              Lending_Rate_monthly  \
# new_monthly_returns                                      0.120148
# sector_volume                                            0.220726
# consumer_price_index(CPI)_monthly                        0.393682
# Inflation_allItemsAverage_monthly                        0.283431
# Premium_Motor_Spirit(PMS)_monthly                        0.565611
# Crude Oil Price_monthly                                 -0.145855
# Domestic Production_monthly                              0.417685
# Crude Oil Export_monthly                                 0.417685
# Money Supply(M2)_monthly                                 0.416599
# currency in circulation_monthly                          0.348031
# bank reserves_monthly                                    0.361018
# netForeignAssets_monthly                                 0.664011
# netDomesticAssets_monthly                                0.321643
# netDomesticCredit_monthly                                0.307125
# creditToGovernment_monthly                               0.149401
# creditToPrivateSector_monthly                            0.367302
# MonetaryPolicyRate_monthly                               0.633589
# TreasuryBillRate_monthly                                 0.833241
# Lending_Rate_monthly                                     1.000000
# Exchange_Rate(USD-EOP)_monthly                           0.483645
# GDP_AGRICULTURE(agric)_quarterly                         0.337051
# GDP_INDUSTRY(ind)_quarterly                              0.029064
# GDP at Current Market Prices_quarterly                   0.429947
# gdp_svc_FI_Financial Institutions_quarterly              0.429936
# foreign_reserve_Gross(USD)_monthly                       0.315263
# foreign_reserve_Liquid(USD)_monthly                      0.289397
# n_stocks_contributing                                   -0.156960
#
#                                              Exchange_Rate(USD-EOP)_monthly  \
# new_monthly_returns                                                0.165206
# sector_volume                                                      0.260912
# consumer_price_index(CPI)_monthly                                  0.941353
# Inflation_allItemsAverage_monthly                                  0.801148
# Premium_Motor_Spirit(PMS)_monthly                                  0.926690
# Crude Oil Price_monthly                                            0.248405
# Domestic Production_monthly                                       -0.397901
# Crude Oil Export_monthly                                          -0.397901
# Money Supply(M2)_monthly                                           0.972108
# currency in circulation_monthly                                    0.886734
# bank reserves_monthly                                              0.920577
# netForeignAssets_monthly                                           0.788011
# netDomesticAssets_monthly                                          0.920623
# netDomesticCredit_monthly                                          0.926710
# creditToGovernment_monthly                                         0.756976
# creditToPrivateSector_monthly                                      0.962587
# MonetaryPolicyRate_monthly                                         0.957649
# TreasuryBillRate_monthly                                           0.676436
# Lending_Rate_monthly                                               0.483645
# Exchange_Rate(USD-EOP)_monthly                                     1.000000
# GDP_AGRICULTURE(agric)_quarterly                                   0.765514
# GDP_INDUSTRY(ind)_quarterly                                        0.788731
# GDP at Current Market Prices_quarterly                             0.863155
# gdp_svc_FI_Financial Institutions_quarterly                        0.940068
# foreign_reserve_Gross(USD)_monthly                                 0.005382
# foreign_reserve_Liquid(USD)_monthly                               -0.006575
# n_stocks_contributing                                              0.671475
#
#                                              GDP_AGRICULTURE(agric)_quarterly  \
# new_monthly_returns                                                  0.164420
# sector_volume                                                        0.365352
# consumer_price_index(CPI)_monthly                                    0.881655
# Inflation_allItemsAverage_monthly                                    0.525731
# Premium_Motor_Spirit(PMS)_monthly                                    0.794912
# Crude Oil Price_monthly                                              0.208411
# Domestic Production_monthly                                         -0.435900
# Crude Oil Export_monthly                                            -0.435900
# Money Supply(M2)_monthly                                             0.851879
# currency in circulation_monthly                                      0.839732
# bank reserves_monthly                                                0.884466
# netForeignAssets_monthly                                             0.621807
# netDomesticAssets_monthly                                            0.814219
# netDomesticCredit_monthly                                            0.807273
# creditToGovernment_monthly                                           0.723220
# creditToPrivateSector_monthly                                        0.808164
# MonetaryPolicyRate_monthly                                           0.755785
# TreasuryBillRate_monthly                                             0.386818
# Lending_Rate_monthly                                                 0.337051
# Exchange_Rate(USD-EOP)_monthly                                       0.765514
# GDP_AGRICULTURE(agric)_quarterly                                     1.000000
# GDP_INDUSTRY(ind)_quarterly                                          0.719479
# GDP at Current Market Prices_quarterly                               0.953601
# gdp_svc_FI_Financial Institutions_quarterly                          0.734729
# foreign_reserve_Gross(USD)_monthly                                   0.168206
# foreign_reserve_Liquid(USD)_monthly                                  0.166255
# n_stocks_contributing                                                0.678638
#
#                                              GDP_INDUSTRY(ind)_quarterly  \
# new_monthly_returns                                             0.129529
# sector_volume                                                   0.224870
# consumer_price_index(CPI)_monthly                               0.865589
# Inflation_allItemsAverage_monthly                               0.746046
# Premium_Motor_Spirit(PMS)_monthly                               0.761874
# Crude Oil Price_monthly                                         0.517094
# Domestic Production_monthly                                    -0.727369
# Crude Oil Export_monthly                                       -0.727369
# Money Supply(M2)_monthly                                        0.855237
# currency in circulation_monthly                                 0.774980
# bank reserves_monthly                                           0.851388
# netForeignAssets_monthly                                        0.408741
# netDomesticAssets_monthly                                       0.882524
# netDomesticCredit_monthly                                       0.924795
# creditToGovernment_monthly                                      0.906438
# creditToPrivateSector_monthly                                   0.888731
# MonetaryPolicyRate_monthly                                      0.732342
# TreasuryBillRate_monthly                                        0.254495
# Lending_Rate_monthly                                            0.029064
# Exchange_Rate(USD-EOP)_monthly                                  0.788731
# GDP_AGRICULTURE(agric)_quarterly                                0.719479
# GDP_INDUSTRY(ind)_quarterly                                     1.000000
# GDP at Current Market Prices_quarterly                          0.776374
# gdp_svc_FI_Financial Institutions_quarterly                     0.818373
# foreign_reserve_Gross(USD)_monthly                             -0.031781
# foreign_reserve_Liquid(USD)_monthly                            -0.036621
# n_stocks_contributing                                           0.886331
#
#                                              GDP at Current Market Prices_quarterly  \
# new_monthly_returns                                                        0.173275
# sector_volume                                                              0.375271
# consumer_price_index(CPI)_monthly                                          0.964087
# Inflation_allItemsAverage_monthly                                          0.580866
# Premium_Motor_Spirit(PMS)_monthly                                          0.901900
# Crude Oil Price_monthly                                                    0.276090
# Domestic Production_monthly                                               -0.439512
# Crude Oil Export_monthly                                                  -0.439512
# Money Supply(M2)_monthly                                                   0.941845
# currency in circulation_monthly                                            0.917275
# bank reserves_monthly                                                      0.960309
# netForeignAssets_monthly                                                   0.711880
# netDomesticAssets_monthly                                                  0.898078
# netDomesticCredit_monthly                                                  0.895819
# creditToGovernment_monthly                                                 0.792081
# creditToPrivateSector_monthly                                              0.901788
# MonetaryPolicyRate_monthly                                                 0.862889
# TreasuryBillRate_monthly                                                   0.504962
# Lending_Rate_monthly                                                       0.429947
# Exchange_Rate(USD-EOP)_monthly                                             0.863155
# GDP_AGRICULTURE(agric)_quarterly                                           0.953601
# GDP_INDUSTRY(ind)_quarterly                                                0.776374
# GDP at Current Market Prices_quarterly                                     1.000000
# gdp_svc_FI_Financial Institutions_quarterly                                0.858622
# foreign_reserve_Gross(USD)_monthly                                         0.202157
# foreign_reserve_Liquid(USD)_monthly                                        0.197706
# n_stocks_contributing                                                      0.706333
#
#                                              gdp_svc_FI_Financial Institutions_quarterly  \
# new_monthly_returns                                                             0.205102
# sector_volume                                                                   0.282773
# consumer_price_index(CPI)_monthly                                               0.941951
# Inflation_allItemsAverage_monthly                                               0.777581
# Premium_Motor_Spirit(PMS)_monthly                                               0.898998
# Crude Oil Price_monthly                                                         0.334272
# Domestic Production_monthly                                                    -0.461398
# Crude Oil Export_monthly                                                       -0.461398
# Money Supply(M2)_monthly                                                        0.953595
# currency in circulation_monthly                                                 0.883587
# bank reserves_monthly                                                           0.922555
# netForeignAssets_monthly                                                        0.665687
# netDomesticAssets_monthly                                                       0.934691
# netDomesticCredit_monthly                                                       0.936169
# creditToGovernment_monthly                                                      0.823547
# creditToPrivateSector_monthly                                                   0.944411
# MonetaryPolicyRate_monthly                                                      0.925554
# TreasuryBillRate_monthly                                                        0.595301
# Lending_Rate_monthly                                                            0.429936
# Exchange_Rate(USD-EOP)_monthly                                                  0.940068
# GDP_AGRICULTURE(agric)_quarterly                                                0.734729
# GDP_INDUSTRY(ind)_quarterly                                                     0.818373
# GDP at Current Market Prices_quarterly                                          0.858622
# gdp_svc_FI_Financial Institutions_quarterly                                     1.000000
# foreign_reserve_Gross(USD)_monthly                                              0.046945
# foreign_reserve_Liquid(USD)_monthly                                             0.035528
# n_stocks_contributing                                                           0.706647
#
#                                              foreign_reserve_Gross(USD)_monthly  \
# new_monthly_returns                                                   -0.205736
# sector_volume                                                          0.118515
# consumer_price_index(CPI)_monthly                                      0.091090
# Inflation_allItemsAverage_monthly                                     -0.264406
# Premium_Motor_Spirit(PMS)_monthly                                      0.145498
# Crude Oil Price_monthly                                                0.217137
# Domestic Production_monthly                                            0.269427
# Crude Oil Export_monthly                                               0.269427
# Money Supply(M2)_monthly                                               0.064076
# currency in circulation_monthly                                        0.165270
# bank reserves_monthly                                                  0.069119
# netForeignAssets_monthly                                               0.281107
# netDomesticAssets_monthly                                             -0.010910
# netDomesticCredit_monthly                                             -0.007001
# creditToGovernment_monthly                                            -0.009765
# creditToPrivateSector_monthly                                         -0.005346
# MonetaryPolicyRate_monthly                                             0.080722
# TreasuryBillRate_monthly                                               0.198106
# Lending_Rate_monthly                                                   0.315263
# Exchange_Rate(USD-EOP)_monthly                                         0.005382
# GDP_AGRICULTURE(agric)_quarterly                                       0.168206
# GDP_INDUSTRY(ind)_quarterly                                           -0.031781
# GDP at Current Market Prices_quarterly                                 0.202157
# gdp_svc_FI_Financial Institutions_quarterly                            0.046945
# foreign_reserve_Gross(USD)_monthly                                     1.000000
# foreign_reserve_Liquid(USD)_monthly                                    0.998745
# n_stocks_contributing                                                  0.005240
#
#                                              foreign_reserve_Liquid(USD)_monthly  \
# new_monthly_returns                                                    -0.209249
# sector_volume                                                           0.112915
# consumer_price_index(CPI)_monthly                                       0.083398
# Inflation_allItemsAverage_monthly                                      -0.278871
# Premium_Motor_Spirit(PMS)_monthly                                       0.134887
# Crude Oil Price_monthly                                                 0.217957
# Domestic Production_monthly                                             0.258960
# Crude Oil Export_monthly                                                0.258960
# Money Supply(M2)_monthly                                                0.055411
# currency in circulation_monthly                                         0.167388
# bank reserves_monthly                                                   0.063555
# netForeignAssets_monthly                                                0.268203
# netDomesticAssets_monthly                                              -0.017149
# netDomesticCredit_monthly                                              -0.016648
# creditToGovernment_monthly                                             -0.018721
# creditToPrivateSector_monthly                                          -0.014855
# MonetaryPolicyRate_monthly                                              0.059846
# TreasuryBillRate_monthly                                                0.175511
# Lending_Rate_monthly                                                    0.289397
# Exchange_Rate(USD-EOP)_monthly                                         -0.006575
# GDP_AGRICULTURE(agric)_quarterly                                        0.166255
# GDP_INDUSTRY(ind)_quarterly                                            -0.036621
# GDP at Current Market Prices_quarterly                                  0.197706
# gdp_svc_FI_Financial Institutions_quarterly                             0.035528
# foreign_reserve_Gross(USD)_monthly                                      0.998745
# foreign_reserve_Liquid(USD)_monthly                                     1.000000
# n_stocks_contributing                                                   0.004872
#
#                                              n_stocks_contributing
# new_monthly_returns                                       0.044736
# sector_volume                                             0.212434
# consumer_price_index(CPI)_monthly                         0.775110
# Inflation_allItemsAverage_monthly                         0.529628
# Premium_Motor_Spirit(PMS)_monthly                         0.611132
# Crude Oil Price_monthly                                   0.475219
# Domestic Production_monthly                              -0.701794
# Crude Oil Export_monthly                                 -0.701794
# Money Supply(M2)_monthly                                  0.755554
# currency in circulation_monthly                           0.704714
# bank reserves_monthly                                     0.769875
# netForeignAssets_monthly                                  0.368071
# netDomesticAssets_monthly                                 0.768849
# netDomesticCredit_monthly                                 0.807300
# creditToGovernment_monthly                                0.793416
# creditToPrivateSector_monthly                             0.774799
# MonetaryPolicyRate_monthly                                0.592758
# TreasuryBillRate_monthly                                  0.076177
# Lending_Rate_monthly                                     -0.156960
# Exchange_Rate(USD-EOP)_monthly                            0.671475
# GDP_AGRICULTURE(agric)_quarterly                          0.678638
# GDP_INDUSTRY(ind)_quarterly                               0.886331
# GDP at Current Market Prices_quarterly                    0.706333
# gdp_svc_FI_Financial Institutions_quarterly               0.706647
# foreign_reserve_Gross(USD)_monthly                        0.005240
# foreign_reserve_Liquid(USD)_monthly                       0.004872
# n_stocks_contributing                                     1.000000
#
# [27 rows x 27 columns]

# %%
## We will set a threshold for this exercise eg 0.85
## Note: this threshold is determined by the DOMAIN EXPERT
## For now we will use 0.90
## Let us improve the below

def correlation(dataset, threshold):
    col_corr = set()
    col_pair = set()
    
    corr_matrix = dataset.corr()

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname1 = corr_matrix.columns[i]
                colname2 = corr_matrix.columns[j]

                col_pair.add((colname1, colname2, corr_matrix.iloc[i, j]))
                col_corr.add(colname1)

    return col_corr, col_pair

# %%
correlation## We will use the correlation() function we created.
## This will identify features that are highly correlated to each other
correlated_features,column_pairs =correlation(fin_data_tr,0.85)
correlated_features

## The column pairing is good for investigative purposes
# Out:
# {'Crude Oil Export_monthly',
#  'Exchange_Rate(USD-EOP)_monthly',
#  'GDP at Current Market Prices_quarterly',
#  'GDP_AGRICULTURE(agric)_quarterly',
#  'GDP_INDUSTRY(ind)_quarterly',
#  'MonetaryPolicyRate_monthly',
#  'Money Supply(M2)_monthly',
#  'Premium_Motor_Spirit(PMS)_monthly',
#  'bank reserves_monthly',
#  'creditToGovernment_monthly',
#  'creditToPrivateSector_monthly',
#  'currency in circulation_monthly',
#  'foreign_reserve_Liquid(USD)_monthly',
#  'gdp_svc_FI_Financial Institutions_quarterly',
#  'n_stocks_contributing',
#  'netDomesticAssets_monthly',
#  'netDomesticCredit_monthly'}

# %%
column_pairs
# Out:
# {('Crude Oil Export_monthly', 'Domestic Production_monthly', np.float64(1.0)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.9576491793461572)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9721081529567054)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9266900693743361)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9205768260425549)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9413529536776452)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9625870435705848)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.8867339550418918)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9206229532496679)),
#  ('Exchange_Rate(USD-EOP)_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9267099457704021)),
#  ('GDP at Current Market Prices_quarterly',
#   'Exchange_Rate(USD-EOP)_monthly',
#   np.float64(0.8631553170952908)),
#  ('GDP at Current Market Prices_quarterly',
#   'GDP_AGRICULTURE(agric)_quarterly',
#   np.float64(0.9536011477597361)),
#  ('GDP at Current Market Prices_quarterly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.8628887116409812)),
#  ('GDP at Current Market Prices_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9418446847301504)),
#  ('GDP at Current Market Prices_quarterly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9019004447221723)),
#  ('GDP at Current Market Prices_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.9603089423495125)),
#  ('GDP at Current Market Prices_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9640865550430474)),
#  ('GDP at Current Market Prices_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9017878429187735)),
#  ('GDP at Current Market Prices_quarterly',
#   'currency in circulation_monthly',
#   np.float64(0.9172749553852114)),
#  ('GDP at Current Market Prices_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.898078144073525)),
#  ('GDP at Current Market Prices_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.895818964683559)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.8518792649889612)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.8844662278195261)),
#  ('GDP_AGRICULTURE(agric)_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8816547990553996)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.8552365429993705)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.8513877222138815)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8655887072959361)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'creditToGovernment_monthly',
#   np.float64(0.9064384995153834)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.8887306053490396)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.8825243458166253)),
#  ('GDP_INDUSTRY(ind)_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9247949111921324)),
#  ('MonetaryPolicyRate_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9435081253885989)),
#  ('MonetaryPolicyRate_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9300491835263016)),
#  ('MonetaryPolicyRate_monthly',
#   'bank reserves_monthly',
#   np.float64(0.893858270355348)),
#  ('MonetaryPolicyRate_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.925461680023216)),
#  ('MonetaryPolicyRate_monthly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9249459593383624)),
#  ('MonetaryPolicyRate_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.8851106039042548)),
#  ('MonetaryPolicyRate_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.8998253896506823)),
#  ('Money Supply(M2)_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9397488001408807)),
#  ('Money Supply(M2)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9928261629021097)),
#  ('Premium_Motor_Spirit(PMS)_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9366668127810687)),
#  ('bank reserves_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9778835747628404)),
#  ('bank reserves_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.927520506698207)),
#  ('bank reserves_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9881135683110814)),
#  ('bank reserves_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9217680300333764)),
#  ('creditToGovernment_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.8604838598362654)),
#  ('creditToGovernment_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9012370085064538)),
#  ('creditToGovernment_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9304093189872013)),
#  ('creditToPrivateSector_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9849466948460442)),
#  ('creditToPrivateSector_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.9139725616846737)),
#  ('creditToPrivateSector_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9535642659855396)),
#  ('creditToPrivateSector_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9726903104714547)),
#  ('creditToPrivateSector_monthly',
#   'creditToGovernment_monthly',
#   np.float64(0.8522228135181539)),
#  ('creditToPrivateSector_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9002182203353526)),
#  ('creditToPrivateSector_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9608319993794384)),
#  ('creditToPrivateSector_monthly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9846727520607641)),
#  ('currency in circulation_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9324943521873212)),
#  ('currency in circulation_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8896369404788191)),
#  ('currency in circulation_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9299053433257637)),
#  ('foreign_reserve_Liquid(USD)_monthly',
#   'foreign_reserve_Gross(USD)_monthly',
#   np.float64(0.9987450669890262)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Exchange_Rate(USD-EOP)_monthly',
#   np.float64(0.9400681810491938)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'GDP at Current Market Prices_quarterly',
#   np.float64(0.8586215748387847)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'MonetaryPolicyRate_monthly',
#   np.float64(0.9255539791558516)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.953594940847639)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8989984378152897)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'bank reserves_monthly',
#   np.float64(0.9225551655520214)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9419508717572236)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'creditToPrivateSector_monthly',
#   np.float64(0.9444105358130831)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'currency in circulation_monthly',
#   np.float64(0.8835871119669909)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9346907490869097)),
#  ('gdp_svc_FI_Financial Institutions_quarterly',
#   'netDomesticCredit_monthly',
#   np.float64(0.9361688386262328)),
#  ('n_stocks_contributing',
#   'GDP_INDUSTRY(ind)_quarterly',
#   np.float64(0.8863312952347339)),
#  ('netDomesticAssets_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9621069868987964)),
#  ('netDomesticAssets_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8932481205028497)),
#  ('netDomesticAssets_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9470482364565334)),
#  ('netDomesticAssets_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9619650054120634)),
#  ('netDomesticAssets_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.9172318595338825)),
#  ('netDomesticCredit_monthly',
#   'Money Supply(M2)_monthly',
#   np.float64(0.9694707096259647)),
#  ('netDomesticCredit_monthly',
#   'Premium_Motor_Spirit(PMS)_monthly',
#   np.float64(0.8948461830271802)),
#  ('netDomesticCredit_monthly',
#   'bank reserves_monthly',
#   np.float64(0.9502666272613957)),
#  ('netDomesticCredit_monthly',
#   'consumer_price_index(CPI)_monthly',
#   np.float64(0.9682944566326122)),
#  ('netDomesticCredit_monthly',
#   'currency in circulation_monthly',
#   np.float64(0.8809537134589494)),
#  ('netDomesticCredit_monthly',
#   'netDomesticAssets_monthly',
#   np.float64(0.9735727786322169))}

# %%
from xgboost import XGBRegressor, XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score,classification_report,confusion_matrix
import numpy as np

# %%
X=fin_data_tr.drop(columns=['new_monthly_returns'])
y=fin_data_tr['new_monthly_returns']


X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,shuffle=False)



## getting baseline
pred_base = np.full_like(y_test, y_train.mean(), dtype=float)
baseline_rmse=np.sqrt(mean_squared_error(y_test, pred_base))

## Apply standardscaler to standardize the data
# Fit to the training data (calculates mean and std)
scaler=StandardScaler()
scaler.fit(X_train)

# Transform the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = XGBRegressor(
    max_depth=2,           # very shallow — start conservative
    n_estimators=300,
    learning_rate=0.01,
    subsample=0.6,
    colsample_bytree=0.6,
    reg_alpha=2.0,
    reg_lambda=10.0,
    min_child_weight=20,
    random_state=42
)


model.fit(X_train_scaled, y_train)
preds_test = model.predict(X_test_scaled)
preds_train = model.predict(X_train_scaled)

rmse = np.sqrt(mean_squared_error(y_test, preds_test))

r2_test=r2_score(y_true=y_test,y_pred=preds_test)
r2_train=r2_score(y_true=y_train,y_pred=preds_train)

    
print(f"\nRMSE: {rmse:.4f}")
print(f"\nR2_score_test: {r2_test:.4f}")
print(f"\nMean R2_score_train across folds: {r2_train:.4f}")
print('baseline information: ', baseline_rmse)
# Out:
# RMSE: 8.8887
#
# R2_score_test: -0.2469
#
# Mean R2_score_train across folds: 0.2270
# baseline information:  8.775099710172928

# %% [markdown]
# Let us apply classification. Regression will be very poor because of how small the data size is.

# %%
## include a target column for classification

fin_data_tr['returns_movement']=[1 if num >= 0 else 0 for num in fin_data_tr['new_monthly_returns']]

# %%
fin_data_tr['returns_movement']
# Out:
# 3      1
# 4      1
# 5      1
# 6      1
# 7      1
#       ..
# 108    1
# 109    1
# 110    0
# 111    1
# 112    1
# Name: returns_movement, Length: 110, dtype: int64

# %%
fin_data_tr['returns_movement'].value_counts()
# Out:
# returns_movement
# 1    69
# 0    41
# Name: count, dtype: int64

# %%
X=fin_data_tr.drop(columns=['new_monthly_returns','returns_movement'])
y=fin_data_tr['returns_movement']


X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,shuffle=False)



## getting baseline
pred_base = np.full_like(y_test, y_train.mean(), dtype=float)
baseline_rmse=np.sqrt(mean_squared_error(y_test, pred_base))

## Apply standardscaler to standardize the data
# Fit to the training data (calculates mean and std)
scaler=StandardScaler()
scaler.fit(X_train)

# Transform the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)


model_obj=XGBClassifier(
    max_depth=2,
    n_estimators=300,
    learning_rate=0.01,
    subsample=0.6,
    colsample_bytree=0.6,
    reg_alpha=2.0,
    reg_lambda=10.0,
    min_child_weight=20,
    random_state=42
)


model_obj.fit(X_train_scaled, y_train)
preds_train=model_obj.predict(X_train_scaled)
preds_test = model_obj.predict(X_test_scaled)


train_accuracy_score1=accuracy_score(y_true=y_train,y_pred=preds_train)
test_accuracy_score1=accuracy_score(y_true=y_test,y_pred=preds_test)

print(f"training accuracy_score={train_accuracy_score1}")
print(f"test accuracy_score ={test_accuracy_score1:.4f}")
print(f'{classification_report(y_true=y_test,y_pred=preds_test)}')
print(f'{confusion_matrix(y_true=y_test,y_pred=preds_test)}')
# Out:
# training accuracy_score=0.5909090909090909
# test accuracy_score =0.6818
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.68      1.00      0.81        30
#
#     accuracy                           0.68        44
#    macro avg       0.34      0.50      0.41        44
# weighted avg       0.46      0.68      0.55        44
#
# [[ 0 14]
#  [ 0 30]]
# c:\Users\pc\Downloads\Python_NGX_Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\pc\Downloads\Python_NGX_Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\pc\Downloads\Python_NGX_Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### I DON TIRE!!!

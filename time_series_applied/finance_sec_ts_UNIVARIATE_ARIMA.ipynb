# %% [markdown]
# ## ARIMA

# %% [markdown]
# In this case since i is for integration(differencing). We will use the sector index instead of the wighted returns. Because the weighted returns have already been differenced.

# %%
import pandas as pd

finsec_data=pd.read_csv('../feature_engineering/stocks_sectors/financial_services/financial_services_sector')

finsec_data
# Out:
#             date              sector  weighted_sector_returns  \
# 0     2017-01-03  financial_services                 0.000000
# 1     2017-01-04  financial_services                 0.353432
# 2     2017-01-05  financial_services                -0.182223
# 3     2017-01-06  financial_services                 1.397196
# 4     2017-01-09  financial_services                 3.645896
# ...          ...                 ...                      ...
# 2258  2026-07-13  financial_services                -0.746327
# 2259  2026-07-14  financial_services                 0.906947
# 2260  2026-07-15  financial_services                 0.779799
# 2261  2026-07-16  financial_services                 1.505893
# 2262  2026-07-17  financial_services                 1.536021
#
#       n_stocks_contributing  sector_index  sector_volume
# 0                      20.0    100.000000     48125518.0
# 1                      20.0    100.353432     26705191.0
# 2                      20.0    100.170565     66991076.0
# 3                      20.0    101.570144     97521276.0
# 4                      20.0    105.273286     99013315.0
# ...                     ...           ...            ...
# 2258                   35.0   2695.019313    290562049.0
# 2259                   35.0   2719.461701    163509442.0
# 2260                   35.0   2740.668037    258362267.0
# 2261                   35.0   2781.939574    261040578.0
# 2262                   35.0   2824.670764    295044834.0
#
# [2263 rows x 6 columns]

# %%
fin_data=finsec_data[['date','weighted_sector_returns', 'sector_index']]
fin_data
# Out:
#             date  weighted_sector_returns  sector_index
# 0     2017-01-03                 0.000000    100.000000
# 1     2017-01-04                 0.353432    100.353432
# 2     2017-01-05                -0.182223    100.170565
# 3     2017-01-06                 1.397196    101.570144
# 4     2017-01-09                 3.645896    105.273286
# ...          ...                      ...           ...
# 2258  2026-07-13                -0.746327   2695.019313
# 2259  2026-07-14                 0.906947   2719.461701
# 2260  2026-07-15                 0.779799   2740.668037
# 2261  2026-07-16                 1.505893   2781.939574
# 2262  2026-07-17                 1.536021   2824.670764
#
# [2263 rows x 3 columns]

# %%
fin_data['date']=pd.to_datetime(fin_data['date'])
fin_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     2263 non-null   datetime64[us]
#  1   weighted_sector_returns  2263 non-null   float64
#  2   sector_index             2263 non-null   float64
# dtypes: datetime64[us](1), float64(2)
# memory usage: 53.2 KB

# %% [markdown]
# Instead of guessing \(p, d, q\), We can use the `pmdarima` library. It automatically tests our trended data, finds the correct \(d\) to remove the trend, and picks the best \(p\) and \(q\).

# %%
import pmdarima as pm

# This automatically finds the best p, d, and q for your trended data
model = pm.auto_arima(fin_data['sector_index'], 
                      d=None,           # Let the algorithm find the best 'd'
                      seasonal=False,   # Set to True if you also have seasonal patterns
                      stepwise=True)

print(model.summary()) # This will show you the chosen p, d, q values
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2263
# Model:               SARIMAX(5, 2, 0)   Log Likelihood               -9256.569
# Date:                Sun, 23 Aug 2026   AIC                          18525.138
# Time:                        10:35:56   BIC                          18559.479
# Sample:                             0   HQIC                         18537.669
#                                - 2263
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6990      0.008    -88.737      0.000      -0.714      -0.684
# ar.L2         -0.6463      0.011    -59.757      0.000      -0.668      -0.625
# ar.L3         -0.4937      0.013    -39.383      0.000      -0.518      -0.469
# ar.L4         -0.3389      0.011    -31.947      0.000      -0.360      -0.318
# ar.L5         -0.2104      0.011    -19.282      0.000      -0.232      -0.189
# sigma2       210.5467      1.728    121.848      0.000     207.160     213.933
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):            202665.87
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):              81.24   Skew:                            -0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                        49.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# This result is actually quite informative. The most important part is:
#
# SARIMAX(5, 2, 0). But there are other red flags. The `Heteroskedasticity` and `Jarque-Bera` are not good signs(check CHAT).
#
# But lets test it below.

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# Showing the test prediction of the final model
data_array = fin_data['sector_index'].to_numpy().reshape(-1, 1)
X_train, X_test = data_array[:-10], data_array[-10:]
X_test_orig = X_test
fcst = []

for step in range(10):
    mod = ARIMA(X_train, order=(5,2,0))
    res = mod.fit()
    fcst.append(res.forecast(steps=1))
    X_train = np.concatenate((X_train, X_test[0:1,:]))
    X_test = X_test[1:]

# %%
plt.plot(X_test_orig)
plt.plot(fcst)
plt.legend(['Actual Sunspots', 'Predicted Sunspots'])
plt.xlabel('Time steps of test data')
plt.show()
print("r2_score: ", r2_score(X_test_orig,fcst))
# Out:
# r2_score:  0.33809219484471

# %% [markdown]
# This is sooo much better. We will try other hyperparameters. For now lets see how well it works with the sector returns.

# %%
import pmdarima as pm

# This automatically finds the best p, d, and q for your trended data
model = pm.auto_arima(fin_data['weighted_sector_returns'], 
                      d=None,           # Let the algorithm find the best 'd'
                      seasonal=True,   # Set to True if you also have seasonal patterns
                      stepwise=True)

print(model.summary()) # This will show you the chosen p, d, q values
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2263
# Model:               SARIMAX(0, 0, 1)   Log Likelihood               -4245.795
# Date:                Sun, 23 Aug 2026   AIC                           8497.589
# Time:                        11:41:33   BIC                           8514.763
# Sample:                             0   HQIC                          8503.856
#                                - 2263
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1607      0.039      4.111      0.000       0.084       0.237
# ma.L1          0.1771      0.009     18.975      0.000       0.159       0.195
# sigma2         2.4955      0.032     78.903      0.000       2.433       2.557
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              7676.04
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.82   Skew:                            -0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Lets work with SARIMAX(0, 0, 1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# Showing the test prediction of the final model
data_array = fin_data['weighted_sector_returns'].to_numpy().reshape(-1, 1)
X_train, X_test = data_array[:-10], data_array[-10:]
X_test_orig = X_test
fcst = []

for step in range(10):
    mod = ARIMA(X_train, order=(0,0,1))
    res = mod.fit()
    fcst.append(res.forecast(steps=1))
    X_train = np.concatenate((X_train, X_test[0:1,:]))
    X_test = X_test[1:]

# %%
plt.plot(X_test_orig)
plt.plot(fcst)
plt.legend(['Actual Sunspots', 'Predicted Sunspots'])
plt.xlabel('Time steps of test data')
plt.show()
print("r2_score: ", r2_score(X_test_orig,fcst))
# Out:
# r2_score:  -0.04428741361142774

# %% [markdown]
# It learned better from the trend data. So how do we improve it. Lets improve the max of each parameter.

# %%
import pmdarima as pm

# This automatically finds the best p, d, and q for your trended data
model = pm.auto_arima(fin_data['sector_index'], 
                      d=None,           # Let the algorithm find the best 'd'
                      max_P=10, start_p=1,
                      max_d=10, 
                      max_q=10, start_q=1,
                      seasonal=False,   # Set to True if you also have seasonal patterns
                      stepwise=True)

print(model.summary()) # This will show you the chosen p, d, q values
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2263
# Model:               SARIMAX(5, 2, 0)   Log Likelihood               -9256.569
# Date:                Sun, 23 Aug 2026   AIC                          18525.138
# Time:                        11:56:40   BIC                          18559.479
# Sample:                             0   HQIC                         18537.669
#                                - 2263
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6990      0.008    -88.737      0.000      -0.714      -0.684
# ar.L2         -0.6463      0.011    -59.757      0.000      -0.668      -0.625
# ar.L3         -0.4937      0.013    -39.383      0.000      -0.518      -0.469
# ar.L4         -0.3389      0.011    -31.947      0.000      -0.360      -0.318
# ar.L5         -0.2104      0.011    -19.282      0.000      -0.232      -0.189
# sigma2       210.5467      1.728    121.848      0.000     207.160     213.933
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):            202665.87
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):              81.24   Skew:                            -0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                        49.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Its the same. Lets move on.

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
from statsmodels.tsa.arima.model import ARIMA
import warnings

warnings.filterwarnings('ignore')

data_array = fin_data['sector_index'].to_numpy().reshape(-1, 1)
avg_errors = []

for p in range(6):
    for q in range(3):
        for i in range(5):
            errors = []
            tscv = TimeSeriesSplit(test_size=10)

            for train_index, test_index in tscv.split(data_array):
                X_train = data_array[train_index]
                X_test = data_array[test_index]
                X_test_orig = X_test.copy()
                fcst = []

                for step in range(10):
                    try:
                        mod = ARIMA(X_train, order=(p, i, q))
                        res = mod.fit()

                        # Convert forecast from array to scalar
                        forecast = res.forecast(steps=1)[0]
                        fcst.append(forecast)

                    except Exception as e:
                        print(f"Error for p={p}, i={i}, q={q}, step={step}: {e}")

                        # Use a scalar here as well
                        fcst.append(np.nan)

                    # Add actual observation to training data
                    X_train = np.concatenate(
                        (X_train, X_test[0:1, :])
                    )

                    # Remove first test observation
                    X_test = X_test[1:]

                # Convert actual values to 1D
                y_true = X_test_orig.ravel()

                # Convert forecasts to 1D
                y_pred = np.array(fcst)

                # Don't calculate R² if a model failed
                if np.isnan(y_pred).any():
                    errors.append(np.nan)
                else:
                    errors.append(r2_score(y_true, y_pred))

            pq_result = [p, i, q, np.nanmean(errors)]
            print(pq_result)
            avg_errors.append(pq_result)
# Out:
# [0, 0, 0, np.float64(-1608.1446182406326)]
# [0, 1, 0, np.float64(0.5693287514112593)]
# [0, 2, 0, np.float64(0.3439805530816028)]
# [0, 3, 0, np.float64(-0.8059758009922888)]
# [0, 4, 0, np.float64(-4.591510577637024)]
# [0, 0, 1, np.float64(-456.73347489933786)]
# [0, 1, 1, np.float64(0.5957376321690979)]
# [0, 2, 1, np.float64(0.5416865769192253)]
# [0, 3, 1, np.float64(0.34364269486590443)]
# [0, 4, 1, np.float64(-0.8070334080728567)]
# [0, 0, 2, np.float64(-130.08693874213594)]
# [0, 1, 2, np.float64(0.5951425987545678)]
# [0, 2, 2, np.float64(0.5943279887820173)]
# [0, 3, 2, np.float64(0.5396901709809343)]
# [0, 4, 2, np.float64(0.3535679543900635)]
# [1, 0, 0, np.float64(0.5690407982738267)]
# [1, 1, 0, np.float64(0.5913500201239374)]
# [1, 2, 0, np.float64(0.40121965332819104)]
# [1, 3, 0, np.float64(-0.294571072016443)]
# [1, 4, 0, np.float64(-2.3450668613808054)]
# [1, 0, 1, np.float64(0.595368912868105)]
# [1, 1, 1, np.float64(0.5952198152699134)]
# [1, 2, 1, np.float64(0.5898011548140042)]
# [1, 3, 1, np.float64(0.4009713095257978)]
# [1, 4, 1, np.float64(-0.2951713349105608)]
# [1, 0, 2, np.float64(0.5947970321440607)]
# [1, 1, 2, np.float64(0.6003490876235301)]
# [1, 2, 2, np.float64(0.5938259473819268)]
# [1, 3, 2, np.float64(0.5911323325213652)]
# [1, 4, 2, np.float64(0.39636057292481547)]
# Error for p=2, i=0, q=0, step=2: LU decomposition error.
# Error for p=2, i=0, q=0, step=7: LU decomposition error.
# Error for p=2, i=0, q=0, step=7: LU decomposition error.
# [2, 0, 0, np.float64(-8663.467508436255)]
# [2, 1, 0, np.float64(0.5946143116695949)]
# [2, 2, 0, np.float64(0.45865297533270066)]
# [2, 3, 0, np.float64(0.0546593166642392)]
# [2, 4, 0, np.float64(-1.1255060520395466)]
# [2, 0, 1, np.float64(-7.1250238733063895)]
# [2, 1, 1, np.float64(0.5919036256497465)]
# [2, 2, 1, np.float64(0.5876149998135785)]
# [2, 3, 1, np.float64(0.45847080119023714)]
# [2, 4, 1, np.float64(0.05421565321517145)]
# Error for p=2, i=0, q=2, step=6: LU decomposition error.
# [2, 0, 2, np.float64(0.5400481805741799)]
# [2, 1, 2, np.float64(0.5860314485452002)]
# [2, 2, 2, np.float64(0.5876127615593114)]
# Error for p=2, i=3, q=2, step=8: LU decomposition error.
# [2, 3, 2, np.float64(0.5446666161110527)]
# [2, 4, 2, np.float64(0.4578806108024436)]
# Error for p=3, i=0, q=0, step=4: LU decomposition error.
# Error for p=3, i=0, q=0, step=6: LU decomposition error.
# Error for p=3, i=0, q=0, step=8: LU decomposition error.
# Error for p=3, i=0, q=0, step=0: LU decomposition error.
# Error for p=3, i=0, q=0, step=8: LU decomposition error.
# Error for p=3, i=0, q=0, step=6: LU decomposition error.
# Error for p=3, i=0, q=0, step=5: LU decomposition error.
# [3, 0, 0, np.float64(nan)]
# [3, 1, 0, np.float64(0.5919166325746161)]
# [3, 2, 0, np.float64(0.44598760218645433)]
# [3, 3, 0, np.float64(0.15928651253916642)]
# [3, 4, 0, np.float64(-0.5995436753172309)]
# [3, 0, 1, np.float64(-14.904731233877746)]
# [3, 1, 1, np.float64(0.5747360279587969)]
# [3, 2, 1, np.float64(0.5904630245910136)]
# [3, 3, 1, np.float64(0.44588575595368213)]
# [3, 4, 1, np.float64(0.1589281885609707)]
# [3, 0, 2, np.float64(0.5889312567692431)]
# [3, 1, 2, np.float64(0.5650212192474664)]
# [3, 2, 2, np.float64(0.5917061380860287)]
# Error for p=3, i=3, q=2, step=0: LU decomposition error.
# [3, 3, 2, np.float64(-1500587009957.3843)]
# [3, 4, 2, np.float64(-21.799579424830174)]
# [4, 0, 0, np.float64(-9.840003196379046)]
# [4, 1, 0, np.float64(0.5822484164574032)]
# [4, 2, 0, np.float64(0.4485917685624033)]
# [4, 3, 0, np.float64(0.1130544699093949)]
# [4, 4, 0, np.float64(-0.5195613249888813)]
# [4, 0, 1, np.float64(0.5913176985622299)]
# [4, 1, 1, np.float64(0.5731066114152652)]
# [4, 2, 1, np.float64(0.5845319547162875)]
# [4, 3, 1, np.float64(0.4485110494074176)]
# [4, 4, 1, np.float64(0.1127594546991709)]
# [4, 0, 2, np.float64(0.5931870455348982)]
# [4, 1, 2, np.float64(0.5738276682173911)]
# [4, 2, 2, np.float64(0.5837659999830528)]
# Error for p=4, i=3, q=2, step=2: LU decomposition error.
# Error for p=4, i=3, q=2, step=9: LU decomposition error.
# Error for p=4, i=3, q=2, step=9: LU decomposition error.
# [4, 3, 2, np.float64(-1.0075761075601842e+18)]
# [4, 4, 2, np.float64(0.43459881010132745)]
# Error for p=5, i=0, q=0, step=4: LU decomposition error.
# Error for p=5, i=0, q=0, step=9: LU decomposition error.
# [5, 0, 0, np.float64(0.513313752580629)]
# [5, 1, 0, np.float64(0.5761263354773634)]
# [5, 2, 0, np.float64(0.5035374241724675)]
# [5, 3, 0, np.float64(0.18340044339309083)]
# [5, 4, 0, np.float64(-0.4355101753437346)]
# [5, 0, 1, np.float64(0.5869679131934346)]
# [5, 1, 1, np.float64(0.5741374675451676)]
# [5, 2, 1, np.float64(0.5810668012063637)]
# [5, 3, 1, np.float64(0.5033201609973299)]
# [5, 4, 1, np.float64(0.18326600120828065)]
# [5, 0, 2, np.float64(0.5873253851250632)]
# [5, 1, 2, np.float64(0.5731822622092431)]
# [5, 2, 2, np.float64(0.5834551291340964)]
# [5, 3, 2, np.float64(0.4399426562679298)]
# [5, 4, 2, np.float64(-4.821228300642553e+22)]

# %%
import pandas as pd

avg_errors = pd.DataFrame(avg_errors)
avg_errors.columns = ['p', 'i', 'q', 'error']
result=avg_errors.sort_values('error', ascending=False)

# %%
result
# Out:
#     p  i  q         error
# 26  1  1  2  6.003491e-01
# 6   0  1  1  5.957376e-01
# 20  1  0  1  5.953689e-01
# 21  1  1  1  5.952198e-01
# 11  0  1  2  5.951426e-01
# .. .. .. ..           ...
# 30  2  0  0 -8.663468e+03
# 58  3  3  2 -1.500587e+12
# 73  4  3  2 -1.007576e+18
# 89  5  4  2 -4.821228e+22
# 45  3  0  0           NaN
#
# [90 rows x 4 columns]

# %% [markdown]
# from this (1,1,2) is the best hyperprameter. We will train with both Timeseriescv and train_test_split to view its performance

# %% [markdown]
# #### train_test_split

# %%
data_array
# Out:
# array([[ 100.        ],
#        [ 100.35343188],
#        [ 100.17056456],
#        ...,
#        [2740.66803716],
#        [2781.93957376],
#        [2824.67076352]], shape=(2263, 1))

# %%
# Plot the final result

X_train, X_test = data_array[:-10], data_array[-10:]
X_test_orig = X_test

fcst = []
for step in range(10):
    mod = ARIMA(X_train, order=(1,1,2))
    res = mod.fit()
    fcst.append(res.forecast(steps=1))
    X_train = np.concatenate((X_train, X_test[0:1,:]))
    X_test = X_test[1:]
plt.plot(fcst)
plt.plot(X_test_orig)
plt.legend(['Predicted', 'Actual'])
plt.ylabel('sector_index')
plt.xlabel('Time Step of Test Data')
plt.show()
print('r2_score: ', r2_score(X_test_orig,fcst))
# Out:
# r2_score:  0.42708355785610885

# %% [markdown]
# Not very good but better. Now:
#
# #### TimeSeriesSplitCV

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt

tscv = TimeSeriesSplit(test_size=10)

actual = []
predicted = []

for train_index, test_index in tscv.split(data_array):

    train = data_array[train_index]
    test = data_array[test_index]

    # Train ARIMA(1,1,2)
    model = ARIMA(train, order=(1, 1, 2))
    results = model.fit()

    # Forecast the entire 10-observation test period
    forecast = results.forecast(steps=len(test))

    actual.extend(test)
    predicted.extend(forecast)

# Convert to arrays
actual = np.array(actual)
predicted = np.array(predicted)

# R² across all test observations
r2 = r2_score(actual, predicted)

print("R² Score:", r2)

# Plot
plt.figure(figsize=(12, 5))

plt.plot(actual, label="Actual")
plt.plot(predicted, label="Predicted")

plt.xlabel("Time")
plt.ylabel("Sector Index")
plt.title("ARIMA(1,1,2) - Actual vs Predicted")
plt.legend()

plt.show()
# Out:
# R² Score: 0.567961055361135

# %% [markdown]
# When you come back look at the code properly its not very correct
